# %% [markdown]
# ## 0. Import libraries

# %%
import torch
import pandas as pd
import numpy as np
import math, copy, time
import torch.nn as nn
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset 
from torch.optim import Adam
import tqdm
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error

# %% [markdown]
# ## 1. Load Data

# %%
df = pd.read_csv('./total.csv')
df.tail()
# Out:
#             Date          S&P     currency         gold        kospi  \
# 5339  2024-05-17  5303.270020  1346.040039  2412.199951  2724.620117
# 5340  2024-05-20  5308.129883  1353.390015  2433.899902  2742.139893
# 5341  2024-05-21  5321.410156  1360.160034  2421.699951  2724.179932
# 5342  2024-05-22  5307.009766  1363.420044  2389.199951  2723.459961
# 5343  2024-05-23  5307.009766  1363.420044  2365.199951  2721.810059
#
#       kospi_shift
# 5339  2742.139893
# 5340  2724.179932
# 5341  2723.459961
# 5342  2721.810059
# 5343  2721.810059

# %%
col_names = df.columns.values
print(col_names)
# Out:
# ['Date' 'S&P' 'currency' 'gold' 'kospi' 'kospi_shift']

# %%
# global variables and hyperparameter
IN_DIM = 128
DAY_INT = 1
BATCH_SIZE = 64
SCALER = 'MINMAX'   # 'NORMAL'
# SCALER = 'NORMAL'   # 'NORMAL'
TRAIN_TEST_SPLIT = 0.95
LR = 1e-4

# %% [markdown]
# ## 2. Split data train and test

# %%
# train test split
df_train = df.iloc[:int(len(df) * TRAIN_TEST_SPLIT), :]
df_test = df.iloc[int(len(df) * TRAIN_TEST_SPLIT): , :]
# print(df_train.tail())
# print(df_test.head())
scale_params = pd.DataFrame(index=['mean', 'var', 'max', 'min'])
for i in col_names[1:]:
    scale_params[i] = [df_train[i].mean(), df_train[i].var(), df_train[i].max(), df_train[i].min()]
scale_params
# Out:
#                S&P      currency           gold          kospi    kospi_shift
# mean  2.060187e+03   1120.468225    1212.153132    1908.118825    1908.346142
# var   1.040263e+06  11179.495861  197490.747079  285130.964445  285101.043571
# max   4.796560e+03   1571.400024    2051.500000    3305.209961    3305.209961
# min   6.765300e+02    886.679993     374.799988     719.590027     719.590027

# %%
# scaling
train_data = pd.DataFrame()
test_data = pd.DataFrame()
if SCALER == 'MINMAX':
    for i in col_names[1:]:
        train_data[i] = df_train[i].apply(lambda x: (x - scale_params.loc['min', i])/(scale_params.loc['max', i] - scale_params.loc['min', i]))
        test_data[i] = df_test[i].apply(lambda x: (x - scale_params.loc['min', i])/(scale_params.loc['max', i] - scale_params.loc['min', i]))
elif SCALER == 'NORMAL':
    for i in col_names[1:]:
        train_data[i] = df_train[i].apply(lambda x: (x - scale_params.loc['mean', i])/scale_params.loc['var', i])
        test_data[i] = df_test[i].apply(lambda x: (x - scale_params.loc['mean', i])/scale_params.loc['var', i])
test_data.tail()
# Out:
#            S&P  currency      gold     kospi  kospi_shift
# 5339  1.122987  0.670873  1.215125  0.775454     0.782230
# 5340  1.124167  0.681607  1.228067  0.782230     0.775284
# 5341  1.127390  0.691494  1.220791  0.775284     0.775006
# 5342  1.123895  0.696255  1.201407  0.775006     0.774367
# 5343  1.123895  0.696255  1.187094  0.774367     0.774367

# %%
class StockDataset(Dataset):
    def __init__(self, data, input_window=128, output_window=1, stride=1):
        #총 데이터의 개수
        # print(data.shape)
        L = data.shape[0]
        features = data.shape[1] - 1
        #stride씩 움직일 때 생기는 총 sample의 개수
        num_samples = (L - input_window - output_window) // stride + 1
        start_pos = (L - input_window - output_window) % stride
        iter_times = (L - input_window - output_window) // stride + 1
        # print(data.shape, num_samples, iter_times, start_pos, L)

        #input과 output
        X = np.zeros([num_samples, input_window, features])
        Y = np.zeros([num_samples, output_window])
        # print(X.shape, Y.shape)
        for i in np.arange(num_samples):
            start_x = start_pos + i * stride
            end_x = start_x + input_window
            X[i, :, :] = data.iloc[start_x:end_x, :-1]

            # end_y = start_y + output_window
            # print(i, start_x, end_x)
            Y[i, :] = data.iloc[end_x: end_x + output_window, -1:]
        # print(X.shape, Y.shape)
        # X = X.reshape(X.shape[0], X.shape[1], 1).transpose((1,0,2))
        # Y = Y.reshape(Y.shape[0], Y.shape[1], 1).transpose((1,0,2))
        print(X.shape, Y.shape)
        self.x = X
        self.y = Y
        
        self.len = len(X)
    def __getitem__(self, i):
        return self.x[i], self.y[i]
    def __len__(self):
        return self.len

# %% [markdown]
# ### 3. create dataloader

# %%
train_dataset = StockDataset(train_data, 128, 1, 1)
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

test_dataset = StockDataset(test_data, 128, 1, 1)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
a1 = next(iter(train_dataset))
print(len(train_dataloader), len(train_dataloader.dataset), a1[0].shape, a1[1].shape)
print(a1)
# Out:
# (4948, 128, 4) (4948, 1)
# (140, 128, 4) (140, 1)
# 78 4948 (128, 4) (1,)
# (array([[0.09553085, 0.45525181, 0.01663984, 0.03395704],
#        [0.09468134, 0.45028624, 0.01723625, 0.03410788],
#        [0.0942226 , 0.44663511, 0.01735552, 0.03432446],
#        [0.09543376, 0.44312999, 0.01699767, 0.03308297],
#        [0.09343863, 0.43524352, 0.01884655, 0.02700317],
#        [0.09533183, 0.43655796, 0.01896584, 0.02522024],
#        [0.09311826, 0.43232262, 0.0199201 , 0.02620646],
#        [0.09284399, 0.42312189, 0.01872728, 0.02902592],
#        [0.0957954 , 0.41362896, 0.01777302, 0.0276684 ],
#        [0.09650657, 0.41844834, 0.02063578, 0.03345039],
#        [0.09502601, 0.42823346, 0.02051651, 0.03966938],
#        [0.09674686, 0.42808746, 0.01962189, 0.03527199],
#        [0.09707452, 0.43860263, 0.02218644, 0.03113373],
#        [0.10015704, 0.43392926, 0.02123219, 0.03399957],
#        [0.10003083, 0.44707332, 0.02051651, 0.03543057],
#        [0.10106963, 0.45101646, 0.02135147, 0.03285477],
#        [0.10181722, 0.45087045, 0.02159004, 0.03182601],
#        [0.10133664, 0.45831872, 0.02236536, 0.02821759],
#        [0.10133664, 0.45656625, 0.02236536, 0.02821759],
#        [0.10178566, 0.45861074, 0.02236536, 0.02678659],
#        [0.10508417, 0.43728819, 0.02385638, 0.02817505],
#        [0.10512302, 0.44999422, 0.02510885, 0.03524106],
#        [0.10567642, 0.44283797, 0.02439317, 0.03524106],
#        [0.10567642, 0.43071616, 0.02439317, 0.03524106],
#        [0.10484146, 0.45145467, 0.02439317, 0.03932132],
#        [0.10817638, 0.42677301, 0.02958192, 0.04041969],
#        [0.10852834, 0.44210775, 0.02862766, 0.04016057],
#        [0.10917394, 0.4237061 , 0.0280909 , 0.04156836],
#        [0.11053075, 0.41523542, 0.02934336, 0.04043904],
#        [0.10808901, 0.43027813, 0.03077474, 0.0486073 ],
#        [0.10939239, 0.4120225 , 0.03071509, 0.05074216],
#        [0.10793367, 0.42151543, 0.02916444, 0.04982943],
#        [0.11019094, 0.42136924, 0.02797163, 0.05028967],
#        [0.11056231, 0.42034699, 0.02003937, 0.04875811],
#        [0.11245062, 0.43816442, 0.01902548, 0.04964379],
#        [0.11245062, 0.43933286, 0.01902548, 0.05306656],
#        [0.11219335, 0.42355992, 0.02260394, 0.05483403],
#        [0.11434139, 0.4345133 , 0.02164968, 0.05483403],
#        [0.11344818, 0.43962488, 0.02099363, 0.05483403],
#        [0.11286811, 0.42136924, 0.01974116, 0.05483403],
#        [0.11622245, 0.42034699, 0.01896584, 0.05780043],
#        [0.11347491, 0.41056204, 0.02099363, 0.05547606],
#        [0.10969579, 0.42312189, 0.02367747, 0.05414562],
#        [0.11106229, 0.39654157, 0.01413492, 0.05177866],
#        [0.110339  , 0.39917046, 0.01634164, 0.0498565 ],
#        [0.11134142, 0.39683377, 0.0142542 , 0.05232787],
#        [0.11152831, 0.41421317, 0.01455241, 0.04651881],
#        [0.10922008, 0.4121685 , 0.01562594, 0.0448287 ],
#        [0.10972249, 0.39581135, 0.01389635, 0.0469249 ],
#        [0.11316179, 0.40983182, 0.01717661, 0.05052558],
#        [0.11244579, 0.38865528, 0.01908511, 0.05614901],
#        [0.11383655, 0.40734895, 0.01884655, 0.05693411],
#        [0.11680254, 0.4004849 , 0.02111291, 0.06062376],
#        [0.11543119, 0.39800202, 0.02320035, 0.06124643],
#        [0.11390209, 0.39873225, 0.02117254, 0.06288239],
#        [0.11390209, 0.38120684, 0.02117254, 0.06253433],
#        [0.11661565, 0.39464309, 0.02457208, 0.06389569],
#        [0.11536079, 0.38120684, 0.02236536, 0.06091767],
#        [0.11420549, 0.38018459, 0.02087434, 0.06267742],
#        [0.11348945, 0.39551933, 0.01353851, 0.06106851],
#        [0.11273218, 0.42750324, 0.01443312, 0.06108013],
#        [0.11227101, 0.42852548, 0.01771337, 0.05607939],
#        [0.11338267, 0.39741799, 0.0125246 , 0.05696118],
#        [0.11368364, 0.40764114, 0.0125246 , 0.0561838 ],
#        [0.1136909 , 0.4178643 , 0.01288245, 0.06336196],
#        [0.11636807, 0.42385211, 0.01461204, 0.06336196],
#        [0.11470061, 0.40355181, 0.01115287, 0.06946883],
#        [0.11516906, 0.39420489, 0.01049681, 0.06815386],
#        [0.11610109, 0.39917046, 0.01079502, 0.07264794],
#        [0.11658409, 0.42209946, 0.01580485, 0.0718551 ],
#        [0.11423944, 0.39420489, 0.01538738, 0.06981302],
#        [0.11263266, 0.43042414, 0.01753446, 0.06651789],
#        [0.10858173, 0.397564  , 0.01502953, 0.06049999],
#        [0.10442885, 0.40209136, 0.01544702, 0.05814465],
#        [0.10777589, 0.42399812, 0.0122264 , 0.04997253],
#        [0.10387302, 0.41435918, 0.01467168, 0.05131071],
#        [0.10538028, 0.41581963, 0.01646091, 0.05048692],
#        [0.10854775, 0.42034699, 0.01914475, 0.0590922 ],
#        [0.10820065, 0.39814821, 0.02164968, 0.05926238],
#        [0.105157  , 0.41450519, 0.02248465, 0.06332717],
#        [0.10166673, 0.40369782, 0.02540705, 0.05573131],
#        [0.10131478, 0.40399002, 0.02683843, 0.05669045],
#        [0.10067886, 0.43246881, 0.02528778, 0.05496939],
#        [0.10501378, 0.43349105, 0.02498958, 0.05174387],
#        [0.10473953, 0.43465948, 0.02821019, 0.05583187],
#        [0.10823706, 0.42867149, 0.02522814, 0.05997786],
#        [0.10933657, 0.42648082, 0.02797163, 0.0595099 ],
#        [0.10914482, 0.40837137, 0.0313115 , 0.06223265],
#        [0.11059143, 0.40136113, 0.03160971, 0.06310284],
#        [0.11293122, 0.43436729, 0.02791198, 0.06346639],
#        [0.11505739, 0.45087045, 0.02421423, 0.06346639],
#        [0.11447247, 0.43392926, 0.02630167, 0.07216837],
#        [0.11262054, 0.35813182, 0.02862766, 0.07361483],
#        [0.11232683, 0.36192896, 0.02689808, 0.07629503],
#        [0.11232683, 0.36076053, 0.02689808, 0.0718783 ],
#        [0.11375401, 0.36265918, 0.02701737, 0.07706854],
#        [0.10992879, 0.37317436, 0.0192044 , 0.07659284],
#        [0.10962056, 0.39668776, 0.01491024, 0.07608232],
#        [0.10978317, 0.38777887, 0.01365779, 0.07608232],
#        [0.11118364, 0.40063091, 0.01562594, 0.0693412 ],
#        [0.11147732, 0.39318264, 0.01538738, 0.07058653],
#        [0.10718854, 0.39858624, 0.01365779, 0.07708403],
#        [0.10863026, 0.39712579, 0.00954255, 0.08135766],
#        [0.11247491, 0.39814821, 0.01103358, 0.07906034],
#        [0.11263752, 0.3943509 , 0.01210713, 0.08372072],
#        [0.11140695, 0.37215211, 0.01264389, 0.07740889],
#        [0.11203315, 0.38821707, 0.01419456, 0.07575744],
#        [0.10822251, 0.37653347, 0.00632195, 0.07048213],
#        [0.10615456, 0.41319075, 0.00703764, 0.06026406],
#        [0.10455507, 0.4031136 , 0.0072762 , 0.05540257],
#        [0.10702834, 0.39931647, 0.0072762 , 0.05666725],
#        [0.10752835, 0.41728008, 0.0099004 , 0.0571971 ],
#        [0.10800892, 0.41056204, 0.01109322, 0.0571971 ],
#        [0.10617883, 0.40764114, 0.00787261, 0.04567182],
#        [0.10246768, 0.39887844, 0.00232601, 0.04608178],
#        [0.09965703, 0.4261888 , 0.00208743, 0.02749436],
#        [0.10167885, 0.43611994, 0.00125246, 0.02762587],
#        [0.10212304, 0.41158429, 0.00155067, 0.03770856],
#        [0.10191914, 0.43816442, 0.        , 0.02728165],
#        [0.10173953, 0.4377264 , 0.00131211, 0.01890069],
#        [0.09892402, 0.42852548, 0.00280313, 0.00363161],
#        [0.1007177 , 0.43378307, 0.00059641, 0.00866329],
#        [0.10003568, 0.41903255, 0.00483092, 0.02257098],
#        [0.10015944, 0.41961677, 0.00214708, 0.01864155],
#        [0.10122014, 0.41771811, 0.0059641 , 0.02582358],
#        [0.10166916, 0.42750324, 0.00644123, 0.03095969],
#        [0.10595069, 0.42823346, 0.00805153, 0.02493405],
#        [0.1064094 , 0.42735723, 0.00805153, 0.02493405]]), array([0.03748423]))

# %% [markdown]
# ## 3. Build a model

# %%
class LinearEmbedding(nn.Module):
    def __init__(self, dropout, d_model):
        '''
        data: [batch_size, seq_len, 1]
        In this model, only kospi input window
        '''
        super().__init__()
        self.d_model = d_model
        self.linear1 = nn.Linear(1, d_model//2)
        self.linear2 = nn.Linear(d_model//2, d_model)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=dropout)
    
    def forward(self, x):
        '''
        input: [batch_size, seq_len, 1]
        output: [batch_size, seq_len, d_model]
        '''
        x = self.linear1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear2(x)
        x = self.relu(x)
        return x

# %%
class lstm_encoder(nn.Module):
    def __init__(self, in_ch, input_size, hidden_size, dropout, num_layers=1):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.droptout = dropout

        self.conv1d_1 = nn.Conv1d(in_channels=in_ch, out_channels=input_size//2, kernel_size=3, padding=1)
        self.conv1d_2 = nn.Conv1d(in_channels=input_size//2, out_channels=input_size//2, kernel_size=3, padding=1)
        self.conv1d_3 = nn.Conv1d(in_channels=input_size//2, out_channels=input_size, kernel_size=3, padding=1)
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        # self.emb = LinearEmbedding(dropout, input_size)
        self.linear1 = nn.Linear(hidden_size, hidden_size//2)
        self.linear2 = nn.Linear(hidden_size//2, 1)
        self.dropout = nn.Dropout(p=dropout)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        # x = self.emb(x)
        # [Batch_size, sel_len, ch]
        # print('start:', x.size())
        x = x.transpose(1, 2).contiguous()  # [batch_size, ch, sel_len]
        # print('transpose:',x.size())
        x = self.conv1d_1(x)
        x = self.conv1d_2(x)
        x = self.conv1d_3(x)
        x = x.transpose(1, 2).contiguous()
        # print('after conv1d:',x.size())
        
        lstm_out, self.hidden = self.lstm(x)
        # print(lstm_out[:, -1, :].size())
        x = self.linear1(lstm_out[:, -1, :])
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear2(x)
        x = self.relu(x)
        # print(x.size())
        return x

# %% [markdown]
# ## 4. Model, loss_fn, optimizer

# %%
batch_size, seq_len, input_dim = next(iter(train_dataloader))[0].size()
print(batch_size, seq_len, input_dim)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model_d = 64
dropout = 0.2
n_hidden = 256
n_layers = 1
in_ch = 4
lr = 2e-4
lr_sched = True
# Out:
# 64 128 4

# %%
model = lstm_encoder(in_ch, model_d, n_hidden, dropout, n_layers).to(device)
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=lr)
if lr_sched == True:
    # scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer=optimizer,
    #                                     lr_lambda=lambda epoch: 0.95 ** epoch,
    #                                     last_epoch=-1,
    #                                     verbose=False)
    # scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)

# %% [markdown]
# ## 5. Train and Test

# %%
in_x, in_y = next(iter(train_dataloader))
in_x = in_x.to(device).float()
out = model(in_x)
print(out.size())
print(in_y.shape)
print(in_y.contiguous().view(-1).shape)
# Out:
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64])

# %%
epochs = 1000
loss_np = np.zeros((epochs, 2))
df_loss = pd.DataFrame(loss_np, columns=['epoch', 'loss'])
for i in range(epochs):
    epoch_loss = 0
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device).float()
        labels = labels.squeeze(1).to(device)

        optimizer.zero_grad()
        output = model(inputs)
        loss = loss_fn(output.view(-1).float(), labels.float())
        # print(loss)
        loss.backward()
        # torch.nn.utils.clip_grad_norm(model.parameters(), 0.5)  # when using scheduler, it is not for grad exploding
        optimizer.step()

        epoch_loss += loss.item()
    
    print(f'epochs: {i}, loss: {epoch_loss:.6f}, lr: ', round(optimizer.param_groups[0]['lr'], 8))
    if lr_sched == True:
        scheduler.step()
    df_loss.loc[i, :] = [i, epoch_loss]
# Out:
# epochs: 0, loss: 2.994948, lr:  0.0002
# epochs: 1, loss: 0.381952, lr:  0.0002
# epochs: 2, loss: 0.264281, lr:  0.0002
# epochs: 3, loss: 0.188859, lr:  0.0002
# epochs: 4, loss: 0.129203, lr:  0.0002
# epochs: 5, loss: 0.115633, lr:  0.0002
# epochs: 6, loss: 0.112338, lr:  0.0002
# epochs: 7, loss: 0.117962, lr:  0.0002
# epochs: 8, loss: 0.117417, lr:  0.0002
# epochs: 9, loss: 0.112260, lr:  0.0002
# epochs: 10, loss: 0.113501, lr:  0.0002
# epochs: 11, loss: 0.114879, lr:  0.0002
# epochs: 12, loss: 0.107393, lr:  0.0002
# epochs: 13, loss: 0.109750, lr:  0.0002
# epochs: 14, loss: 0.109480, lr:  0.0002
# epochs: 15, loss: 0.103486, lr:  0.0002
# epochs: 16, loss: 0.103883, lr:  0.0002
# epochs: 17, loss: 0.105275, lr:  0.0002
# epochs: 18, loss: 0.108031, lr:  0.0002
# epochs: 19, loss: 0.108796, lr:  0.0002
# epochs: 20, loss: 0.099297, lr:  0.0002
# epochs: 21, loss: 0.105313, lr:  0.0002
# epochs: 22, loss: 0.099357, lr:  0.0002
# epochs: 23, loss: 0.098578, lr:  0.0002
# epochs: 24, loss: 0.098334, lr:  0.0002
# epochs: 25, loss: 0.101903, lr:  0.0002
# epochs: 26, loss: 0.093355, lr:  0.0002
# epochs: 27, loss: 0.096906, lr:  0.0002
# epochs: 28, loss: 0.101692, lr:  0.0002
# epochs: 29, loss: 0.100418, lr:  0.0002
# epochs: 30, loss: 0.097785, lr:  0.0002
# epochs: 31, loss: 0.090270, lr:  0.0002
# epochs: 32, loss: 0.095049, lr:  0.0002
# epochs: 33, loss: 0.087721, lr:  0.0002
# epochs: 34, loss: 0.090521, lr:  0.0002
# epochs: 35, loss: 0.092636, lr:  0.0002
# epochs: 36, loss: 0.088985, lr:  0.0002
# epochs: 37, loss: 0.095587, lr:  0.0002
# epochs: 38, loss: 0.082968, lr:  0.0002
# epochs: 39, loss: 0.087155, lr:  0.0002
# epochs: 40, loss: 0.087975, lr:  0.0002
# epochs: 41, loss: 0.088926, lr:  0.0002
# epochs: 42, loss: 0.086370, lr:  0.0002
# epochs: 43, loss: 0.087071, lr:  0.0002
# epochs: 44, loss: 0.075261, lr:  0.0002
# epochs: 45, loss: 0.078608, lr:  0.0002
# epochs: 46, loss: 0.085312, lr:  0.0002
# epochs: 47, loss: 0.078282, lr:  0.0002
# epochs: 48, loss: 0.077982, lr:  0.0002
# epochs: 49, loss: 0.083008, lr:  0.0002
# epochs: 50, loss: 0.080876, lr:  0.0002
# epochs: 51, loss: 0.074243, lr:  0.0002
# epochs: 52, loss: 0.077383, lr:  0.0002
# epochs: 53, loss: 0.077778, lr:  0.0002
# epochs: 54, loss: 0.083416, lr:  0.0002
# epochs: 55, loss: 0.081993, lr:  0.0002
# epochs: 56, loss: 0.072850, lr:  0.0002
# epochs: 57, loss: 0.074931, lr:  0.0002
# epochs: 58, loss: 0.077704, lr:  0.0002
# epochs: 59, loss: 0.068693, lr:  0.0002
# epochs: 60, loss: 0.070836, lr:  0.0002
# epochs: 61, loss: 0.066644, lr:  0.0002
# epochs: 62, loss: 0.070087, lr:  0.0002
# epochs: 63, loss: 0.070642, lr:  0.0002
# epochs: 64, loss: 0.068778, lr:  0.0002
# epochs: 65, loss: 0.068510, lr:  0.0002
# epochs: 66, loss: 0.066333, lr:  0.0002
# epochs: 67, loss: 0.066800, lr:  0.0002
# epochs: 68, loss: 0.065996, lr:  0.0002
# epochs: 69, loss: 0.063302, lr:  0.0002
# epochs: 70, loss: 0.064738, lr:  0.0002
# epochs: 71, loss: 0.060853, lr:  0.0002
# epochs: 72, loss: 0.060703, lr:  0.0002
# epochs: 73, loss: 0.059631, lr:  0.0002
# epochs: 74, loss: 0.062490, lr:  0.0002
# epochs: 75, loss: 0.061730, lr:  0.0002
# epochs: 76, loss: 0.062618, lr:  0.0002
# epochs: 77, loss: 0.057718, lr:  0.0002
# epochs: 78, loss: 0.059993, lr:  0.0002
# epochs: 79, loss: 0.056501, lr:  0.0002
# epochs: 80, loss: 0.054337, lr:  0.0002
# epochs: 81, loss: 0.058179, lr:  0.0002
# epochs: 82, loss: 0.057956, lr:  0.0002
# epochs: 83, loss: 0.053067, lr:  0.0002
# epochs: 84, loss: 0.053712, lr:  0.0002
# epochs: 85, loss: 0.059488, lr:  0.0002
# epochs: 86, loss: 0.056639, lr:  0.0002
# epochs: 87, loss: 0.052773, lr:  0.0002
# epochs: 88, loss: 0.057807, lr:  0.0002
# epochs: 89, loss: 0.052054, lr:  0.0002
# epochs: 90, loss: 0.052925, lr:  0.0002
# epochs: 91, loss: 0.055135, lr:  0.0002
# epochs: 92, loss: 0.050551, lr:  0.0002
# epochs: 93, loss: 0.049361, lr:  0.0002
# epochs: 94, loss: 0.048887, lr:  0.0002
# epochs: 95, loss: 0.049855, lr:  0.0002
# epochs: 96, loss: 0.051347, lr:  0.0002
# epochs: 97, loss: 0.047149, lr:  0.0002
# epochs: 98, loss: 0.049262, lr:  0.0002
# epochs: 99, loss: 0.047065, lr:  0.0002
# epochs: 100, loss: 0.044323, lr:  0.0001
# epochs: 101, loss: 0.048077, lr:  0.0001
# epochs: 102, loss: 0.046169, lr:  0.0001
# epochs: 103, loss: 0.044985, lr:  0.0001
# epochs: 104, loss: 0.042215, lr:  0.0001
# epochs: 105, loss: 0.043876, lr:  0.0001
# epochs: 106, loss: 0.046141, lr:  0.0001
# epochs: 107, loss: 0.044161, lr:  0.0001
# epochs: 108, loss: 0.042680, lr:  0.0001
# epochs: 109, loss: 0.044322, lr:  0.0001
# epochs: 110, loss: 0.043454, lr:  0.0001
# epochs: 111, loss: 0.044010, lr:  0.0001
# epochs: 112, loss: 0.042003, lr:  0.0001
# epochs: 113, loss: 0.043754, lr:  0.0001
# epochs: 114, loss: 0.042719, lr:  0.0001
# epochs: 115, loss: 0.041971, lr:  0.0001
# epochs: 116, loss: 0.041566, lr:  0.0001
# epochs: 117, loss: 0.043480, lr:  0.0001
# epochs: 118, loss: 0.042884, lr:  0.0001
# epochs: 119, loss: 0.043472, lr:  0.0001
# epochs: 120, loss: 0.040288, lr:  0.0001
# epochs: 121, loss: 0.041747, lr:  0.0001
# epochs: 122, loss: 0.040054, lr:  0.0001
# epochs: 123, loss: 0.042148, lr:  0.0001
# epochs: 124, loss: 0.041755, lr:  0.0001
# epochs: 125, loss: 0.040820, lr:  0.0001
# epochs: 126, loss: 0.041019, lr:  0.0001
# epochs: 127, loss: 0.038646, lr:  0.0001
# epochs: 128, loss: 0.038584, lr:  0.0001
# epochs: 129, loss: 0.040275, lr:  0.0001
# epochs: 130, loss: 0.041716, lr:  0.0001
# epochs: 131, loss: 0.038479, lr:  0.0001
# epochs: 132, loss: 0.038329, lr:  0.0001
# epochs: 133, loss: 0.038349, lr:  0.0001
# epochs: 134, loss: 0.038150, lr:  0.0001
# epochs: 135, loss: 0.041196, lr:  0.0001
# epochs: 136, loss: 0.039435, lr:  0.0001
# epochs: 137, loss: 0.039355, lr:  0.0001
# epochs: 138, loss: 0.038029, lr:  0.0001
# epochs: 139, loss: 0.038109, lr:  0.0001
# epochs: 140, loss: 0.036584, lr:  0.0001
# epochs: 141, loss: 0.037812, lr:  0.0001
# epochs: 142, loss: 0.040408, lr:  0.0001
# epochs: 143, loss: 0.037724, lr:  0.0001
# epochs: 144, loss: 0.036585, lr:  0.0001
# epochs: 145, loss: 0.037319, lr:  0.0001
# epochs: 146, loss: 0.037494, lr:  0.0001
# epochs: 147, loss: 0.039126, lr:  0.0001
# epochs: 148, loss: 0.038903, lr:  0.0001
# epochs: 149, loss: 0.038310, lr:  0.0001
# epochs: 150, loss: 0.037927, lr:  0.0001
# epochs: 151, loss: 0.035622, lr:  0.0001
# epochs: 152, loss: 0.038199, lr:  0.0001
# epochs: 153, loss: 0.036252, lr:  0.0001
# epochs: 154, loss: 0.034123, lr:  0.0001
# epochs: 155, loss: 0.035764, lr:  0.0001
# epochs: 156, loss: 0.036675, lr:  0.0001
# epochs: 157, loss: 0.036615, lr:  0.0001
# epochs: 158, loss: 0.035675, lr:  0.0001
# epochs: 159, loss: 0.034437, lr:  0.0001
# epochs: 160, loss: 0.035236, lr:  0.0001
# epochs: 161, loss: 0.034473, lr:  0.0001
# epochs: 162, loss: 0.035980, lr:  0.0001
# epochs: 163, loss: 0.033763, lr:  0.0001
# epochs: 164, loss: 0.033970, lr:  0.0001
# epochs: 165, loss: 0.033826, lr:  0.0001
# epochs: 166, loss: 0.033854, lr:  0.0001
# epochs: 167, loss: 0.033215, lr:  0.0001
# epochs: 168, loss: 0.034827, lr:  0.0001
# epochs: 169, loss: 0.034055, lr:  0.0001
# epochs: 170, loss: 0.034393, lr:  0.0001
# epochs: 171, loss: 0.034521, lr:  0.0001
# epochs: 172, loss: 0.034553, lr:  0.0001
# epochs: 173, loss: 0.033979, lr:  0.0001
# epochs: 174, loss: 0.033359, lr:  0.0001
# epochs: 175, loss: 0.032835, lr:  0.0001
# epochs: 176, loss: 0.036093, lr:  0.0001
# epochs: 177, loss: 0.033792, lr:  0.0001
# epochs: 178, loss: 0.033860, lr:  0.0001
# epochs: 179, loss: 0.032477, lr:  0.0001
# epochs: 180, loss: 0.034995, lr:  0.0001
# epochs: 181, loss: 0.033385, lr:  0.0001
# epochs: 182, loss: 0.033274, lr:  0.0001
# epochs: 183, loss: 0.032083, lr:  0.0001
# epochs: 184, loss: 0.033561, lr:  0.0001
# epochs: 185, loss: 0.033263, lr:  0.0001
# epochs: 186, loss: 0.031905, lr:  0.0001
# epochs: 187, loss: 0.033949, lr:  0.0001
# epochs: 188, loss: 0.032577, lr:  0.0001
# epochs: 189, loss: 0.032585, lr:  0.0001
# epochs: 190, loss: 0.032180, lr:  0.0001
# epochs: 191, loss: 0.032332, lr:  0.0001
# epochs: 192, loss: 0.031227, lr:  0.0001
# epochs: 193, loss: 0.030281, lr:  0.0001
# epochs: 194, loss: 0.030717, lr:  0.0001
# epochs: 195, loss: 0.031713, lr:  0.0001
# epochs: 196, loss: 0.032993, lr:  0.0001
# epochs: 197, loss: 0.032364, lr:  0.0001
# epochs: 198, loss: 0.032553, lr:  0.0001
# epochs: 199, loss: 0.031855, lr:  0.0001
# epochs: 200, loss: 0.031486, lr:  5e-05
# epochs: 201, loss: 0.030138, lr:  5e-05
# epochs: 202, loss: 0.030549, lr:  5e-05
# epochs: 203, loss: 0.030793, lr:  5e-05
# epochs: 204, loss: 0.032043, lr:  5e-05
# epochs: 205, loss: 0.030183, lr:  5e-05
# epochs: 206, loss: 0.029995, lr:  5e-05
# epochs: 207, loss: 0.030662, lr:  5e-05
# epochs: 208, loss: 0.030966, lr:  5e-05
# epochs: 209, loss: 0.029351, lr:  5e-05
# epochs: 210, loss: 0.031071, lr:  5e-05
# epochs: 211, loss: 0.030386, lr:  5e-05
# epochs: 212, loss: 0.031373, lr:  5e-05
# epochs: 213, loss: 0.029387, lr:  5e-05
# epochs: 214, loss: 0.030999, lr:  5e-05
# epochs: 215, loss: 0.029255, lr:  5e-05
# epochs: 216, loss: 0.029873, lr:  5e-05
# epochs: 217, loss: 0.030276, lr:  5e-05
# epochs: 218, loss: 0.030080, lr:  5e-05
# epochs: 219, loss: 0.029686, lr:  5e-05
# epochs: 220, loss: 0.031377, lr:  5e-05
# epochs: 221, loss: 0.030514, lr:  5e-05
# epochs: 222, loss: 0.029736, lr:  5e-05
# epochs: 223, loss: 0.028823, lr:  5e-05
# epochs: 224, loss: 0.031391, lr:  5e-05
# epochs: 225, loss: 0.029379, lr:  5e-05
# epochs: 226, loss: 0.030682, lr:  5e-05
# epochs: 227, loss: 0.029765, lr:  5e-05
# epochs: 228, loss: 0.030381, lr:  5e-05
# epochs: 229, loss: 0.029714, lr:  5e-05
# epochs: 230, loss: 0.029196, lr:  5e-05
# epochs: 231, loss: 0.028859, lr:  5e-05
# epochs: 232, loss: 0.027552, lr:  5e-05
# epochs: 233, loss: 0.028763, lr:  5e-05
# epochs: 234, loss: 0.030694, lr:  5e-05
# epochs: 235, loss: 0.030095, lr:  5e-05
# epochs: 236, loss: 0.028645, lr:  5e-05
# epochs: 237, loss: 0.030014, lr:  5e-05
# epochs: 238, loss: 0.031192, lr:  5e-05
# epochs: 239, loss: 0.029498, lr:  5e-05
# epochs: 240, loss: 0.028011, lr:  5e-05
# epochs: 241, loss: 0.030368, lr:  5e-05
# epochs: 242, loss: 0.029661, lr:  5e-05
# epochs: 243, loss: 0.028101, lr:  5e-05
# epochs: 244, loss: 0.029782, lr:  5e-05
# epochs: 245, loss: 0.028259, lr:  5e-05
# epochs: 246, loss: 0.029278, lr:  5e-05
# epochs: 247, loss: 0.030238, lr:  5e-05
# epochs: 248, loss: 0.029487, lr:  5e-05
# epochs: 249, loss: 0.029304, lr:  5e-05
# epochs: 250, loss: 0.029996, lr:  5e-05
# epochs: 251, loss: 0.028433, lr:  5e-05
# epochs: 252, loss: 0.029123, lr:  5e-05
# epochs: 253, loss: 0.030277, lr:  5e-05
# epochs: 254, loss: 0.029369, lr:  5e-05
# epochs: 255, loss: 0.029002, lr:  5e-05
# epochs: 256, loss: 0.027517, lr:  5e-05
# epochs: 257, loss: 0.028692, lr:  5e-05
# epochs: 258, loss: 0.028898, lr:  5e-05
# epochs: 259, loss: 0.029366, lr:  5e-05
# epochs: 260, loss: 0.029355, lr:  5e-05
# epochs: 261, loss: 0.029430, lr:  5e-05
# epochs: 262, loss: 0.028400, lr:  5e-05
# epochs: 263, loss: 0.027156, lr:  5e-05
# epochs: 264, loss: 0.028032, lr:  5e-05
# epochs: 265, loss: 0.029577, lr:  5e-05
# epochs: 266, loss: 0.030078, lr:  5e-05
# epochs: 267, loss: 0.027742, lr:  5e-05
# epochs: 268, loss: 0.027540, lr:  5e-05
# epochs: 269, loss: 0.027769, lr:  5e-05
# epochs: 270, loss: 0.028755, lr:  5e-05
# epochs: 271, loss: 0.027602, lr:  5e-05
# epochs: 272, loss: 0.027763, lr:  5e-05
# epochs: 273, loss: 0.028598, lr:  5e-05
# epochs: 274, loss: 0.028440, lr:  5e-05
# epochs: 275, loss: 0.028119, lr:  5e-05
# epochs: 276, loss: 0.028826, lr:  5e-05
# epochs: 277, loss: 0.027165, lr:  5e-05
# epochs: 278, loss: 0.028552, lr:  5e-05
# epochs: 279, loss: 0.028705, lr:  5e-05
# epochs: 280, loss: 0.028972, lr:  5e-05
# epochs: 281, loss: 0.028028, lr:  5e-05
# epochs: 282, loss: 0.029588, lr:  5e-05
# epochs: 283, loss: 0.030340, lr:  5e-05
# epochs: 284, loss: 0.028867, lr:  5e-05
# epochs: 285, loss: 0.027959, lr:  5e-05
# epochs: 286, loss: 0.029407, lr:  5e-05
# epochs: 287, loss: 0.027451, lr:  5e-05
# epochs: 288, loss: 0.027051, lr:  5e-05
# epochs: 289, loss: 0.029020, lr:  5e-05
# epochs: 290, loss: 0.027884, lr:  5e-05
# epochs: 291, loss: 0.028618, lr:  5e-05
# epochs: 292, loss: 0.027047, lr:  5e-05
# epochs: 293, loss: 0.027253, lr:  5e-05
# epochs: 294, loss: 0.029138, lr:  5e-05
# epochs: 295, loss: 0.029248, lr:  5e-05
# epochs: 296, loss: 0.027253, lr:  5e-05
# epochs: 297, loss: 0.027373, lr:  5e-05
# epochs: 298, loss: 0.026128, lr:  5e-05
# epochs: 299, loss: 0.029604, lr:  5e-05
# epochs: 300, loss: 0.027073, lr:  2.5e-05
# epochs: 301, loss: 0.027698, lr:  2.5e-05
# epochs: 302, loss: 0.028387, lr:  2.5e-05
# epochs: 303, loss: 0.026417, lr:  2.5e-05
# epochs: 304, loss: 0.027429, lr:  2.5e-05
# epochs: 305, loss: 0.028663, lr:  2.5e-05
# epochs: 306, loss: 0.028973, lr:  2.5e-05
# epochs: 307, loss: 0.027307, lr:  2.5e-05
# epochs: 308, loss: 0.025952, lr:  2.5e-05
# epochs: 309, loss: 0.027657, lr:  2.5e-05
# epochs: 310, loss: 0.026365, lr:  2.5e-05
# epochs: 311, loss: 0.028080, lr:  2.5e-05
# epochs: 312, loss: 0.027680, lr:  2.5e-05
# epochs: 313, loss: 0.026445, lr:  2.5e-05
# epochs: 314, loss: 0.025849, lr:  2.5e-05
# epochs: 315, loss: 0.027529, lr:  2.5e-05
# epochs: 316, loss: 0.026813, lr:  2.5e-05
# epochs: 317, loss: 0.027194, lr:  2.5e-05
# epochs: 318, loss: 0.027400, lr:  2.5e-05
# epochs: 319, loss: 0.027002, lr:  2.5e-05
# epochs: 320, loss: 0.027866, lr:  2.5e-05
# epochs: 321, loss: 0.027528, lr:  2.5e-05
# epochs: 322, loss: 0.025673, lr:  2.5e-05
# epochs: 323, loss: 0.026056, lr:  2.5e-05
# epochs: 324, loss: 0.026587, lr:  2.5e-05
# epochs: 325, loss: 0.027322, lr:  2.5e-05
# epochs: 326, loss: 0.027872, lr:  2.5e-05
# epochs: 327, loss: 0.026193, lr:  2.5e-05
# epochs: 328, loss: 0.027078, lr:  2.5e-05
# epochs: 329, loss: 0.026550, lr:  2.5e-05
# epochs: 330, loss: 0.026451, lr:  2.5e-05
# epochs: 331, loss: 0.026489, lr:  2.5e-05
# epochs: 332, loss: 0.028005, lr:  2.5e-05
# epochs: 333, loss: 0.027114, lr:  2.5e-05
# epochs: 334, loss: 0.026984, lr:  2.5e-05
# epochs: 335, loss: 0.027526, lr:  2.5e-05
# epochs: 336, loss: 0.026481, lr:  2.5e-05
# epochs: 337, loss: 0.026591, lr:  2.5e-05
# epochs: 338, loss: 0.027911, lr:  2.5e-05
# epochs: 339, loss: 0.027194, lr:  2.5e-05
# epochs: 340, loss: 0.025933, lr:  2.5e-05
# epochs: 341, loss: 0.027226, lr:  2.5e-05
# epochs: 342, loss: 0.026315, lr:  2.5e-05
# epochs: 343, loss: 0.026804, lr:  2.5e-05
# epochs: 344, loss: 0.026491, lr:  2.5e-05
# epochs: 345, loss: 0.026852, lr:  2.5e-05
# epochs: 346, loss: 0.027925, lr:  2.5e-05
# epochs: 347, loss: 0.027314, lr:  2.5e-05
# epochs: 348, loss: 0.026538, lr:  2.5e-05
# epochs: 349, loss: 0.027976, lr:  2.5e-05
# epochs: 350, loss: 0.026874, lr:  2.5e-05
# epochs: 351, loss: 0.027203, lr:  2.5e-05
# epochs: 352, loss: 0.025261, lr:  2.5e-05
# epochs: 353, loss: 0.026675, lr:  2.5e-05
# epochs: 354, loss: 0.026914, lr:  2.5e-05
# epochs: 355, loss: 0.027163, lr:  2.5e-05
# epochs: 356, loss: 0.026900, lr:  2.5e-05
# epochs: 357, loss: 0.026937, lr:  2.5e-05
# epochs: 358, loss: 0.026787, lr:  2.5e-05
# epochs: 359, loss: 0.027391, lr:  2.5e-05
# epochs: 360, loss: 0.027313, lr:  2.5e-05
# epochs: 361, loss: 0.028258, lr:  2.5e-05
# epochs: 362, loss: 0.027216, lr:  2.5e-05
# epochs: 363, loss: 0.027570, lr:  2.5e-05
# epochs: 364, loss: 0.026505, lr:  2.5e-05
# epochs: 365, loss: 0.026488, lr:  2.5e-05
# epochs: 366, loss: 0.027049, lr:  2.5e-05
# epochs: 367, loss: 0.028205, lr:  2.5e-05
# epochs: 368, loss: 0.026775, lr:  2.5e-05
# epochs: 369, loss: 0.028002, lr:  2.5e-05
# epochs: 370, loss: 0.028303, lr:  2.5e-05
# epochs: 371, loss: 0.026010, lr:  2.5e-05
# epochs: 372, loss: 0.026721, lr:  2.5e-05
# epochs: 373, loss: 0.028070, lr:  2.5e-05
# epochs: 374, loss: 0.026721, lr:  2.5e-05
# epochs: 375, loss: 0.026450, lr:  2.5e-05
# epochs: 376, loss: 0.025930, lr:  2.5e-05
# epochs: 377, loss: 0.027443, lr:  2.5e-05
# epochs: 378, loss: 0.027990, lr:  2.5e-05
# epochs: 379, loss: 0.026957, lr:  2.5e-05
# epochs: 380, loss: 0.026617, lr:  2.5e-05
# epochs: 381, loss: 0.025448, lr:  2.5e-05
# epochs: 382, loss: 0.025470, lr:  2.5e-05
# epochs: 383, loss: 0.028358, lr:  2.5e-05
# epochs: 384, loss: 0.027434, lr:  2.5e-05
# epochs: 385, loss: 0.027024, lr:  2.5e-05
# epochs: 386, loss: 0.025992, lr:  2.5e-05
# epochs: 387, loss: 0.027267, lr:  2.5e-05
# epochs: 388, loss: 0.026859, lr:  2.5e-05
# epochs: 389, loss: 0.026945, lr:  2.5e-05
# epochs: 390, loss: 0.026318, lr:  2.5e-05
# epochs: 391, loss: 0.027874, lr:  2.5e-05
# epochs: 392, loss: 0.025606, lr:  2.5e-05
# epochs: 393, loss: 0.025805, lr:  2.5e-05
# epochs: 394, loss: 0.028650, lr:  2.5e-05
# epochs: 395, loss: 0.026094, lr:  2.5e-05
# epochs: 396, loss: 0.026194, lr:  2.5e-05
# epochs: 397, loss: 0.027770, lr:  2.5e-05
# epochs: 398, loss: 0.026990, lr:  2.5e-05
# epochs: 399, loss: 0.026124, lr:  2.5e-05
# epochs: 400, loss: 0.027231, lr:  1.25e-05
# epochs: 401, loss: 0.027074, lr:  1.25e-05
# epochs: 402, loss: 0.026670, lr:  1.25e-05
# epochs: 403, loss: 0.027092, lr:  1.25e-05
# epochs: 404, loss: 0.025302, lr:  1.25e-05
# epochs: 405, loss: 0.025846, lr:  1.25e-05
# epochs: 406, loss: 0.026296, lr:  1.25e-05
# epochs: 407, loss: 0.027453, lr:  1.25e-05
# epochs: 408, loss: 0.025948, lr:  1.25e-05
# epochs: 409, loss: 0.026212, lr:  1.25e-05
# epochs: 410, loss: 0.026973, lr:  1.25e-05
# epochs: 411, loss: 0.025849, lr:  1.25e-05
# epochs: 412, loss: 0.026780, lr:  1.25e-05
# epochs: 413, loss: 0.025439, lr:  1.25e-05
# epochs: 414, loss: 0.026436, lr:  1.25e-05
# epochs: 415, loss: 0.026539, lr:  1.25e-05
# epochs: 416, loss: 0.025732, lr:  1.25e-05
# epochs: 417, loss: 0.026494, lr:  1.25e-05
# epochs: 418, loss: 0.027116, lr:  1.25e-05
# epochs: 419, loss: 0.026060, lr:  1.25e-05
# epochs: 420, loss: 0.026201, lr:  1.25e-05
# epochs: 421, loss: 0.025631, lr:  1.25e-05
# epochs: 422, loss: 0.026532, lr:  1.25e-05
# epochs: 423, loss: 0.026230, lr:  1.25e-05
# epochs: 424, loss: 0.027108, lr:  1.25e-05
# epochs: 425, loss: 0.025876, lr:  1.25e-05
# epochs: 426, loss: 0.026339, lr:  1.25e-05
# epochs: 427, loss: 0.026647, lr:  1.25e-05
# epochs: 428, loss: 0.026609, lr:  1.25e-05
# epochs: 429, loss: 0.026319, lr:  1.25e-05
# epochs: 430, loss: 0.025770, lr:  1.25e-05
# epochs: 431, loss: 0.025569, lr:  1.25e-05
# epochs: 432, loss: 0.027172, lr:  1.25e-05
# epochs: 433, loss: 0.026025, lr:  1.25e-05
# epochs: 434, loss: 0.026256, lr:  1.25e-05
# epochs: 435, loss: 0.026813, lr:  1.25e-05
# epochs: 436, loss: 0.026028, lr:  1.25e-05
# epochs: 437, loss: 0.025242, lr:  1.25e-05
# epochs: 438, loss: 0.026993, lr:  1.25e-05
# epochs: 439, loss: 0.026422, lr:  1.25e-05
# epochs: 440, loss: 0.026310, lr:  1.25e-05
# epochs: 441, loss: 0.025932, lr:  1.25e-05
# epochs: 442, loss: 0.026381, lr:  1.25e-05
# epochs: 443, loss: 0.026974, lr:  1.25e-05
# epochs: 444, loss: 0.026370, lr:  1.25e-05
# epochs: 445, loss: 0.025731, lr:  1.25e-05
# epochs: 446, loss: 0.025201, lr:  1.25e-05
# epochs: 447, loss: 0.026483, lr:  1.25e-05
# epochs: 448, loss: 0.026130, lr:  1.25e-05
# epochs: 449, loss: 0.025776, lr:  1.25e-05
# epochs: 450, loss: 0.025053, lr:  1.25e-05
# epochs: 451, loss: 0.025509, lr:  1.25e-05
# epochs: 452, loss: 0.027516, lr:  1.25e-05
# epochs: 453, loss: 0.025504, lr:  1.25e-05
# epochs: 454, loss: 0.025473, lr:  1.25e-05
# epochs: 455, loss: 0.025448, lr:  1.25e-05
# epochs: 456, loss: 0.025881, lr:  1.25e-05
# epochs: 457, loss: 0.026128, lr:  1.25e-05
# epochs: 458, loss: 0.026810, lr:  1.25e-05
# epochs: 459, loss: 0.027036, lr:  1.25e-05
# epochs: 460, loss: 0.027412, lr:  1.25e-05
# epochs: 461, loss: 0.026606, lr:  1.25e-05
# epochs: 462, loss: 0.025895, lr:  1.25e-05
# epochs: 463, loss: 0.025517, lr:  1.25e-05
# epochs: 464, loss: 0.025711, lr:  1.25e-05
# epochs: 465, loss: 0.024924, lr:  1.25e-05
# epochs: 466, loss: 0.025107, lr:  1.25e-05
# epochs: 467, loss: 0.025172, lr:  1.25e-05
# epochs: 468, loss: 0.027303, lr:  1.25e-05
# epochs: 469, loss: 0.025719, lr:  1.25e-05
# epochs: 470, loss: 0.025974, lr:  1.25e-05
# epochs: 471, loss: 0.026196, lr:  1.25e-05
# epochs: 472, loss: 0.026039, lr:  1.25e-05
# epochs: 473, loss: 0.025075, lr:  1.25e-05
# epochs: 474, loss: 0.024573, lr:  1.25e-05
# epochs: 475, loss: 0.026804, lr:  1.25e-05
# epochs: 476, loss: 0.025397, lr:  1.25e-05
# epochs: 477, loss: 0.026844, lr:  1.25e-05
# epochs: 478, loss: 0.026658, lr:  1.25e-05
# epochs: 479, loss: 0.026069, lr:  1.25e-05
# epochs: 480, loss: 0.026557, lr:  1.25e-05
# epochs: 481, loss: 0.025012, lr:  1.25e-05
# epochs: 482, loss: 0.026372, lr:  1.25e-05
# epochs: 483, loss: 0.027301, lr:  1.25e-05
# epochs: 484, loss: 0.026645, lr:  1.25e-05
# epochs: 485, loss: 0.025372, lr:  1.25e-05
# epochs: 486, loss: 0.026792, lr:  1.25e-05
# epochs: 487, loss: 0.025126, lr:  1.25e-05
# epochs: 488, loss: 0.026171, lr:  1.25e-05
# epochs: 489, loss: 0.026153, lr:  1.25e-05
# epochs: 490, loss: 0.025963, lr:  1.25e-05
# epochs: 491, loss: 0.026587, lr:  1.25e-05
# epochs: 492, loss: 0.025841, lr:  1.25e-05
# epochs: 493, loss: 0.025843, lr:  1.25e-05
# epochs: 494, loss: 0.026621, lr:  1.25e-05
# epochs: 495, loss: 0.025985, lr:  1.25e-05
# epochs: 496, loss: 0.025323, lr:  1.25e-05
# epochs: 497, loss: 0.025670, lr:  1.25e-05
# epochs: 498, loss: 0.026939, lr:  1.25e-05
# epochs: 499, loss: 0.025834, lr:  1.25e-05
# epochs: 500, loss: 0.025762, lr:  6.25e-06
# epochs: 501, loss: 0.024922, lr:  6.25e-06
# epochs: 502, loss: 0.024546, lr:  6.25e-06
# epochs: 503, loss: 0.025045, lr:  6.25e-06
# epochs: 504, loss: 0.026644, lr:  6.25e-06
# epochs: 505, loss: 0.026332, lr:  6.25e-06
# epochs: 506, loss: 0.025843, lr:  6.25e-06
# epochs: 507, loss: 0.026553, lr:  6.25e-06
# epochs: 508, loss: 0.027025, lr:  6.25e-06
# epochs: 509, loss: 0.026210, lr:  6.25e-06
# epochs: 510, loss: 0.025470, lr:  6.25e-06
# epochs: 511, loss: 0.026642, lr:  6.25e-06
# epochs: 512, loss: 0.025465, lr:  6.25e-06
# epochs: 513, loss: 0.025689, lr:  6.25e-06
# epochs: 514, loss: 0.026156, lr:  6.25e-06
# epochs: 515, loss: 0.023447, lr:  6.25e-06
# epochs: 516, loss: 0.026222, lr:  6.25e-06
# epochs: 517, loss: 0.025737, lr:  6.25e-06
# epochs: 518, loss: 0.024932, lr:  6.25e-06
# epochs: 519, loss: 0.026249, lr:  6.25e-06
# epochs: 520, loss: 0.025821, lr:  6.25e-06
# epochs: 521, loss: 0.025309, lr:  6.25e-06
# epochs: 522, loss: 0.025209, lr:  6.25e-06
# epochs: 523, loss: 0.025207, lr:  6.25e-06
# epochs: 524, loss: 0.026061, lr:  6.25e-06
# epochs: 525, loss: 0.025678, lr:  6.25e-06
# epochs: 526, loss: 0.026979, lr:  6.25e-06
# epochs: 527, loss: 0.025728, lr:  6.25e-06
# epochs: 528, loss: 0.025577, lr:  6.25e-06
# epochs: 529, loss: 0.026060, lr:  6.25e-06
# epochs: 530, loss: 0.025615, lr:  6.25e-06
# epochs: 531, loss: 0.023957, lr:  6.25e-06
# epochs: 532, loss: 0.027301, lr:  6.25e-06
# epochs: 533, loss: 0.026309, lr:  6.25e-06
# epochs: 534, loss: 0.025175, lr:  6.25e-06
# epochs: 535, loss: 0.025931, lr:  6.25e-06
# epochs: 536, loss: 0.024552, lr:  6.25e-06
# epochs: 537, loss: 0.024108, lr:  6.25e-06
# epochs: 538, loss: 0.027214, lr:  6.25e-06
# epochs: 539, loss: 0.026376, lr:  6.25e-06
# epochs: 540, loss: 0.025657, lr:  6.25e-06
# epochs: 541, loss: 0.026106, lr:  6.25e-06
# epochs: 542, loss: 0.026905, lr:  6.25e-06
# epochs: 543, loss: 0.024894, lr:  6.25e-06
# epochs: 544, loss: 0.026467, lr:  6.25e-06
# epochs: 545, loss: 0.026380, lr:  6.25e-06
# epochs: 546, loss: 0.025355, lr:  6.25e-06
# epochs: 547, loss: 0.026707, lr:  6.25e-06
# epochs: 548, loss: 0.026774, lr:  6.25e-06
# epochs: 549, loss: 0.026011, lr:  6.25e-06
# epochs: 550, loss: 0.025160, lr:  6.25e-06
# epochs: 551, loss: 0.025104, lr:  6.25e-06
# epochs: 552, loss: 0.026149, lr:  6.25e-06
# epochs: 553, loss: 0.026443, lr:  6.25e-06
# epochs: 554, loss: 0.026223, lr:  6.25e-06
# epochs: 555, loss: 0.025799, lr:  6.25e-06
# epochs: 556, loss: 0.027143, lr:  6.25e-06
# epochs: 557, loss: 0.025962, lr:  6.25e-06
# epochs: 558, loss: 0.026093, lr:  6.25e-06
# epochs: 559, loss: 0.025394, lr:  6.25e-06
# epochs: 560, loss: 0.024769, lr:  6.25e-06
# epochs: 561, loss: 0.026029, lr:  6.25e-06
# epochs: 562, loss: 0.025413, lr:  6.25e-06
# epochs: 563, loss: 0.025765, lr:  6.25e-06
# epochs: 564, loss: 0.025115, lr:  6.25e-06
# epochs: 565, loss: 0.026470, lr:  6.25e-06
# epochs: 566, loss: 0.025449, lr:  6.25e-06
# epochs: 567, loss: 0.026806, lr:  6.25e-06
# epochs: 568, loss: 0.026216, lr:  6.25e-06
# epochs: 569, loss: 0.026265, lr:  6.25e-06
# epochs: 570, loss: 0.025048, lr:  6.25e-06
# epochs: 571, loss: 0.025998, lr:  6.25e-06
# epochs: 572, loss: 0.025151, lr:  6.25e-06
# epochs: 573, loss: 0.025288, lr:  6.25e-06
# epochs: 574, loss: 0.025792, lr:  6.25e-06
# epochs: 575, loss: 0.026516, lr:  6.25e-06
# epochs: 576, loss: 0.025767, lr:  6.25e-06
# epochs: 577, loss: 0.026835, lr:  6.25e-06
# epochs: 578, loss: 0.027117, lr:  6.25e-06
# epochs: 579, loss: 0.025035, lr:  6.25e-06
# epochs: 580, loss: 0.025720, lr:  6.25e-06
# epochs: 581, loss: 0.026161, lr:  6.25e-06
# epochs: 582, loss: 0.026868, lr:  6.25e-06
# epochs: 583, loss: 0.025337, lr:  6.25e-06
# epochs: 584, loss: 0.024497, lr:  6.25e-06
# epochs: 585, loss: 0.024279, lr:  6.25e-06
# epochs: 586, loss: 0.025051, lr:  6.25e-06
# epochs: 587, loss: 0.026598, lr:  6.25e-06
# epochs: 588, loss: 0.027277, lr:  6.25e-06
# epochs: 589, loss: 0.025717, lr:  6.25e-06
# epochs: 590, loss: 0.025303, lr:  6.25e-06
# epochs: 591, loss: 0.026834, lr:  6.25e-06
# epochs: 592, loss: 0.025342, lr:  6.25e-06
# epochs: 593, loss: 0.025523, lr:  6.25e-06
# epochs: 594, loss: 0.026897, lr:  6.25e-06
# epochs: 595, loss: 0.026557, lr:  6.25e-06
# epochs: 596, loss: 0.026365, lr:  6.25e-06
# epochs: 597, loss: 0.025809, lr:  6.25e-06
# epochs: 598, loss: 0.026539, lr:  6.25e-06
# epochs: 599, loss: 0.025516, lr:  6.25e-06
# epochs: 600, loss: 0.026065, lr:  3.13e-06
# epochs: 601, loss: 0.024256, lr:  3.13e-06
# epochs: 602, loss: 0.026296, lr:  3.13e-06
# epochs: 603, loss: 0.025945, lr:  3.13e-06
# epochs: 604, loss: 0.025924, lr:  3.13e-06
# epochs: 605, loss: 0.026498, lr:  3.13e-06
# epochs: 606, loss: 0.026899, lr:  3.13e-06
# epochs: 607, loss: 0.025712, lr:  3.13e-06
# epochs: 608, loss: 0.025538, lr:  3.13e-06
# epochs: 609, loss: 0.025654, lr:  3.13e-06
# epochs: 610, loss: 0.025872, lr:  3.13e-06
# epochs: 611, loss: 0.025588, lr:  3.13e-06
# epochs: 612, loss: 0.025609, lr:  3.13e-06
# epochs: 613, loss: 0.025694, lr:  3.13e-06
# epochs: 614, loss: 0.027315, lr:  3.13e-06
# epochs: 615, loss: 0.025103, lr:  3.13e-06
# epochs: 616, loss: 0.025865, lr:  3.13e-06
# epochs: 617, loss: 0.025743, lr:  3.13e-06
# epochs: 618, loss: 0.025643, lr:  3.13e-06
# epochs: 619, loss: 0.026351, lr:  3.13e-06
# epochs: 620, loss: 0.026536, lr:  3.13e-06
# epochs: 621, loss: 0.026310, lr:  3.13e-06
# epochs: 622, loss: 0.024828, lr:  3.13e-06
# epochs: 623, loss: 0.025645, lr:  3.13e-06
# epochs: 624, loss: 0.025480, lr:  3.13e-06
# epochs: 625, loss: 0.025636, lr:  3.13e-06
# epochs: 626, loss: 0.023970, lr:  3.13e-06
# epochs: 627, loss: 0.026683, lr:  3.13e-06
# epochs: 628, loss: 0.027020, lr:  3.13e-06
# epochs: 629, loss: 0.026010, lr:  3.13e-06
# epochs: 630, loss: 0.025302, lr:  3.13e-06
# epochs: 631, loss: 0.026875, lr:  3.13e-06
# epochs: 632, loss: 0.026269, lr:  3.13e-06
# epochs: 633, loss: 0.025428, lr:  3.13e-06
# epochs: 634, loss: 0.025780, lr:  3.13e-06
# epochs: 635, loss: 0.026238, lr:  3.13e-06
# epochs: 636, loss: 0.025053, lr:  3.13e-06
# epochs: 637, loss: 0.025957, lr:  3.13e-06
# epochs: 638, loss: 0.026232, lr:  3.13e-06
# epochs: 639, loss: 0.026257, lr:  3.13e-06
# epochs: 640, loss: 0.026711, lr:  3.13e-06
# epochs: 641, loss: 0.026184, lr:  3.13e-06
# epochs: 642, loss: 0.024936, lr:  3.13e-06
# epochs: 643, loss: 0.025833, lr:  3.13e-06
# epochs: 644, loss: 0.025376, lr:  3.13e-06
# epochs: 645, loss: 0.025516, lr:  3.13e-06
# epochs: 646, loss: 0.025506, lr:  3.13e-06
# epochs: 647, loss: 0.026255, lr:  3.13e-06
# epochs: 648, loss: 0.025267, lr:  3.13e-06
# epochs: 649, loss: 0.026428, lr:  3.13e-06
# epochs: 650, loss: 0.026139, lr:  3.13e-06
# epochs: 651, loss: 0.025822, lr:  3.13e-06
# epochs: 652, loss: 0.026570, lr:  3.13e-06
# epochs: 653, loss: 0.024854, lr:  3.13e-06
# epochs: 654, loss: 0.025638, lr:  3.13e-06
# epochs: 655, loss: 0.025268, lr:  3.13e-06
# epochs: 656, loss: 0.026370, lr:  3.13e-06
# epochs: 657, loss: 0.025722, lr:  3.13e-06
# epochs: 658, loss: 0.027087, lr:  3.13e-06
# epochs: 659, loss: 0.024957, lr:  3.13e-06
# epochs: 660, loss: 0.025728, lr:  3.13e-06
# epochs: 661, loss: 0.024040, lr:  3.13e-06
# epochs: 662, loss: 0.025124, lr:  3.13e-06
# epochs: 663, loss: 0.025308, lr:  3.13e-06
# epochs: 664, loss: 0.024683, lr:  3.13e-06
# epochs: 665, loss: 0.025930, lr:  3.13e-06
# epochs: 666, loss: 0.025736, lr:  3.13e-06
# epochs: 667, loss: 0.026532, lr:  3.13e-06
# epochs: 668, loss: 0.025257, lr:  3.13e-06
# epochs: 669, loss: 0.026398, lr:  3.13e-06
# epochs: 670, loss: 0.025177, lr:  3.13e-06
# epochs: 671, loss: 0.024960, lr:  3.13e-06
# epochs: 672, loss: 0.025385, lr:  3.13e-06
# epochs: 673, loss: 0.025818, lr:  3.13e-06
# epochs: 674, loss: 0.025722, lr:  3.13e-06
# epochs: 675, loss: 0.026656, lr:  3.13e-06
# epochs: 676, loss: 0.026190, lr:  3.13e-06
# epochs: 677, loss: 0.025564, lr:  3.13e-06
# epochs: 678, loss: 0.025925, lr:  3.13e-06
# epochs: 679, loss: 0.026060, lr:  3.13e-06
# epochs: 680, loss: 0.026451, lr:  3.13e-06
# epochs: 681, loss: 0.024823, lr:  3.13e-06
# epochs: 682, loss: 0.026677, lr:  3.13e-06
# epochs: 683, loss: 0.026889, lr:  3.13e-06
# epochs: 684, loss: 0.025883, lr:  3.13e-06
# epochs: 685, loss: 0.026633, lr:  3.13e-06
# epochs: 686, loss: 0.025995, lr:  3.13e-06
# epochs: 687, loss: 0.024927, lr:  3.13e-06
# epochs: 688, loss: 0.025617, lr:  3.13e-06
# epochs: 689, loss: 0.026290, lr:  3.13e-06
# epochs: 690, loss: 0.026078, lr:  3.13e-06
# epochs: 691, loss: 0.026410, lr:  3.13e-06
# epochs: 692, loss: 0.026231, lr:  3.13e-06
# epochs: 693, loss: 0.026840, lr:  3.13e-06
# epochs: 694, loss: 0.025399, lr:  3.13e-06
# epochs: 695, loss: 0.025906, lr:  3.13e-06
# epochs: 696, loss: 0.025873, lr:  3.13e-06
# epochs: 697, loss: 0.025072, lr:  3.13e-06
# epochs: 698, loss: 0.025565, lr:  3.13e-06
# epochs: 699, loss: 0.025780, lr:  3.13e-06
# epochs: 700, loss: 0.025286, lr:  1.56e-06
# epochs: 701, loss: 0.024826, lr:  1.56e-06
# epochs: 702, loss: 0.025958, lr:  1.56e-06
# epochs: 703, loss: 0.024450, lr:  1.56e-06
# epochs: 704, loss: 0.025647, lr:  1.56e-06
# epochs: 705, loss: 0.025362, lr:  1.56e-06
# epochs: 706, loss: 0.025546, lr:  1.56e-06
# epochs: 707, loss: 0.026384, lr:  1.56e-06
# epochs: 708, loss: 0.027490, lr:  1.56e-06
# epochs: 709, loss: 0.025811, lr:  1.56e-06
# epochs: 710, loss: 0.025884, lr:  1.56e-06
# epochs: 711, loss: 0.026148, lr:  1.56e-06
# epochs: 712, loss: 0.025213, lr:  1.56e-06
# epochs: 713, loss: 0.026217, lr:  1.56e-06
# epochs: 714, loss: 0.024579, lr:  1.56e-06
# epochs: 715, loss: 0.025103, lr:  1.56e-06
# epochs: 716, loss: 0.025399, lr:  1.56e-06
# epochs: 717, loss: 0.025837, lr:  1.56e-06
# epochs: 718, loss: 0.025474, lr:  1.56e-06
# epochs: 719, loss: 0.025444, lr:  1.56e-06
# epochs: 720, loss: 0.025854, lr:  1.56e-06
# epochs: 721, loss: 0.025377, lr:  1.56e-06
# epochs: 722, loss: 0.025371, lr:  1.56e-06
# epochs: 723, loss: 0.025304, lr:  1.56e-06
# epochs: 724, loss: 0.026302, lr:  1.56e-06
# epochs: 725, loss: 0.024855, lr:  1.56e-06
# epochs: 726, loss: 0.023452, lr:  1.56e-06
# epochs: 727, loss: 0.025696, lr:  1.56e-06
# epochs: 728, loss: 0.024681, lr:  1.56e-06
# epochs: 729, loss: 0.026041, lr:  1.56e-06
# epochs: 730, loss: 0.025566, lr:  1.56e-06
# epochs: 731, loss: 0.024672, lr:  1.56e-06
# epochs: 732, loss: 0.026119, lr:  1.56e-06
# epochs: 733, loss: 0.026082, lr:  1.56e-06
# epochs: 734, loss: 0.026036, lr:  1.56e-06
# epochs: 735, loss: 0.026262, lr:  1.56e-06
# epochs: 736, loss: 0.025688, lr:  1.56e-06
# epochs: 737, loss: 0.025391, lr:  1.56e-06
# epochs: 738, loss: 0.025727, lr:  1.56e-06
# epochs: 739, loss: 0.025793, lr:  1.56e-06
# epochs: 740, loss: 0.023413, lr:  1.56e-06
# epochs: 741, loss: 0.024708, lr:  1.56e-06
# epochs: 742, loss: 0.027701, lr:  1.56e-06
# epochs: 743, loss: 0.027109, lr:  1.56e-06
# epochs: 744, loss: 0.026035, lr:  1.56e-06
# epochs: 745, loss: 0.026164, lr:  1.56e-06
# epochs: 746, loss: 0.026510, lr:  1.56e-06
# epochs: 747, loss: 0.025233, lr:  1.56e-06
# epochs: 748, loss: 0.025198, lr:  1.56e-06
# epochs: 749, loss: 0.025614, lr:  1.56e-06
# epochs: 750, loss: 0.024940, lr:  1.56e-06
# epochs: 751, loss: 0.026670, lr:  1.56e-06
# epochs: 752, loss: 0.025968, lr:  1.56e-06
# epochs: 753, loss: 0.025375, lr:  1.56e-06
# epochs: 754, loss: 0.027048, lr:  1.56e-06
# epochs: 755, loss: 0.025456, lr:  1.56e-06
# epochs: 756, loss: 0.025644, lr:  1.56e-06
# epochs: 757, loss: 0.026463, lr:  1.56e-06
# epochs: 758, loss: 0.024985, lr:  1.56e-06
# epochs: 759, loss: 0.025754, lr:  1.56e-06
# epochs: 760, loss: 0.025651, lr:  1.56e-06
# epochs: 761, loss: 0.026135, lr:  1.56e-06
# epochs: 762, loss: 0.026405, lr:  1.56e-06
# epochs: 763, loss: 0.024976, lr:  1.56e-06
# epochs: 764, loss: 0.026497, lr:  1.56e-06
# epochs: 765, loss: 0.024557, lr:  1.56e-06
# epochs: 766, loss: 0.026667, lr:  1.56e-06
# epochs: 767, loss: 0.025737, lr:  1.56e-06
# epochs: 768, loss: 0.024569, lr:  1.56e-06
# epochs: 769, loss: 0.025200, lr:  1.56e-06
# epochs: 770, loss: 0.026273, lr:  1.56e-06
# epochs: 771, loss: 0.026645, lr:  1.56e-06
# epochs: 772, loss: 0.024871, lr:  1.56e-06
# epochs: 773, loss: 0.025418, lr:  1.56e-06
# epochs: 774, loss: 0.025725, lr:  1.56e-06
# epochs: 775, loss: 0.026866, lr:  1.56e-06
# epochs: 776, loss: 0.025660, lr:  1.56e-06
# epochs: 777, loss: 0.025967, lr:  1.56e-06
# epochs: 778, loss: 0.026538, lr:  1.56e-06
# epochs: 779, loss: 0.025913, lr:  1.56e-06
# epochs: 780, loss: 0.025273, lr:  1.56e-06
# epochs: 781, loss: 0.026068, lr:  1.56e-06
# epochs: 782, loss: 0.026253, lr:  1.56e-06
# epochs: 783, loss: 0.025499, lr:  1.56e-06
# epochs: 784, loss: 0.026174, lr:  1.56e-06
# epochs: 785, loss: 0.024871, lr:  1.56e-06
# epochs: 786, loss: 0.026047, lr:  1.56e-06
# epochs: 787, loss: 0.026124, lr:  1.56e-06
# epochs: 788, loss: 0.024844, lr:  1.56e-06
# epochs: 789, loss: 0.025016, lr:  1.56e-06
# epochs: 790, loss: 0.026372, lr:  1.56e-06
# epochs: 791, loss: 0.025783, lr:  1.56e-06
# epochs: 792, loss: 0.027840, lr:  1.56e-06
# epochs: 793, loss: 0.027012, lr:  1.56e-06
# epochs: 794, loss: 0.025482, lr:  1.56e-06
# epochs: 795, loss: 0.025623, lr:  1.56e-06
# epochs: 796, loss: 0.025665, lr:  1.56e-06
# epochs: 797, loss: 0.026066, lr:  1.56e-06
# epochs: 798, loss: 0.026494, lr:  1.56e-06
# epochs: 799, loss: 0.026511, lr:  1.56e-06
# epochs: 800, loss: 0.026303, lr:  7.8e-07
# epochs: 801, loss: 0.026240, lr:  7.8e-07
# epochs: 802, loss: 0.027221, lr:  7.8e-07
# epochs: 803, loss: 0.025428, lr:  7.8e-07
# epochs: 804, loss: 0.025028, lr:  7.8e-07
# epochs: 805, loss: 0.024649, lr:  7.8e-07
# epochs: 806, loss: 0.026532, lr:  7.8e-07
# epochs: 807, loss: 0.024792, lr:  7.8e-07
# epochs: 808, loss: 0.026429, lr:  7.8e-07
# epochs: 809, loss: 0.024664, lr:  7.8e-07
# epochs: 810, loss: 0.026288, lr:  7.8e-07
# epochs: 811, loss: 0.025026, lr:  7.8e-07
# epochs: 812, loss: 0.026575, lr:  7.8e-07
# epochs: 813, loss: 0.026016, lr:  7.8e-07
# epochs: 814, loss: 0.025359, lr:  7.8e-07
# epochs: 815, loss: 0.025315, lr:  7.8e-07
# epochs: 816, loss: 0.025528, lr:  7.8e-07
# epochs: 817, loss: 0.025656, lr:  7.8e-07
# epochs: 818, loss: 0.026997, lr:  7.8e-07
# epochs: 819, loss: 0.024707, lr:  7.8e-07
# epochs: 820, loss: 0.027022, lr:  7.8e-07
# epochs: 821, loss: 0.025102, lr:  7.8e-07
# epochs: 822, loss: 0.026757, lr:  7.8e-07
# epochs: 823, loss: 0.026132, lr:  7.8e-07
# epochs: 824, loss: 0.025372, lr:  7.8e-07
# epochs: 825, loss: 0.026381, lr:  7.8e-07
# epochs: 826, loss: 0.025548, lr:  7.8e-07
# epochs: 827, loss: 0.026524, lr:  7.8e-07
# epochs: 828, loss: 0.025952, lr:  7.8e-07
# epochs: 829, loss: 0.024903, lr:  7.8e-07
# epochs: 830, loss: 0.025829, lr:  7.8e-07
# epochs: 831, loss: 0.025701, lr:  7.8e-07
# epochs: 832, loss: 0.024848, lr:  7.8e-07
# epochs: 833, loss: 0.025242, lr:  7.8e-07
# epochs: 834, loss: 0.025976, lr:  7.8e-07
# epochs: 835, loss: 0.024922, lr:  7.8e-07
# epochs: 836, loss: 0.025106, lr:  7.8e-07
# epochs: 837, loss: 0.026133, lr:  7.8e-07
# epochs: 838, loss: 0.026627, lr:  7.8e-07
# epochs: 839, loss: 0.025346, lr:  7.8e-07
# epochs: 840, loss: 0.025974, lr:  7.8e-07
# epochs: 841, loss: 0.023854, lr:  7.8e-07
# epochs: 842, loss: 0.025308, lr:  7.8e-07
# epochs: 843, loss: 0.025497, lr:  7.8e-07
# epochs: 844, loss: 0.025313, lr:  7.8e-07
# epochs: 845, loss: 0.024609, lr:  7.8e-07
# epochs: 846, loss: 0.024470, lr:  7.8e-07
# epochs: 847, loss: 0.024376, lr:  7.8e-07
# epochs: 848, loss: 0.025414, lr:  7.8e-07
# epochs: 849, loss: 0.024949, lr:  7.8e-07
# epochs: 850, loss: 0.025598, lr:  7.8e-07
# epochs: 851, loss: 0.025767, lr:  7.8e-07
# epochs: 852, loss: 0.025780, lr:  7.8e-07
# epochs: 853, loss: 0.026249, lr:  7.8e-07
# epochs: 854, loss: 0.025129, lr:  7.8e-07
# epochs: 855, loss: 0.025638, lr:  7.8e-07
# epochs: 856, loss: 0.025549, lr:  7.8e-07
# epochs: 857, loss: 0.025796, lr:  7.8e-07
# epochs: 858, loss: 0.025962, lr:  7.8e-07
# epochs: 859, loss: 0.025623, lr:  7.8e-07
# epochs: 860, loss: 0.025304, lr:  7.8e-07
# epochs: 861, loss: 0.025337, lr:  7.8e-07
# epochs: 862, loss: 0.024706, lr:  7.8e-07
# epochs: 863, loss: 0.025795, lr:  7.8e-07
# epochs: 864, loss: 0.025022, lr:  7.8e-07
# epochs: 865, loss: 0.026256, lr:  7.8e-07
# epochs: 866, loss: 0.026919, lr:  7.8e-07
# epochs: 867, loss: 0.025991, lr:  7.8e-07
# epochs: 868, loss: 0.025692, lr:  7.8e-07
# epochs: 869, loss: 0.025353, lr:  7.8e-07
# epochs: 870, loss: 0.026371, lr:  7.8e-07
# epochs: 871, loss: 0.027577, lr:  7.8e-07
# epochs: 872, loss: 0.026076, lr:  7.8e-07
# epochs: 873, loss: 0.025885, lr:  7.8e-07
# epochs: 874, loss: 0.025813, lr:  7.8e-07
# epochs: 875, loss: 0.025120, lr:  7.8e-07
# epochs: 876, loss: 0.026805, lr:  7.8e-07
# epochs: 877, loss: 0.024951, lr:  7.8e-07
# epochs: 878, loss: 0.024987, lr:  7.8e-07
# epochs: 879, loss: 0.026156, lr:  7.8e-07
# epochs: 880, loss: 0.025628, lr:  7.8e-07
# epochs: 881, loss: 0.025740, lr:  7.8e-07
# epochs: 882, loss: 0.026739, lr:  7.8e-07
# epochs: 883, loss: 0.026427, lr:  7.8e-07
# epochs: 884, loss: 0.025288, lr:  7.8e-07
# epochs: 885, loss: 0.025853, lr:  7.8e-07
# epochs: 886, loss: 0.026473, lr:  7.8e-07
# epochs: 887, loss: 0.025769, lr:  7.8e-07
# epochs: 888, loss: 0.026033, lr:  7.8e-07
# epochs: 889, loss: 0.025899, lr:  7.8e-07
# epochs: 890, loss: 0.026668, lr:  7.8e-07
# epochs: 891, loss: 0.026210, lr:  7.8e-07
# epochs: 892, loss: 0.025775, lr:  7.8e-07
# epochs: 893, loss: 0.024448, lr:  7.8e-07
# epochs: 894, loss: 0.026063, lr:  7.8e-07
# epochs: 895, loss: 0.025384, lr:  7.8e-07
# epochs: 896, loss: 0.025345, lr:  7.8e-07
# epochs: 897, loss: 0.025488, lr:  7.8e-07
# epochs: 898, loss: 0.026056, lr:  7.8e-07
# epochs: 899, loss: 0.026856, lr:  7.8e-07
# epochs: 900, loss: 0.025181, lr:  3.9e-07
# epochs: 901, loss: 0.025864, lr:  3.9e-07
# epochs: 902, loss: 0.025136, lr:  3.9e-07
# epochs: 903, loss: 0.025498, lr:  3.9e-07
# epochs: 904, loss: 0.025397, lr:  3.9e-07
# epochs: 905, loss: 0.025733, lr:  3.9e-07
# epochs: 906, loss: 0.025474, lr:  3.9e-07
# epochs: 907, loss: 0.025882, lr:  3.9e-07
# epochs: 908, loss: 0.025386, lr:  3.9e-07
# epochs: 909, loss: 0.025722, lr:  3.9e-07
# epochs: 910, loss: 0.025433, lr:  3.9e-07
# epochs: 911, loss: 0.025190, lr:  3.9e-07
# epochs: 912, loss: 0.025122, lr:  3.9e-07
# epochs: 913, loss: 0.025613, lr:  3.9e-07
# epochs: 914, loss: 0.027328, lr:  3.9e-07
# epochs: 915, loss: 0.025865, lr:  3.9e-07
# epochs: 916, loss: 0.025088, lr:  3.9e-07
# epochs: 917, loss: 0.025659, lr:  3.9e-07
# epochs: 918, loss: 0.025509, lr:  3.9e-07
# epochs: 919, loss: 0.025486, lr:  3.9e-07
# epochs: 920, loss: 0.025180, lr:  3.9e-07
# epochs: 921, loss: 0.025867, lr:  3.9e-07
# epochs: 922, loss: 0.026832, lr:  3.9e-07
# epochs: 923, loss: 0.026477, lr:  3.9e-07
# epochs: 924, loss: 0.027101, lr:  3.9e-07
# epochs: 925, loss: 0.024575, lr:  3.9e-07
# epochs: 926, loss: 0.025689, lr:  3.9e-07
# epochs: 927, loss: 0.025913, lr:  3.9e-07
# epochs: 928, loss: 0.025954, lr:  3.9e-07
# epochs: 929, loss: 0.025663, lr:  3.9e-07
# epochs: 930, loss: 0.024336, lr:  3.9e-07
# epochs: 931, loss: 0.026515, lr:  3.9e-07
# epochs: 932, loss: 0.026278, lr:  3.9e-07
# epochs: 933, loss: 0.025933, lr:  3.9e-07
# epochs: 934, loss: 0.025755, lr:  3.9e-07
# epochs: 935, loss: 0.025611, lr:  3.9e-07
# epochs: 936, loss: 0.026010, lr:  3.9e-07
# epochs: 937, loss: 0.025702, lr:  3.9e-07
# epochs: 938, loss: 0.025756, lr:  3.9e-07
# epochs: 939, loss: 0.025251, lr:  3.9e-07
# epochs: 940, loss: 0.026451, lr:  3.9e-07
# epochs: 941, loss: 0.025054, lr:  3.9e-07
# epochs: 942, loss: 0.025325, lr:  3.9e-07
# epochs: 943, loss: 0.027072, lr:  3.9e-07
# epochs: 944, loss: 0.025180, lr:  3.9e-07
# epochs: 945, loss: 0.025710, lr:  3.9e-07
# epochs: 946, loss: 0.025177, lr:  3.9e-07
# epochs: 947, loss: 0.025119, lr:  3.9e-07
# epochs: 948, loss: 0.025985, lr:  3.9e-07
# epochs: 949, loss: 0.025000, lr:  3.9e-07
# epochs: 950, loss: 0.025046, lr:  3.9e-07
# epochs: 951, loss: 0.025471, lr:  3.9e-07
# epochs: 952, loss: 0.025511, lr:  3.9e-07
# epochs: 953, loss: 0.025177, lr:  3.9e-07
# epochs: 954, loss: 0.025359, lr:  3.9e-07
# epochs: 955, loss: 0.025718, lr:  3.9e-07
# epochs: 956, loss: 0.026134, lr:  3.9e-07
# epochs: 957, loss: 0.026284, lr:  3.9e-07
# epochs: 958, loss: 0.026262, lr:  3.9e-07
# epochs: 959, loss: 0.025552, lr:  3.9e-07
# epochs: 960, loss: 0.023793, lr:  3.9e-07
# epochs: 961, loss: 0.024900, lr:  3.9e-07
# epochs: 962, loss: 0.025753, lr:  3.9e-07
# epochs: 963, loss: 0.026445, lr:  3.9e-07
# epochs: 964, loss: 0.024869, lr:  3.9e-07
# epochs: 965, loss: 0.025498, lr:  3.9e-07
# epochs: 966, loss: 0.024615, lr:  3.9e-07
# epochs: 967, loss: 0.025219, lr:  3.9e-07
# epochs: 968, loss: 0.026190, lr:  3.9e-07
# epochs: 969, loss: 0.025496, lr:  3.9e-07
# epochs: 970, loss: 0.025028, lr:  3.9e-07
# epochs: 971, loss: 0.025606, lr:  3.9e-07
# epochs: 972, loss: 0.025696, lr:  3.9e-07
# epochs: 973, loss: 0.025126, lr:  3.9e-07
# epochs: 974, loss: 0.025165, lr:  3.9e-07
# epochs: 975, loss: 0.025857, lr:  3.9e-07
# epochs: 976, loss: 0.026495, lr:  3.9e-07
# epochs: 977, loss: 0.026208, lr:  3.9e-07
# epochs: 978, loss: 0.026525, lr:  3.9e-07
# epochs: 979, loss: 0.026719, lr:  3.9e-07
# epochs: 980, loss: 0.024957, lr:  3.9e-07
# epochs: 981, loss: 0.025824, lr:  3.9e-07
# epochs: 982, loss: 0.025159, lr:  3.9e-07
# epochs: 983, loss: 0.025631, lr:  3.9e-07
# epochs: 984, loss: 0.025319, lr:  3.9e-07
# epochs: 985, loss: 0.025617, lr:  3.9e-07
# epochs: 986, loss: 0.026160, lr:  3.9e-07
# epochs: 987, loss: 0.025282, lr:  3.9e-07
# epochs: 988, loss: 0.025290, lr:  3.9e-07
# epochs: 989, loss: 0.026296, lr:  3.9e-07
# epochs: 990, loss: 0.025104, lr:  3.9e-07
# epochs: 991, loss: 0.026170, lr:  3.9e-07
# epochs: 992, loss: 0.025440, lr:  3.9e-07
# epochs: 993, loss: 0.026076, lr:  3.9e-07
# epochs: 994, loss: 0.025593, lr:  3.9e-07
# epochs: 995, loss: 0.026349, lr:  3.9e-07
# epochs: 996, loss: 0.025271, lr:  3.9e-07
# epochs: 997, loss: 0.025919, lr:  3.9e-07
# epochs: 998, loss: 0.025783, lr:  3.9e-07
# epochs: 999, loss: 0.026416, lr:  3.9e-07

# %%
save_path = 'lstm_kospi_only_window_inputsize' + str(model_d) + '_hiddensize' + str(n_hidden) + '_seqlen' + str(seq_len) + '_layaers' + str(n_layers)  + '.pt'
# save_path = 'kospi_only.pt'
torch.save(model.state_dict(), save_path)
df_loss
# Out:
#      epoch      loss
# 0      0.0  2.994948
# 1      1.0  0.381952
# 2      2.0  0.264281
# 3      3.0  0.188859
# 4      4.0  0.129203
# ..     ...       ...
# 995  995.0  0.026349
# 996  996.0  0.025271
# 997  997.0  0.025919
# 998  998.0  0.025783
# 999  999.0  0.026416
#
# [1000 rows x 2 columns]

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_loss.loc[20: , 'epoch'], df_loss.loc[20: , 'loss'])
plt.show()

# %%
test_result = pd.DataFrame(columns=['pred', 'pred_rescale', 'real'])
num = 0
min = scale_params.loc['min', 'kospi']
max = scale_params.loc['max', 'kospi']
with torch.no_grad():
    for _, data in enumerate(test_dataloader):
        inputs = data[0].to(device).float()
        # outputs = data[1].to(device).float()
        outputs = data[1]

        pred = model(inputs)
        for i in range(len(pred)):
            pred_ = pred.detach().cpu().numpy()[i][0]
            pred_scaled = pred_ * (max - min) + min
            out_scaled = outputs.numpy()[i] * (max - min) + min
            test_result.loc[num] = [pred_, pred_scaled, out_scaled[0]]
            num += 1

# %%
test_result.tail(10)
# Out:
#          pred  pred_rescale         real
# 130  0.791644   2766.479858  2727.209961
# 131  0.781165   2739.385216  2730.340088
# 132  0.776621   2727.635954  2753.000000
# 133  0.756150   2674.706096  2753.000000
# 134  0.754560   2670.595850  2724.620117
# 135  0.797393   2781.344863  2742.139893
# 136  0.772413   2716.756208  2724.179932
# 137  0.783943   2746.569901  2723.459961
# 138  0.771561   2714.554368  2721.810059
# 139  0.740913   2635.310152  2721.810059

# %%
plt.figure(figsize=(20, 5))
# plt.plot(idx_num, test_result['pred'], label='pred')
plt.scatter(range(len(test_result)), test_result['pred_rescale'], label='pred')
plt.plot(range(len(test_result)), test_result['real'], 'g--', label='real')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 5))
# plt.plot(idx_num, test_result['pred'], label='pred')
plt.scatter(range(20), test_result.iloc[-20: , 1], label='pred')
plt.plot(range(20), test_result.iloc[-20: , 2], 'g--', label='real')
# plt.scatter(range(len(test_result)), test_result['pred'], label='pred')
# plt.plot(range(len(test_result)), test_result['real'], 'g--', label='real')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 5))
# plt.plot(idx_num, test_result['pred'], label='pred')
plt.scatter(range(20), test_result.iloc[-50:-30 , 1], label='pred')
plt.plot(range(20), test_result.iloc[-50:-30 , 2], 'g--', label='real')
# plt.scatter(range(len(test_result)), test_result['pred'], label='pred')
# plt.plot(range(len(test_result)), test_result['real'], 'g--', label='real')
plt.legend()
plt.show()

# %% [markdown]
# ## 6. evaluation metrics
# MAPE, MSE

# %%
mse = mean_squared_error(test_result['real'], test_result['pred_rescale'])
mape = mean_absolute_percentage_error(test_result['real'], test_result['pred_rescale'])
print(f'MSE: {mse:.4f}, MAPE: {mape:.4f}')
# Out:
# MSE: 3114.2501, MAPE: 0.0176

# %% [markdown]
# ## 0. Import libraries

# %%
import torch
import pandas as pd
import numpy as np
import math, copy, time
import torch.nn as nn
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset 
from torch.optim import Adam
import tqdm
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error

# %% [markdown]
# ## 1. Load Data

# %%
df = pd.read_csv('./kospi.csv')
df.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 6762  2024-05-23  2719.030029  2734.270020  2704.000000  2721.810059
# 6763  2024-05-24  2693.649902  2696.989990  2681.169922  2687.600098
# 6764  2024-05-27  2697.159912  2725.080078  2693.659912  2722.989990
# 6765  2024-05-28  2715.520020  2730.120117  2714.340088  2722.850098
# 6766  2024-05-29  2719.560059  2721.629883  2678.090088  2679.189941
#
#         Adj Close  Volume
# 6762  2721.810059  427400
# 6763  2687.600098  501600
# 6764  2722.989990  556700
# 6765  2722.850098  441000
# 6766  2679.189941  409427

# %%
df['kospi_shift'] = df['Adj Close'].shift(-1)
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  1996-12-11  705.989990  709.479980  704.429993  704.679993  704.679993
# 1  1996-12-12  705.109985  706.010010  688.739990  689.380005  689.380005
# 2  1996-12-13  690.440002  695.719971  677.640015  689.070007  689.070007
# 3  1996-12-16  686.969971  686.969971  667.710022  673.919983  673.919983
# 4  1996-12-17  675.349976  680.090027  660.390015  663.349976  663.349976
#
#    Volume  kospi_shift
# 0   28000   689.380005
# 1   25900   689.070007
# 2   26500   673.919983
# 3   22800   663.349976
# 4   31600   661.390015

# %%
col_names = df.columns.values
print(col_names)
# Out:
# ['Date' 'Open' 'High' 'Low' 'Close' 'Adj Close' 'Volume' 'kospi_shift']

# %%
# global variables and hyperparameter
IN_DIM = 128
DAY_INT = 1
BATCH_SIZE = 64
SCALER = 'MINMAX'   # 'NORMAL'
# SCALER = 'NORMAL'   # 'NORMAL'
TRAIN_TEST_SPLIT = 0.95
LR = 1e-4

# %% [markdown]
# ## 2. Split data train and test

# %%
# train test split
df_train = df.iloc[:int(len(df) * TRAIN_TEST_SPLIT), :]
df_test = df.iloc[int(len(df) * TRAIN_TEST_SPLIT): , :]
# print(df_train.tail())
# print(df_test.head())
scale_params = pd.DataFrame(index=['mean', 'var', 'max', 'min'])
for i in col_names[1:]:
    scale_params[i] = [df_train[i].mean(), df_train[i].var(), df_train[i].max(), df_train[i].min()]
scale_params
# Out:
#                Open           High            Low          Close  \
# mean    1567.444804    1577.017282    1555.558617    1566.653486
# var   516459.039009  518614.771196  512750.743107  515807.315879
# max     3305.459961    3316.080078    3295.439941    3305.209961
# min      283.410004     291.010010     277.369995     280.000000
#
#           Adj Close        Volume    kospi_shift
# mean    1566.653486  4.352549e+05    1566.909651
# var   515807.315879  7.423809e+10  515787.441260
# max     3305.209961  3.455500e+06    3305.209961
# min      280.000000  1.390000e+04     280.000000

# %%
# scaling
train_data = pd.DataFrame()
test_data = pd.DataFrame()
if SCALER == 'MINMAX':
    for i in col_names[1:]:
        train_data[i] = df_train[i].apply(lambda x: (x - scale_params.loc['min', i])/(scale_params.loc['max', i] - scale_params.loc['min', i]))
        test_data[i] = df_test[i].apply(lambda x: (x - scale_params.loc['min', i])/(scale_params.loc['max', i] - scale_params.loc['min', i]))
elif SCALER == 'NORMAL':
    for i in col_names[1:]:
        train_data[i] = df_train[i].apply(lambda x: (x - scale_params.loc['mean', i])/scale_params.loc['var', i])
        test_data[i] = df_test[i].apply(lambda x: (x - scale_params.loc['mean', i])/scale_params.loc['var', i])
test_data.tail()
# Out:
#           Open      High       Low     Close  Adj Close    Volume  kospi_shift
# 6762  0.805950  0.807671  0.804034  0.807154   0.807154  0.120148     0.795846
# 6763  0.797551  0.795347  0.796469  0.795846   0.795846  0.141707     0.807544
# 6764  0.798713  0.804633  0.800608  0.807544   0.807544  0.157717     0.807498
# 6765  0.804788  0.806299  0.807460  0.807498   0.807498  0.124099     0.793066
# 6766  0.806125  0.803492  0.795449  0.793066   0.793066  0.114925          NaN

# %%
train_x = np.zeros([(len(train_data) - 64 + 1), 64])
test_x = np.zeros([(len(test_data) - 64 + 1), 64])
train_x.shape, test_x.shape
# Out:
# ((6365, 64), (276, 64))

# %%
class StockDataset(Dataset):
    def __init__(self, y, seq_len, input_window=128, output_window=1, stride=1, status='train'):
        #총 데이터의 개수
        L = y.shape[0]
        #stride씩 움직일 때 생기는 총 sample의 개수
        num_samples = (L - input_window - output_window) // stride + 1
        start_pos = (L - input_window - output_window) % stride
        iter_times = (L - input_window - output_window) // stride + 1
        seq_iter = num_samples - seq_len + 1
        # print(y.shape, num_samples, iter_times, start_pos, L)

        #input과 output
        # X = np.zeros([input_window, num_samples])
        # Y = np.zeros([output_window, num_samples])
        X = np.zeros([num_samples, input_window])
        X_FFT = np.zeros([num_samples, input_window])
        X_random = np.zeros([num_samples, input_window])        
        X_randf = np.zeros([num_samples, input_window])        
        Y = np.zeros([num_samples, output_window])

        for i in np.arange(num_samples):
            start_x = start_pos + i * stride
            end_x = start_x + input_window
            X[i, :] = y[start_x:end_x]
            ft = np.fft.fftn(y[start_x:end_x], norm='forward')
            X_FFT[i, :] = abs(ft)

            # random values
            
            X_random[i, :] = np.random.randn(input_window) + X[i, :]            
            # X_randf[i, :] = np.random.randn(input_window) + X_FFT[i, :]

            # end_y = start_y + output_window
            # print(i, start_x, end_x)
            Y[i, :] = y[end_x: end_x + output_window]
        print(X.shape, Y.shape)
        print(X[-1, -1], '\n', Y[0])
        # X = X.reshape(X.shape[0], X.shape[1], 1).transpose((1,0,2))
        # Y = Y.reshape(Y.shape[0], Y.shape[1], 1).transpose((1,0,2))

        start_pos = num_samples % seq_len
        seq_iter = seq_iter - start_pos - 1
        X_ = np.zeros([seq_iter, seq_len, 3, input_window])
        Y_ = np.zeros([seq_iter, output_window])
        print('start pos:', start_pos, 'seq_iter:', seq_iter)
        for i in range(seq_iter):
            X_[i, :, 0, :] = X[(start_pos+i):(start_pos+seq_len+i), :]
            X_[i, :, 1, :] = X_FFT[(start_pos+i):(start_pos+seq_len+i), :]
            X_[i, :, 2, :] = X_random[(start_pos+i):(start_pos+seq_len+i), :]
            # X_[i, :, 3, :] = X_randf[(start_pos+i):(start_pos+seq_len+i), :]
            Y_[i, :] = Y[start_pos+seq_len+i-1, :]
            # print('i:', i, 'index start:', start_pos+i, 'index end:', start_pos+seq_len+i)
        # X_[0, :, :] = X[(start_pos+0*seq_len):(start_pos+(0+1)*seq_len), :]
        # Y_[0, :] = Y[start_pos+0*seq_len, :]
        print(X[(start_pos+i):(start_pos+seq_len+i), :].shape)
        print(X_.shape, Y_.shape)
        self.x = X_
        self.y = Y_
        
        self.len = len(X_)
    def __getitem__(self, i):
        return self.x[i], self.y[i]
    def __len__(self):
        return self.len

# %%
aa = train_data.loc[:63, 'Adj Close']
aa_ft = np.fft.fftn(aa, norm='forward')
print(abs(aa_ft), np.sum(abs(aa_ft)))
plt.plot(abs(aa_ft))
plt.show()
# Out:
# [1.31988255e-01 3.12271658e-03 1.29683371e-03 2.35780424e-03
#  2.80902610e-03 9.73406883e-04 1.45464698e-03 7.41390180e-04
#  5.13405540e-04 5.54392750e-04 6.60125892e-04 3.03655271e-04
#  7.31274817e-04 4.41558934e-04 1.01014959e-04 1.81445632e-04
#  5.30915635e-04 4.19992340e-04 5.34497679e-04 1.23551995e-04
#  2.60700292e-04 7.37847060e-05 3.18493456e-04 3.70558504e-04
#  1.07783208e-04 1.47474140e-04 1.16297853e-04 2.22296420e-04
#  3.64346220e-04 1.53758572e-04 3.54410473e-04 3.88272864e-04
#  1.69404937e-05 3.88272864e-04 3.54410473e-04 1.53758572e-04
#  3.64346220e-04 2.22296420e-04 1.16297853e-04 1.47474140e-04
#  1.07783208e-04 3.70558504e-04 3.18493456e-04 7.37847060e-05
#  2.60700292e-04 1.23551995e-04 5.34497679e-04 4.19992340e-04
#  5.30915635e-04 1.81445632e-04 1.01014959e-04 4.41558934e-04
#  7.31274817e-04 3.03655271e-04 6.60125892e-04 5.54392750e-04
#  5.13405540e-04 7.41390180e-04 1.45464698e-03 9.73406883e-04
#  2.80902610e-03 2.35780424e-03 1.29683371e-03 3.12271658e-03] 0.17346486151359236

# %%
train_x = StockDataset(train_data['Adj Close'], 64, 64, 1, 1)
print('length of data', len(train_x))
print(next(iter(train_x))[1])
# Out:
# (6364, 64) (6364, 1)
# 0.6644067673505358
#  [0.12107919]
# start pos: 28 seq_iter: 6272
# (64, 64)
# (6272, 64, 3, 64) (6272, 1)
# length of data 6272
# [0.14746745]

# %% [markdown]
# ### 3. create dataloader

# %%
train_dataset = StockDataset(train_data['Adj Close'], 64, 64, 1, 1, 'train')
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

test_dataset = StockDataset(test_data['Adj Close'], 64, 64, 1, 1, 'test')
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
a1 = next(iter(train_dataset))
print(len(train_dataloader), len(train_dataloader.dataset), a1[0].shape, a1[1].shape)
# print(next(iter(test_dataset)))
# Out:
# (6364, 64) (6364, 1)
# 0.6644067673505358
#  [0.12107919]
# start pos: 28 seq_iter: 6272
# (64, 64)
# (6272, 64, 3, 64) (6272, 1)
# (275, 64) (275, 1)
# 0.8074977040268706
#  [0.75421539]
# start pos: 19 seq_iter: 192
# (64, 64)
# (192, 64, 3, 64) (192, 1)
# 98 6272 (64, 3, 64) (1,)

# %%
for x1, y1 in train_dataloader:
    pass
print(x1[0], '\n', y1[63])
# Out:
# tensor([[[ 1.5185e-01,  1.5549e-01,  1.5106e-01,  ...,  1.8730e-01,
#            1.8575e-01,  1.8784e-01],
#          [ 1.7278e-01,  1.0196e-02,  4.1207e-03,  ...,  2.0506e-03,
#            4.1207e-03,  1.0196e-02],
#          [-6.1664e-01,  8.4412e-01,  2.3377e-01,  ...,  1.4340e+00,
#            1.4142e+00,  6.9759e-01]],
#
#         [[ 1.5549e-01,  1.5106e-01,  1.5646e-01,  ...,  1.8575e-01,
#            1.8784e-01,  1.9032e-01],
#          [ 1.7338e-01,  1.0136e-02,  4.2237e-03,  ...,  2.1087e-03,
#            4.2237e-03,  1.0136e-02],
#          [-1.1107e+00,  9.0377e-01,  4.1626e-01,  ...,  7.7907e-01,
#           -4.0206e-01, -1.7373e-01]],
#
#         [[ 1.5106e-01,  1.5646e-01,  1.5292e-01,  ...,  1.8784e-01,
#            1.9032e-01,  1.8135e-01],
#          [ 1.7379e-01,  1.0076e-02,  4.2616e-03,  ...,  2.1254e-03,
#            4.2616e-03,  1.0076e-02],
#          [-3.3335e-01,  1.7534e-01, -1.1116e+00,  ...,  1.9869e+00,
#            3.1044e-01, -4.9317e-01]],
#
#         ...,
#
#         [[ 1.8730e-01,  1.8575e-01,  1.8784e-01,  ...,  1.9641e-01,
#            1.9975e-01,  1.9834e-01],
#          [ 1.9261e-01,  2.8351e-03,  3.0304e-03,  ...,  1.0284e-03,
#            3.0304e-03,  2.8351e-03],
#          [ 3.8587e-01, -1.2749e+00,  2.2085e+00,  ..., -6.7247e-01,
#            6.1330e-01,  9.6791e-01]],
#
#         [[ 1.8575e-01,  1.8784e-01,  1.9032e-01,  ...,  1.9975e-01,
#            1.9834e-01,  2.0016e-01],
#          [ 1.9281e-01,  2.7506e-03,  3.0346e-03,  ...,  1.0658e-03,
#            3.0346e-03,  2.7506e-03],
#          [ 1.7720e+00,  9.8730e-01,  4.7372e-01,  ..., -5.7630e-01,
#           -1.1751e+00,  1.1816e+00]],
#
#         [[ 1.8784e-01,  1.9032e-01,  1.8135e-01,  ...,  1.9834e-01,
#            2.0016e-01,  2.0663e-01],
#          [ 1.9314e-01,  2.6102e-03,  3.0058e-03,  ...,  1.1104e-03,
#            3.0058e-03,  2.6102e-03],
#          [-7.6825e-01,  6.7703e-01, -5.5810e-01,  ...,  5.9969e-01,
#            5.6428e-02,  3.3874e-01]]], dtype=torch.float64)
#  tensor([0.4147], dtype=torch.float64)

# %%
for x1, y1 in test_dataloader:
    pass
print(x1[0].shape, '\n', y1[0].shape)
# Out:
# torch.Size([64, 3, 64])
#  torch.Size([1])

# %% [markdown]
# ## 4. Make a Transformer model

# %% [markdown]
# In this sections, we will implement the building blocks of the transformer: [Positional encoding](#1a), [Multi-head attention](#1b) and [Position wise feedforward network](#1c)

# %% [markdown]
# ### a. Sinusoidal Positional Encoding
# <a id='1a'></a>
# In this section, we will implement sinusoidal positional encoding
#
# $$\begin{align}
# PE(pos, 2i) &= \sin \left( pos / 10000^{2i / d_{model}} \right)  \\
# PE(pos, 2i+1) &= \cos \left( pos / 10000^{2i / d_{model}} \right)
# \end{align}$$

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model , max_len, device):
        """
        d_model: dimension of model
        max_len: maximum sequence length
        device: 'cuda' or 'cpu'
        """
        super().__init__()
        self.encoding = torch.zeros(max_len, d_model, device=device)
        self.encoding.required_grad = False

        pos = torch.arange(0, max_len, device=device)
        pos = pos.float().unsqueeze(dim=1) # [a, b, ...] -> [[a], [b], [c], ...]

        _2i = torch.arange(0, d_model, step=2, device=device) # i is d_model and step=2 means 2*i
        self.encoding[:, 0::2] = torch.sin(pos / (10000 ** (_2i / d_model)))
        self.encoding[:, 1::2] = torch.cos(pos / (10000 ** (_2i / d_model)))
    
    def forward(self, x):
        # x: Tensor, shape ``[batch_size, seq_len, embedding_dim]
        # d_model = 512
        # print(x.size())
        batch_size, seq_len = x.size()[:2]
        pe = self.encoding[:seq_len, :]
        return pe

# %%
sample_pos_encoding = PositionalEncoding(128, 50, device='cpu')

plt.pcolormesh(sample_pos_encoding.encoding.numpy(), cmap='RdBu')
plt.xlabel('Depth')
plt.ylabel('Position')
plt.colorbar()
plt.show()

# %% [markdown]
# ### b. Scaled dot product attention

# %% [markdown]
# __Scaled dot product:__
# ![picture](./assets/transformer_2.png)

# %%
class ScaleDotProductAttention(nn.Module):
    """
    Query: given setence
    Key: same with query(encoder)
    Value: same with key
    """

    def __init__(self):
        super().__init__()
        self.softmax = nn.Softmax(dim=-1)
    
    def forward(self, q, k, v, mask=None, e=1e-12):
        # input: 4 dimension tensor
        # [batch_size, head, length, d_tensor]
        batch_size, head, length, d_tensor = k.size()

        # 1. q @ K.T
        k_t = k.transpose(2, 3)
        # print(q.size(), k_t.size())
        score = (q @ k_t) / math.sqrt(d_tensor)

        # 2. masking(decoder self attention only)
        if mask is not None:
            score = score.masked_fill(mask == 0, -10000)
        
        # 3. pass them softmax to [0, 1] range
        score = self.softmax(score)

        # 4. multiply with value
        v = score @ v

        return v, score

# %% [markdown]
# ### c. MultiheadAttention
# <a id='1b'></a>
# Equation:
#
# $$\begin{align} \text{MultiHead}(Q, K, V) &= \text{Concat}(head_1, ...., head_h) W^O \\
# \text{where head}_i &= \text{Attention} \left( QW^Q_i, K W^K_i, VW^v_i \right)
# \end{align}$$

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, n_head):
        super().__init__()
        self.n_head = n_head
        self.attention = ScaleDotProductAttention()
        self.w_q = nn.Linear(d_model, d_model)
        self.w_k = nn.Linear(d_model, d_model)
        self.w_v = nn.Linear(d_model, d_model)
        self.w_concat = nn.Linear(d_model, d_model)
    
    def forward(self, q, k, v, mask=None):
        # 1. dot product with weight matrices
        q, k, v = self.w_q(q), self.w_k(k), self.w_v(v)

        # 2. split tensor by heads
        q, k, v = self.split(q), self.split(k), self.split(v)

        # 3. scale dot product
        out, attention = self.attention(q, k, v, mask=mask)

        # 4. concat and pass to linear layer
        out = self.concat(out)
        out = self.w_concat(out)

        return out
    
    def split(self, tensor):
        '''
        split tensor by heads
        tensor: [batch_size, seq_len, d_model]
        return: [batch_size, head, seq_len, d_tensor] --- d_model = head * d_tensor
        '''
        batch_size, seq_len, d_model = tensor.size()
        d_tensor = d_model // self.n_head
        tensor = tensor.view(batch_size, seq_len, self.n_head, d_tensor).transpose(1, 2)
        # split by # of heads
        return tensor
    
    def concat(self, tensor):
        '''
        inverse of split(tensor)
        tensor: [batch_size, head, seq_len, d_tensor]
        return: [batch_size, seq_len, d_model]
        '''
        batch_size, head, seq_len, d_tensor = tensor.size()
        d_model = head * d_tensor

        tensor = tensor.transpose(1, 2).contiguous().view(batch_size, seq_len, d_model)
        return tensor

# %% [markdown]
# ### d. Position-wise feed forward network
# <a id='1c'></a>
# In this section, we will implement position-wise feed forward network
#
# $$\text{FFN}(x) = \max \left(0, x W_1 + b_1 \right) W_2 + b_2$$

# %%
class PositionwiseFeedForward(nn.Module):
    def __init__(self, d_model, hidden, dropout):
        super().__init__()
        self.linear1 = nn.Linear(d_model, hidden)
        self.linear2 = nn.Linear(hidden, d_model)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=dropout)
    
    def forward(self, x):
        x = self.linear1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear2(x)
        x = self.relu(x)
        return x

# %% [markdown]
# ### e. Layer Normalization

# %%
class LayerNorm(nn.Module):
    def __init__(self, d_model, eps=1e-12):
        super().__init__()
        self.gamma = nn.Parameter(torch.ones(d_model))
        self.beta = nn.Parameter(torch.zeros(d_model))
        self.eps = eps
    
    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        var = x.var(-1, keepdim=True)
        # -1 to get mean and var for the last dimension(d_model)

        out = (x - mean) / torch.sqrt(var + self.eps)
        out = self.gamma * out + self.beta
        return out

# %% [markdown]
# ## 5. Embedding input data
#
# make 1 input dimension data to d_model dimentions

# %%
class LinearEmbedding(nn.Module):
    def __init__(self, in_d, dropout, d_model):
        '''
        data: [batch_size, seq_len, in_d]
        In this model, only kospi input window
        '''
        super().__init__()
        self.d_model = d_model
        self.in_d = in_d
        print(type(in_d), type(d_model))
        self.linear1 = nn.Linear(in_d, d_model//2)
        self.linear2 = nn.Linear(d_model//2, d_model)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=dropout)
        self.normal1 = LayerNorm(d_model//2)
    
    def forward(self, x):
        '''
        input: [batch_size, seq_len, in_d]
        output: [batch_size, seq_len, d_model]
        '''
        if x.size()[-1] == self.d_model:
            return x
        else:
            x = self.linear1(x)
            x = self.relu(x)
            x = self.dropout(x)
            x = self.normal1(x)
            x = self.linear2(x)
            x = self.relu(x)
            return x

# %%
class TrnasformerEmbedding(nn.Module):
    '''
    d_model: dimension of input data
    seq_len: max length of sequence
    '''
    def __init__(self, in_d, dropout, d_model, seq_len, device):
        # in_d, dropout, d_model, seq_len, device
        super().__init__()
        self.in_d = in_d
        self.d_model = d_model
        self.lin_emb = LinearEmbedding(in_d, dropout, d_model)
        # self.pos_emb = PositionalEncoding(d_model, seq_len, device)
        self.dropout = nn.Dropout(p=dropout)

    def forward(self, x):
        if self.in_d == self.d_model:
            lin_emb = x
        else:
            lin_emb = self.lin_emb(x)
        # pos_emb = self.pos_emb(x)
        # print(pos_emb.size(), lin_emb.size())
        return self.dropout(lin_emb)
        # return self.dropout(lin_emb + pos_emb)

# %% [markdown]
# ## 6. Encoder Layer
# Trnasformer Encoder Except Embedding

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, ffn_hidden, n_head, dropout):
        super().__init__()
        self.attention = MultiHeadAttention(d_model=d_model, n_head=n_head)
        self.normal1 = LayerNorm(d_model=d_model)
        self.dropout1 = nn.Dropout(p=dropout)

        self.ffn = PositionwiseFeedForward(d_model=d_model, hidden=ffn_hidden, dropout=dropout)
        self.normal2 = LayerNorm(d_model=d_model)
        self.dropout2 = nn.Dropout(p=dropout)
    
    def forward(self, x, src_mask=None):
        # 1. multihead Attention
        residual = x
        x = self.attention(x, x, x)

        # 2. add and norm
        x = self.dropout1(x)
        x = self.normal1(x + residual)

        # 3. positionwise FFN
        residual = x
        x = self.ffn(x)

        # 4. add and norm
        x = self.dropout2(x)
        x = self.normal2(x + residual)

        return x

# %% [markdown]
# ## 7. Encoder
# Build Embedding and Encoder Block

# %%
class Encoder(nn.Module):
    def __init__(self, in_d, seq_len, d_model, ffn_hidden, n_head, dropout, n_layers, device):
        # in_d, seq_len, d_model, ffn_hidden, n_head, dropout, n_layers, device)
        super().__init__()
        self.emb = TrnasformerEmbedding(in_d, dropout, d_model, seq_len, device)
        self.layers = nn.ModuleList([EncoderLayer(d_model, ffn_hidden, n_head, dropout)
                                     for _ in range(n_layers)])
    
    def forward(self, x):
        x = self.emb(x)
        for layer in self.layers:
            x = layer(x)
        
        return x

# %% [markdown]
# ## 8. Transformer Encoder
# Only use encoder module and FFN

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, in_d, seq_len, d_model, ffn_hidden, n_head, dropout, n_layers, lstm_hidden_size, lstm_layers, device):
        super().__init__()
        self.encoder1 = Encoder(in_d, seq_len, d_model, ffn_hidden, n_head, dropout, n_layers, device)
        self.encoder2 = Encoder(in_d, seq_len, d_model, ffn_hidden, n_head, dropout, n_layers, device)
        self.encoder3 = Encoder(in_d, seq_len, d_model, ffn_hidden, n_head, dropout, n_layers, device)
        # self.encoder4 = Encoder(in_d, seq_len, d_model, ffn_hidden, n_head, dropout, n_layers, device)

        # # self.flatten = nn.Flatten()
        self.lstm = nn.LSTM(d_model, lstm_hidden_size, lstm_layers, batch_first=True, dropout=dropout)
        # self.flatten_dim = seq_len * d_model
        self.linear1 = nn.Linear(lstm_hidden_size, lstm_hidden_size//2)
        self.linear2 = nn.Linear(lstm_hidden_size//2, 1)
        self.normal1 = nn.LayerNorm(lstm_hidden_size//2)

        self.dropout = nn.Dropout(p=dropout)
        self.relu = nn.ReLU()
    
    def forward(self, x, i):
        # print('model dimention', x.size())
        # print('encode input0 dim', x[:, :, 0, :].squeeze().size())
        # print('encode input1 dim', x[:, :, 1, :].squeeze().size())

        # if i == 0:
        x_t = self.encoder1(x[:, :, 0, :].squeeze())
        x_fft = self.encoder2(x[:, :, 1, :].squeeze())
        x_random = self.encoder3(x[:, :, 2, :].squeeze())
        # x_randf = self.encoder4(x[:, :, 3, :].squeeze())
        
        xs = x_t + x_fft + x_random
            # xs = x_t
        lstm_out, (hs, cs) = self.lstm(xs)
        # else:
        #     x = self.encoder(x)
        #     lstm_out, (hs, cs) = self.lstm(x)

        return lstm_out

# %%
class TFEncoderBlock(nn.Module):
    def __init__(self, tfl_layer, in_d, seq_len, d_model, ffn_hidden, n_head, dropout, n_layers, lstm_hidden_size, lstm_layers, device):
        super().__init__()
        self.layers = nn.ModuleList([TransformerEncoder(in_d, seq_len, d_model, ffn_hidden, n_head, dropout, n_layers, lstm_hidden_size, lstm_layers, device)
                                     for _ in range(tfl_layer)])
        self.linear1 = nn.Linear(lstm_hidden_size, lstm_hidden_size//2)
        self.linear2 = nn.Linear(lstm_hidden_size//2, 1)
        self.normal1 = nn.LayerNorm(lstm_hidden_size//2)

        self.dropout = nn.Dropout(p=dropout)
        self.relu = nn.ReLU()
        # self.fft = nn.Parameter(torch.empty([BATCH_SIZE, seq_len, d_model], dtype=torch.float).to(device))
        self.tfl_layer_size = tfl_layer
        self.device = device

    def forward(self, x):
        
        for i, layer in enumerate(self.layers):
            x_t = layer(x, i)
            # print(x_t.dtype)
            if i != (self.tfl_layer_size - 1):
                x_fft = nn.Parameter(torch.FloatTensor.abs(torch.fft.fftn(x_t, norm='forward'))).to(self.device)
                x_t = x_t.unsqueeze(2)
                x_fft = x_fft.unsqueeze(2)
                x= torch.cat([x_t, x_fft], dim=2).contiguous()
                # print('x_fft size:', x_fft.size(), ', x size:', x.size())
                # print(x)
        out = x_t[:, -1, :]
        x = self.linear1(out)
        # print(x.size())
        x = self.relu(x)
        x = self.dropout(x)
        x = self.normal1(x)
        x = self.linear2(x)
        x = self.relu(x)
        return x

# %% [markdown]
# ## 9. model, loss_fn, optimizer

# %%
# next(iter(train_dataloader)).shape
# torch.cuda.empty.cache()
batch_size, seq_len, _, input_dim = next(iter(train_dataloader))[0].size()
print(batch_size, seq_len, input_dim)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
in_d = 64
model_d = 512
dropout = 0
ffn_hidden = model_d * 2
n_layers = 4
n_head = 4
lstm_hidden_size = model_d * 2
lstm_layers = 1
tfl_layer = 1
lr_sched = True
lr = 1e-6
# Out:
# 64 64 64

# %%
model = TFEncoderBlock(tfl_layer, in_d, seq_len, model_d, ffn_hidden, n_head, dropout, n_layers, lstm_hidden_size, lstm_layers, device).to(device)
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr = lr)
if lr_sched == True:
    # scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer=optimizer,
    #                                     lr_lambda=lambda epoch: 0.95 ** epoch,
    #                                     last_epoch=-1,
    #                                     verbose=False)
    # scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=150, gamma=0.1)
# Out:
# <class 'int'> <class 'int'>
# <class 'int'> <class 'int'>
# <class 'int'> <class 'int'>

# %%
model
# Out:
# TFEncoderBlock(
#   (layers): ModuleList(
#     (0): TransformerEncoder(
#       (encoder1): Encoder(
#         (emb): TrnasformerEmbedding(
#           (lin_emb): LinearEmbedding(
#             (linear1): Linear(in_features=64, out_features=256, bias=True)
#             (linear2): Linear(in_features=256, out_features=512, bias=True)
#             (relu): ReLU()
#             (dropout): Dropout(p=0, inplace=False)
#             (normal1): LayerNorm()
#           )
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (layers): ModuleList(
#           (0-3): 4 x EncoderLayer(
#             (attention): MultiHeadAttention(
#               (attention): ScaleDotProductAttention(
#                 (softmax): Softmax(dim=-1)
#               )
#               (w_q): Linear(in_features=512, out_features=512, bias=True)
#               (w_k): Linear(in_features=512, out_features=512, bias=True)
#               (w_v): Linear(in_features=512, out_features=512, bias=True)
#               (w_concat): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (normal1): LayerNorm()
#             (dropout1): Dropout(p=0, inplace=False)
#             (ffn): PositionwiseFeedForward(
#               (linear1): Linear(in_features=512, out_features=1024, bias=True)
#               (linear2): Linear(in_features=1024, out_features=512, bias=True)
#               (relu): ReLU()
#               (dropout): Dropout(p=0, inplace=False)
#             )
#             (normal2): LayerNorm()
#             (dropout2): Dropout(p=0, inplace=False)
#           )
#         )
#       )
#       (encoder2): Encoder(
#         (emb): TrnasformerEmbedding(
#           (lin_emb): LinearEmbedding(
#             (linear1): Linear(in_features=64, out_features=256, bias=True)
#             (linear2): Linear(in_features=256, out_features=512, bias=True)
#             (relu): ReLU()
#             (dropout): Dropout(p=0, inplace=False)
#             (normal1): LayerNorm()
#           )
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (layers): ModuleList(
#           (0-3): 4 x EncoderLayer(
#             (attention): MultiHeadAttention(
#               (attention): ScaleDotProductAttention(
#                 (softmax): Softmax(dim=-1)
#               )
#               (w_q): Linear(in_features=512, out_features=512, bias=True)
#               (w_k): Linear(in_features=512, out_features=512, bias=True)
#               (w_v): Linear(in_features=512, out_features=512, bias=True)
#               (w_concat): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (normal1): LayerNorm()
#             (dropout1): Dropout(p=0, inplace=False)
#             (ffn): PositionwiseFeedForward(
#               (linear1): Linear(in_features=512, out_features=1024, bias=True)
#               (linear2): Linear(in_features=1024, out_features=512, bias=True)
#               (relu): ReLU()
#               (dropout): Dropout(p=0, inplace=False)
#             )
#             (normal2): LayerNorm()
#             (dropout2): Dropout(p=0, inplace=False)
#           )
#         )
#       )
#       (encoder3): Encoder(
#         (emb): TrnasformerEmbedding(
#           (lin_emb): LinearEmbedding(
#             (linear1): Linear(in_features=64, out_features=256, bias=True)
#             (linear2): Linear(in_features=256, out_features=512, bias=True)
#             (relu): ReLU()
#             (dropout): Dropout(p=0, inplace=False)
#             (normal1): LayerNorm()
#           )
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (layers): ModuleList(
#           (0-3): 4 x EncoderLayer(
#             (attention): MultiHeadAttention(
#               (attention): ScaleDotProductAttention(
#                 (softmax): Softmax(dim=-1)
#               )
#               (w_q): Linear(in_features=512, out_features=512, bias=True)
#               (w_k): Linear(in_features=512, out_features=512, bias=True)
#               (w_v): Linear(in_features=512, out_features=512, bias=True)
#               (w_concat): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (normal1): LayerNorm()
#             (dropout1): Dropout(p=0, inplace=False)
#             (ffn): PositionwiseFeedForward(
#               (linear1): Linear(in_features=512, out_features=1024, bias=True)
#               (linear2): Linear(in_features=1024, out_features=512, bias=True)
#               (relu): ReLU()
#               (dropout): Dropout(p=0, inplace=False)
#             )
#             (normal2): LayerNorm()
#             (dropout2): Dropout(p=0, inplace=False)
#           )
#         )
#       )
#       (lstm): LSTM(512, 1024, batch_first=True)
#       (linear1): Linear(in_features=1024, out_features=512, bias=True)
#       (linear2): Linear(in_features=512, out_features=1, bias=True)
#       (normal1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0, inplace=False)
#       (relu): ReLU()
#     )
#   )
#   (linear1): Linear(in_features=1024, out_features=512, bias=True)
#   (linear2): Linear(in_features=512, out_features=1, bias=True)
#   (normal1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   (dropout): Dropout(p=0, inplace=False)
#   (relu): ReLU()
# )

# %% [markdown]
# ## 10. Train and Test function

# %%
linear_model = LinearEmbedding(in_d, dropout, model_d).to(device)
in_x, in_y = next(iter(train_dataloader))
in_x = in_x.to(device).float()
out = linear_model(in_x)
out.size()
# Out:
# <class 'int'> <class 'int'>
# torch.Size([64, 64, 3, 512])

# %%
emb_model = TrnasformerEmbedding(in_d, dropout, model_d, seq_len, device).to(device)
in_x, in_y = next(iter(train_dataloader))
in_x = in_x.to(device).float()
print(in_x.shape, in_y.shape)
out = emb_model(in_x[:, :, 0, :].squeeze())
out.size()
# Out:
# <class 'int'> <class 'int'>
# torch.Size([64, 64, 3, 64]) torch.Size([64, 1])
# torch.Size([64, 64, 512])

# %%
encoder_model = Encoder(in_d, seq_len, model_d, ffn_hidden, n_head, dropout, n_layers, device).to(device)
in_x, in_y = next(iter(train_dataloader))
in_x = in_x.to(device).float()
out = encoder_model(in_x[:, :, 0, :].squeeze())
print(out.size())
print(in_y.shape)
print(in_y.contiguous().view(-1).shape)
# Out:
# <class 'int'> <class 'int'>
# torch.Size([64, 64, 512])
# torch.Size([64, 1])
# torch.Size([64])

# %%
in_x, in_y = next(iter(train_dataloader))
in_x = in_x.to(device).float()
out = model(in_x)
print(out.size())
print(in_y.shape)
print(in_y.contiguous().view(-1).shape)
# Out:
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64])

# %%
epochs = 450
loss_np = np.zeros((epochs, 2))
df_loss = pd.DataFrame(loss_np, columns=['epoch', 'loss'])
for i in range(epochs):
    epoch_loss = 0
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device).float()
        labels = labels.squeeze(1).to(device)

        optimizer.zero_grad()
        output = model(inputs)
        # print(output, labels)
        loss = loss_fn(output.squeeze().float(), labels.float())
        # print(loss)
        loss.backward()
        # torch.nn.utils.clip_grad_norm(model.parameters(), 0.5)  # when using scheduler, it is not for grad exploding
        optimizer.step()

        epoch_loss += loss.item()
    
    print(f'epochs: {i}, loss: {epoch_loss:.6f}, lr: ', round(optimizer.param_groups[0]['lr'], 9))
    if lr_sched == True:
        scheduler.step()
    df_loss.loc[i, :] = [i, epoch_loss]
# Out:
# epochs: 0, loss: 3.097016, lr:  1e-06
# epochs: 1, loss: 1.565319, lr:  1e-06
# epochs: 2, loss: 1.134880, lr:  1e-06
# epochs: 3, loss: 0.890906, lr:  1e-06
# epochs: 4, loss: 0.745456, lr:  1e-06
# epochs: 5, loss: 0.629947, lr:  1e-06
# epochs: 6, loss: 0.547861, lr:  1e-06
# epochs: 7, loss: 0.482818, lr:  1e-06
# epochs: 8, loss: 0.434368, lr:  1e-06
# epochs: 9, loss: 0.386360, lr:  1e-06
# epochs: 10, loss: 0.348477, lr:  1e-06
# epochs: 11, loss: 0.322678, lr:  1e-06
# epochs: 12, loss: 0.290353, lr:  1e-06
# epochs: 13, loss: 0.267856, lr:  1e-06
# epochs: 14, loss: 0.250500, lr:  1e-06
# epochs: 15, loss: 0.225319, lr:  1e-06
# epochs: 16, loss: 0.214453, lr:  1e-06
# epochs: 17, loss: 0.196892, lr:  1e-06
# epochs: 18, loss: 0.185428, lr:  1e-06
# epochs: 19, loss: 0.171400, lr:  1e-06
# epochs: 20, loss: 0.160424, lr:  1e-06
# epochs: 21, loss: 0.153057, lr:  1e-06
# epochs: 22, loss: 0.142427, lr:  1e-06
# epochs: 23, loss: 0.135745, lr:  1e-06
# epochs: 24, loss: 0.127521, lr:  1e-06
# epochs: 25, loss: 0.122273, lr:  1e-06
# epochs: 26, loss: 0.113839, lr:  1e-06
# epochs: 27, loss: 0.108684, lr:  1e-06
# epochs: 28, loss: 0.102432, lr:  1e-06
# epochs: 29, loss: 0.099749, lr:  1e-06
# epochs: 30, loss: 0.092599, lr:  1e-06
# epochs: 31, loss: 0.089353, lr:  1e-06
# epochs: 32, loss: 0.085005, lr:  1e-06
# epochs: 33, loss: 0.081305, lr:  1e-06
# epochs: 34, loss: 0.077595, lr:  1e-06
# epochs: 35, loss: 0.074740, lr:  1e-06
# epochs: 36, loss: 0.072783, lr:  1e-06
# epochs: 37, loss: 0.067588, lr:  1e-06
# epochs: 38, loss: 0.065233, lr:  1e-06
# epochs: 39, loss: 0.062532, lr:  1e-06
# epochs: 40, loss: 0.059774, lr:  1e-06
# epochs: 41, loss: 0.057326, lr:  1e-06
# epochs: 42, loss: 0.055546, lr:  1e-06
# epochs: 43, loss: 0.053176, lr:  1e-06
# epochs: 44, loss: 0.051392, lr:  1e-06
# epochs: 45, loss: 0.049147, lr:  1e-06
# epochs: 46, loss: 0.049418, lr:  1e-06
# epochs: 47, loss: 0.044595, lr:  1e-06
# epochs: 48, loss: 0.045067, lr:  1e-06
# epochs: 49, loss: 0.042637, lr:  1e-06
# epochs: 50, loss: 0.039330, lr:  1e-06
# epochs: 51, loss: 0.037503, lr:  1e-06
# epochs: 52, loss: 0.036102, lr:  1e-06
# epochs: 53, loss: 0.034985, lr:  1e-06
# epochs: 54, loss: 0.033325, lr:  1e-06
# epochs: 55, loss: 0.032724, lr:  1e-06
# epochs: 56, loss: 0.031726, lr:  1e-06
# epochs: 57, loss: 0.029655, lr:  1e-06
# epochs: 58, loss: 0.029765, lr:  1e-06
# epochs: 59, loss: 0.027783, lr:  1e-06
# epochs: 60, loss: 0.026892, lr:  1e-06
# epochs: 61, loss: 0.026046, lr:  1e-06
# epochs: 62, loss: 0.024903, lr:  1e-06
# epochs: 63, loss: 0.023709, lr:  1e-06
# epochs: 64, loss: 0.023135, lr:  1e-06
# epochs: 65, loss: 0.022939, lr:  1e-06
# epochs: 66, loss: 0.021860, lr:  1e-06
# epochs: 67, loss: 0.020814, lr:  1e-06
# epochs: 68, loss: 0.020646, lr:  1e-06
# epochs: 69, loss: 0.019346, lr:  1e-06
# epochs: 70, loss: 0.018265, lr:  1e-06
# epochs: 71, loss: 0.018692, lr:  1e-06
# epochs: 72, loss: 0.017430, lr:  1e-06
# epochs: 73, loss: 0.016801, lr:  1e-06
# epochs: 74, loss: 0.016735, lr:  1e-06
# epochs: 75, loss: 0.015502, lr:  1e-06
# epochs: 76, loss: 0.015186, lr:  1e-06
# epochs: 77, loss: 0.015213, lr:  1e-06
# epochs: 78, loss: 0.014032, lr:  1e-06
# epochs: 79, loss: 0.013780, lr:  1e-06
# epochs: 80, loss: 0.012975, lr:  1e-06
# epochs: 81, loss: 0.012645, lr:  1e-06
# epochs: 82, loss: 0.012378, lr:  1e-06
# epochs: 83, loss: 0.011854, lr:  1e-06
# epochs: 84, loss: 0.011764, lr:  1e-06
# epochs: 85, loss: 0.011227, lr:  1e-06
# epochs: 86, loss: 0.011801, lr:  1e-06
# epochs: 87, loss: 0.010937, lr:  1e-06
# epochs: 88, loss: 0.011335, lr:  1e-06
# epochs: 89, loss: 0.009790, lr:  1e-06
# epochs: 90, loss: 0.009175, lr:  1e-06
# epochs: 91, loss: 0.009164, lr:  1e-06
# epochs: 92, loss: 0.009942, lr:  1e-06
# epochs: 93, loss: 0.008814, lr:  1e-06
# epochs: 94, loss: 0.008214, lr:  1e-06
# epochs: 95, loss: 0.008476, lr:  1e-06
# epochs: 96, loss: 0.007916, lr:  1e-06
# epochs: 97, loss: 0.007665, lr:  1e-06
# epochs: 98, loss: 0.007840, lr:  1e-06
# epochs: 99, loss: 0.007056, lr:  1e-06
# epochs: 100, loss: 0.007038, lr:  1e-06
# epochs: 101, loss: 0.007242, lr:  1e-06
# epochs: 102, loss: 0.006997, lr:  1e-06
# epochs: 103, loss: 0.006499, lr:  1e-06
# epochs: 104, loss: 0.005825, lr:  1e-06
# epochs: 105, loss: 0.006072, lr:  1e-06
# epochs: 106, loss: 0.005630, lr:  1e-06
# epochs: 107, loss: 0.005683, lr:  1e-06
# epochs: 108, loss: 0.005984, lr:  1e-06
# epochs: 109, loss: 0.005371, lr:  1e-06
# epochs: 110, loss: 0.005518, lr:  1e-06
# epochs: 111, loss: 0.004977, lr:  1e-06
# epochs: 112, loss: 0.004729, lr:  1e-06
# epochs: 113, loss: 0.004830, lr:  1e-06
# epochs: 114, loss: 0.004874, lr:  1e-06
# epochs: 115, loss: 0.004513, lr:  1e-06
# epochs: 116, loss: 0.004472, lr:  1e-06
# epochs: 117, loss: 0.004482, lr:  1e-06
# epochs: 118, loss: 0.004279, lr:  1e-06
# epochs: 119, loss: 0.004151, lr:  1e-06
# epochs: 120, loss: 0.003957, lr:  1e-06
# epochs: 121, loss: 0.003795, lr:  1e-06
# epochs: 122, loss: 0.003909, lr:  1e-06
# epochs: 123, loss: 0.003642, lr:  1e-06
# epochs: 124, loss: 0.003964, lr:  1e-06
# epochs: 125, loss: 0.003473, lr:  1e-06
# epochs: 126, loss: 0.003445, lr:  1e-06
# epochs: 127, loss: 0.003593, lr:  1e-06
# epochs: 128, loss: 0.003422, lr:  1e-06
# epochs: 129, loss: 0.003184, lr:  1e-06
# epochs: 130, loss: 0.003351, lr:  1e-06
# epochs: 131, loss: 0.003096, lr:  1e-06
# epochs: 132, loss: 0.003106, lr:  1e-06
# epochs: 133, loss: 0.002854, lr:  1e-06
# epochs: 134, loss: 0.003048, lr:  1e-06
# epochs: 135, loss: 0.002767, lr:  1e-06
# epochs: 136, loss: 0.002782, lr:  1e-06
# epochs: 137, loss: 0.002797, lr:  1e-06
# epochs: 138, loss: 0.002899, lr:  1e-06
# epochs: 139, loss: 0.002565, lr:  1e-06
# epochs: 140, loss: 0.002590, lr:  1e-06
# epochs: 141, loss: 0.002474, lr:  1e-06
# epochs: 142, loss: 0.002454, lr:  1e-06
# epochs: 143, loss: 0.002543, lr:  1e-06
# epochs: 144, loss: 0.002648, lr:  1e-06
# epochs: 145, loss: 0.002454, lr:  1e-06
# epochs: 146, loss: 0.002530, lr:  1e-06
# epochs: 147, loss: 0.002290, lr:  1e-06
# epochs: 148, loss: 0.002234, lr:  1e-06
# epochs: 149, loss: 0.002234, lr:  1e-06
# epochs: 150, loss: 0.001967, lr:  1e-07
# epochs: 151, loss: 0.001920, lr:  1e-07
# epochs: 152, loss: 0.001915, lr:  1e-07
# epochs: 153, loss: 0.001913, lr:  1e-07
# epochs: 154, loss: 0.001911, lr:  1e-07
# epochs: 155, loss: 0.001900, lr:  1e-07
# epochs: 156, loss: 0.001902, lr:  1e-07
# epochs: 157, loss: 0.001894, lr:  1e-07
# epochs: 158, loss: 0.001894, lr:  1e-07
# epochs: 159, loss: 0.001888, lr:  1e-07
# epochs: 160, loss: 0.001891, lr:  1e-07
# epochs: 161, loss: 0.001883, lr:  1e-07
# epochs: 162, loss: 0.001886, lr:  1e-07
# epochs: 163, loss: 0.001884, lr:  1e-07
# epochs: 164, loss: 0.001874, lr:  1e-07
# epochs: 165, loss: 0.001871, lr:  1e-07
# epochs: 166, loss: 0.001871, lr:  1e-07
# epochs: 167, loss: 0.001869, lr:  1e-07
# epochs: 168, loss: 0.001862, lr:  1e-07
# epochs: 169, loss: 0.001859, lr:  1e-07
# epochs: 170, loss: 0.001861, lr:  1e-07
# epochs: 171, loss: 0.001860, lr:  1e-07
# epochs: 172, loss: 0.001854, lr:  1e-07
# epochs: 173, loss: 0.001850, lr:  1e-07
# epochs: 174, loss: 0.001852, lr:  1e-07
# epochs: 175, loss: 0.001845, lr:  1e-07
# epochs: 176, loss: 0.001833, lr:  1e-07
# epochs: 177, loss: 0.001838, lr:  1e-07
# epochs: 178, loss: 0.001829, lr:  1e-07
# epochs: 179, loss: 0.001840, lr:  1e-07
# epochs: 180, loss: 0.001821, lr:  1e-07
# epochs: 181, loss: 0.001822, lr:  1e-07
# epochs: 182, loss: 0.001828, lr:  1e-07
# epochs: 183, loss: 0.001820, lr:  1e-07
# epochs: 184, loss: 0.001829, lr:  1e-07
# epochs: 185, loss: 0.001809, lr:  1e-07
# epochs: 186, loss: 0.001802, lr:  1e-07
# epochs: 187, loss: 0.001802, lr:  1e-07
# epochs: 188, loss: 0.001796, lr:  1e-07
# epochs: 189, loss: 0.001804, lr:  1e-07
# epochs: 190, loss: 0.001809, lr:  1e-07
# epochs: 191, loss: 0.001795, lr:  1e-07
# epochs: 192, loss: 0.001793, lr:  1e-07
# epochs: 193, loss: 0.001789, lr:  1e-07
# epochs: 194, loss: 0.001774, lr:  1e-07
# epochs: 195, loss: 0.001773, lr:  1e-07
# epochs: 196, loss: 0.001775, lr:  1e-07
# epochs: 197, loss: 0.001770, lr:  1e-07
# epochs: 198, loss: 0.001763, lr:  1e-07
# epochs: 199, loss: 0.001763, lr:  1e-07
# epochs: 200, loss: 0.001764, lr:  1e-07
# epochs: 201, loss: 0.001764, lr:  1e-07
# epochs: 202, loss: 0.001750, lr:  1e-07
# epochs: 203, loss: 0.001742, lr:  1e-07
# epochs: 204, loss: 0.001749, lr:  1e-07
# epochs: 205, loss: 0.001742, lr:  1e-07
# epochs: 206, loss: 0.001744, lr:  1e-07
# epochs: 207, loss: 0.001737, lr:  1e-07
# epochs: 208, loss: 0.001745, lr:  1e-07
# epochs: 209, loss: 0.001735, lr:  1e-07
# epochs: 210, loss: 0.001727, lr:  1e-07
# epochs: 211, loss: 0.001729, lr:  1e-07
# epochs: 212, loss: 0.001724, lr:  1e-07
# epochs: 213, loss: 0.001726, lr:  1e-07
# epochs: 214, loss: 0.001718, lr:  1e-07
# epochs: 215, loss: 0.001713, lr:  1e-07
# epochs: 216, loss: 0.001712, lr:  1e-07
# epochs: 217, loss: 0.001712, lr:  1e-07
# epochs: 218, loss: 0.001705, lr:  1e-07
# epochs: 219, loss: 0.001707, lr:  1e-07
# epochs: 220, loss: 0.001700, lr:  1e-07
# epochs: 221, loss: 0.001700, lr:  1e-07
# epochs: 222, loss: 0.001697, lr:  1e-07
# epochs: 223, loss: 0.001689, lr:  1e-07
# epochs: 224, loss: 0.001693, lr:  1e-07
# epochs: 225, loss: 0.001698, lr:  1e-07
# epochs: 226, loss: 0.001686, lr:  1e-07
# epochs: 227, loss: 0.001684, lr:  1e-07
# epochs: 228, loss: 0.001689, lr:  1e-07
# epochs: 229, loss: 0.001682, lr:  1e-07
# epochs: 230, loss: 0.001684, lr:  1e-07
# epochs: 231, loss: 0.001682, lr:  1e-07
# epochs: 232, loss: 0.001679, lr:  1e-07
# epochs: 233, loss: 0.001672, lr:  1e-07
# epochs: 234, loss: 0.001680, lr:  1e-07
# epochs: 235, loss: 0.001671, lr:  1e-07
# epochs: 236, loss: 0.001660, lr:  1e-07
# epochs: 237, loss: 0.001664, lr:  1e-07
# epochs: 238, loss: 0.001662, lr:  1e-07
# epochs: 239, loss: 0.001655, lr:  1e-07
# epochs: 240, loss: 0.001653, lr:  1e-07
# epochs: 241, loss: 0.001654, lr:  1e-07
# epochs: 242, loss: 0.001659, lr:  1e-07
# epochs: 243, loss: 0.001653, lr:  1e-07
# epochs: 244, loss: 0.001648, lr:  1e-07
# epochs: 245, loss: 0.001646, lr:  1e-07
# epochs: 246, loss: 0.001645, lr:  1e-07
# epochs: 247, loss: 0.001643, lr:  1e-07
# epochs: 248, loss: 0.001644, lr:  1e-07
# epochs: 249, loss: 0.001653, lr:  1e-07
# epochs: 250, loss: 0.001645, lr:  1e-07
# epochs: 251, loss: 0.001649, lr:  1e-07
# epochs: 252, loss: 0.001633, lr:  1e-07
# epochs: 253, loss: 0.001634, lr:  1e-07
# epochs: 254, loss: 0.001636, lr:  1e-07
# epochs: 255, loss: 0.001633, lr:  1e-07
# epochs: 256, loss: 0.001633, lr:  1e-07
# epochs: 257, loss: 0.001627, lr:  1e-07
# epochs: 258, loss: 0.001626, lr:  1e-07
# epochs: 259, loss: 0.001626, lr:  1e-07
# epochs: 260, loss: 0.001639, lr:  1e-07
# epochs: 261, loss: 0.001623, lr:  1e-07
# epochs: 262, loss: 0.001616, lr:  1e-07
# epochs: 263, loss: 0.001616, lr:  1e-07
# epochs: 264, loss: 0.001618, lr:  1e-07
# epochs: 265, loss: 0.001619, lr:  1e-07
# epochs: 266, loss: 0.001612, lr:  1e-07
# epochs: 267, loss: 0.001615, lr:  1e-07
# epochs: 268, loss: 0.001613, lr:  1e-07
# epochs: 269, loss: 0.001612, lr:  1e-07
# epochs: 270, loss: 0.001611, lr:  1e-07
# epochs: 271, loss: 0.001607, lr:  1e-07
# epochs: 272, loss: 0.001608, lr:  1e-07
# epochs: 273, loss: 0.001604, lr:  1e-07
# epochs: 274, loss: 0.001602, lr:  1e-07
# epochs: 275, loss: 0.001604, lr:  1e-07
# epochs: 276, loss: 0.001610, lr:  1e-07
# epochs: 277, loss: 0.001598, lr:  1e-07
# epochs: 278, loss: 0.001600, lr:  1e-07
# epochs: 279, loss: 0.001604, lr:  1e-07
# epochs: 280, loss: 0.001603, lr:  1e-07
# epochs: 281, loss: 0.001604, lr:  1e-07
# epochs: 282, loss: 0.001595, lr:  1e-07
# epochs: 283, loss: 0.001594, lr:  1e-07
# epochs: 284, loss: 0.001598, lr:  1e-07
# epochs: 285, loss: 0.001595, lr:  1e-07
# epochs: 286, loss: 0.001591, lr:  1e-07
# epochs: 287, loss: 0.001590, lr:  1e-07
# epochs: 288, loss: 0.001590, lr:  1e-07
# epochs: 289, loss: 0.001587, lr:  1e-07
# epochs: 290, loss: 0.001593, lr:  1e-07
# epochs: 291, loss: 0.001595, lr:  1e-07
# epochs: 292, loss: 0.001589, lr:  1e-07
# epochs: 293, loss: 0.001583, lr:  1e-07
# epochs: 294, loss: 0.001583, lr:  1e-07
# epochs: 295, loss: 0.001581, lr:  1e-07
# epochs: 296, loss: 0.001589, lr:  1e-07
# epochs: 297, loss: 0.001586, lr:  1e-07
# epochs: 298, loss: 0.001581, lr:  1e-07
# epochs: 299, loss: 0.001581, lr:  1e-07
# epochs: 300, loss: 0.001576, lr:  1e-08
# epochs: 301, loss: 0.001573, lr:  1e-08
# epochs: 302, loss: 0.001572, lr:  1e-08
# epochs: 303, loss: 0.001572, lr:  1e-08
# epochs: 304, loss: 0.001572, lr:  1e-08
# epochs: 305, loss: 0.001572, lr:  1e-08
# epochs: 306, loss: 0.001572, lr:  1e-08
# epochs: 307, loss: 0.001572, lr:  1e-08
# epochs: 308, loss: 0.001572, lr:  1e-08
# epochs: 309, loss: 0.001571, lr:  1e-08
# epochs: 310, loss: 0.001571, lr:  1e-08
# epochs: 311, loss: 0.001571, lr:  1e-08
# epochs: 312, loss: 0.001571, lr:  1e-08
# epochs: 313, loss: 0.001571, lr:  1e-08
# epochs: 314, loss: 0.001571, lr:  1e-08
# epochs: 315, loss: 0.001571, lr:  1e-08
# epochs: 316, loss: 0.001571, lr:  1e-08
# epochs: 317, loss: 0.001571, lr:  1e-08
# epochs: 318, loss: 0.001571, lr:  1e-08
# epochs: 319, loss: 0.001571, lr:  1e-08
# epochs: 320, loss: 0.001571, lr:  1e-08
# epochs: 321, loss: 0.001571, lr:  1e-08
# epochs: 322, loss: 0.001570, lr:  1e-08
# epochs: 323, loss: 0.001571, lr:  1e-08
# epochs: 324, loss: 0.001571, lr:  1e-08
# epochs: 325, loss: 0.001571, lr:  1e-08
# epochs: 326, loss: 0.001570, lr:  1e-08
# epochs: 327, loss: 0.001570, lr:  1e-08
# epochs: 328, loss: 0.001570, lr:  1e-08
# epochs: 329, loss: 0.001570, lr:  1e-08
# epochs: 330, loss: 0.001570, lr:  1e-08
# epochs: 331, loss: 0.001570, lr:  1e-08
# epochs: 332, loss: 0.001570, lr:  1e-08
# epochs: 333, loss: 0.001570, lr:  1e-08
# epochs: 334, loss: 0.001570, lr:  1e-08
# epochs: 335, loss: 0.001569, lr:  1e-08
# epochs: 336, loss: 0.001570, lr:  1e-08
# epochs: 337, loss: 0.001569, lr:  1e-08
# epochs: 338, loss: 0.001570, lr:  1e-08
# epochs: 339, loss: 0.001569, lr:  1e-08
# epochs: 340, loss: 0.001569, lr:  1e-08
# epochs: 341, loss: 0.001569, lr:  1e-08
# epochs: 342, loss: 0.001569, lr:  1e-08
# epochs: 343, loss: 0.001569, lr:  1e-08
# epochs: 344, loss: 0.001569, lr:  1e-08
# epochs: 345, loss: 0.001569, lr:  1e-08
# epochs: 346, loss: 0.001568, lr:  1e-08
# epochs: 347, loss: 0.001569, lr:  1e-08
# epochs: 348, loss: 0.001568, lr:  1e-08
# epochs: 349, loss: 0.001568, lr:  1e-08
# epochs: 350, loss: 0.001568, lr:  1e-08
# epochs: 351, loss: 0.001568, lr:  1e-08
# epochs: 352, loss: 0.001568, lr:  1e-08
# epochs: 353, loss: 0.001568, lr:  1e-08
# epochs: 354, loss: 0.001568, lr:  1e-08
# epochs: 355, loss: 0.001568, lr:  1e-08
# epochs: 356, loss: 0.001568, lr:  1e-08
# epochs: 357, loss: 0.001567, lr:  1e-08
# epochs: 358, loss: 0.001568, lr:  1e-08
# epochs: 359, loss: 0.001567, lr:  1e-08
# epochs: 360, loss: 0.001568, lr:  1e-08
# epochs: 361, loss: 0.001567, lr:  1e-08
# epochs: 362, loss: 0.001567, lr:  1e-08
# epochs: 363, loss: 0.001567, lr:  1e-08
# epochs: 364, loss: 0.001567, lr:  1e-08
# epochs: 365, loss: 0.001567, lr:  1e-08
# epochs: 366, loss: 0.001567, lr:  1e-08
# epochs: 367, loss: 0.001567, lr:  1e-08
# epochs: 368, loss: 0.001567, lr:  1e-08
# epochs: 369, loss: 0.001567, lr:  1e-08
# epochs: 370, loss: 0.001566, lr:  1e-08
# epochs: 371, loss: 0.001567, lr:  1e-08
# epochs: 372, loss: 0.001567, lr:  1e-08
# epochs: 373, loss: 0.001566, lr:  1e-08
# epochs: 374, loss: 0.001566, lr:  1e-08
# epochs: 375, loss: 0.001566, lr:  1e-08
# epochs: 376, loss: 0.001566, lr:  1e-08
# epochs: 377, loss: 0.001566, lr:  1e-08
# epochs: 378, loss: 0.001566, lr:  1e-08
# epochs: 379, loss: 0.001566, lr:  1e-08
# epochs: 380, loss: 0.001566, lr:  1e-08
# epochs: 381, loss: 0.001566, lr:  1e-08
# epochs: 382, loss: 0.001565, lr:  1e-08
# epochs: 383, loss: 0.001566, lr:  1e-08
# epochs: 384, loss: 0.001566, lr:  1e-08
# epochs: 385, loss: 0.001565, lr:  1e-08
# epochs: 386, loss: 0.001565, lr:  1e-08
# epochs: 387, loss: 0.001565, lr:  1e-08
# epochs: 388, loss: 0.001565, lr:  1e-08
# epochs: 389, loss: 0.001565, lr:  1e-08
# epochs: 390, loss: 0.001565, lr:  1e-08
# epochs: 391, loss: 0.001565, lr:  1e-08
# epochs: 392, loss: 0.001565, lr:  1e-08
# epochs: 393, loss: 0.001565, lr:  1e-08
# epochs: 394, loss: 0.001565, lr:  1e-08
# epochs: 395, loss: 0.001565, lr:  1e-08
# epochs: 396, loss: 0.001564, lr:  1e-08
# epochs: 397, loss: 0.001565, lr:  1e-08
# epochs: 398, loss: 0.001564, lr:  1e-08
# epochs: 399, loss: 0.001564, lr:  1e-08
# epochs: 400, loss: 0.001565, lr:  1e-08
# epochs: 401, loss: 0.001564, lr:  1e-08
# epochs: 402, loss: 0.001564, lr:  1e-08
# epochs: 403, loss: 0.001564, lr:  1e-08
# epochs: 404, loss: 0.001564, lr:  1e-08
# epochs: 405, loss: 0.001564, lr:  1e-08
# epochs: 406, loss: 0.001564, lr:  1e-08
# epochs: 407, loss: 0.001564, lr:  1e-08
# epochs: 408, loss: 0.001564, lr:  1e-08
# epochs: 409, loss: 0.001564, lr:  1e-08
# epochs: 410, loss: 0.001563, lr:  1e-08
# epochs: 411, loss: 0.001563, lr:  1e-08
# epochs: 412, loss: 0.001563, lr:  1e-08
# epochs: 413, loss: 0.001563, lr:  1e-08
# epochs: 414, loss: 0.001563, lr:  1e-08
# epochs: 415, loss: 0.001563, lr:  1e-08
# epochs: 416, loss: 0.001563, lr:  1e-08
# epochs: 417, loss: 0.001563, lr:  1e-08
# epochs: 418, loss: 0.001563, lr:  1e-08
# epochs: 419, loss: 0.001563, lr:  1e-08
# epochs: 420, loss: 0.001563, lr:  1e-08
# epochs: 421, loss: 0.001563, lr:  1e-08
# epochs: 422, loss: 0.001563, lr:  1e-08
# epochs: 423, loss: 0.001563, lr:  1e-08
# epochs: 424, loss: 0.001563, lr:  1e-08
# epochs: 425, loss: 0.001562, lr:  1e-08
# epochs: 426, loss: 0.001562, lr:  1e-08
# epochs: 427, loss: 0.001562, lr:  1e-08
# epochs: 428, loss: 0.001562, lr:  1e-08
# epochs: 429, loss: 0.001562, lr:  1e-08
# epochs: 430, loss: 0.001562, lr:  1e-08
# epochs: 431, loss: 0.001562, lr:  1e-08
# epochs: 432, loss: 0.001562, lr:  1e-08
# epochs: 433, loss: 0.001562, lr:  1e-08
# epochs: 434, loss: 0.001562, lr:  1e-08
# epochs: 435, loss: 0.001562, lr:  1e-08
# epochs: 436, loss: 0.001562, lr:  1e-08
# epochs: 437, loss: 0.001562, lr:  1e-08
# epochs: 438, loss: 0.001561, lr:  1e-08
# epochs: 439, loss: 0.001561, lr:  1e-08
# epochs: 440, loss: 0.001561, lr:  1e-08
# epochs: 441, loss: 0.001561, lr:  1e-08
# epochs: 442, loss: 0.001561, lr:  1e-08
# epochs: 443, loss: 0.001561, lr:  1e-08
# epochs: 444, loss: 0.001561, lr:  1e-08
# epochs: 445, loss: 0.001561, lr:  1e-08
# epochs: 446, loss: 0.001561, lr:  1e-08
# epochs: 447, loss: 0.001561, lr:  1e-08
# epochs: 448, loss: 0.001561, lr:  1e-08
# epochs: 449, loss: 0.001561, lr:  1e-08

# %%
# save_path = 'patch_tst_lstm_block_kospi_random_modeld_' + str(model_d) + '_seqlen' + str(seq_len) + '_layaers' + str(n_layers) + '_nhead' + str(n_head) + '.pt'
# # save_path = 'kospi_only.pt'
# torch.save(model.state_dict(), save_path)
# print(save_path)
df_loss
# Out:
#      epoch      loss
# 0      0.0  3.097016
# 1      1.0  1.565319
# 2      2.0  1.134880
# 3      3.0  0.890906
# 4      4.0  0.745456
# ..     ...       ...
# 445  445.0  0.001561
# 446  446.0  0.001561
# 447  447.0  0.001561
# 448  448.0  0.001561
# 449  449.0  0.001561
#
# [450 rows x 2 columns]

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_loss.loc[20: , 'epoch'], df_loss.loc[20: , 'loss'])
plt.show()

# %%
test_result = pd.DataFrame(columns=['pred', 'pred_rescale', 'real'])
num = 0
min = scale_params.loc['min', 'Adj Close']
max = scale_params.loc['max', 'Adj Close']
with torch.no_grad():
    for _, data in enumerate(test_dataloader):
        inputs = data[0].to(device).float()
        # outputs = data[1].to(device).float()
        outputs = data[1]

        pred = model(inputs)
        for i in range(len(pred)):
            pred_ = pred.detach().cpu().numpy()[i][0]
            pred_scaled = pred_ * (max - min) + min
            out_scaled = outputs.numpy()[i] * (max - min) + min
            test_result.loc[num] = [pred_, pred_scaled, out_scaled[0]]
            num += 1

# %%
test_result.to_csv('./test_result_patch_tft_lstm_block.csv')
test_result
# Out:
#          pred  pred_rescale         real
# 0    0.833984   2802.977117  2591.260010
# 1    0.832195   2797.564014  2570.870117
# 2    0.831031   2794.042612  2525.639893
# 3    0.829078   2788.134540  2519.850098
# 4    0.826257   2779.599976  2504.500000
# ..        ...           ...          ...
# 187  0.864395   2894.976432  2723.459961
# 188  0.864587   2895.558133  2721.810059
# 189  0.866430   2901.132079  2687.600098
# 190  0.865172   2897.327760  2722.989990
# 191  0.866427   2901.122883  2722.850098
#
# [192 rows x 3 columns]

# %%
plt.figure(figsize=(20, 5))
# plt.plot(idx_num, test_result['pred'], label='pred')
# plt.plot(range(len(test_result)), test_result['pred_rescale'], label='pred')
plt.scatter(range(len(test_result)), test_result['pred_rescale'], label='pred')
plt.plot(range(len(test_result)), test_result['real'], 'g--', label='real')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 5))
# plt.plot(idx_num, test_result['pred'], label='pred')
plt.scatter(range(20), test_result.iloc[-20: , 1], label='pred')
plt.plot(range(20), test_result.iloc[-20: , 2], 'g--', label='real')
# plt.scatter(range(len(test_result)), test_result['pred'], label='pred')
# plt.plot(range(len(test_result)), test_result['real'], 'g--', label='real')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 5))
# plt.plot(idx_num, test_result['pred'], label='pred')
plt.scatter(range(20), test_result.iloc[-50:-30 , 1], label='pred')
plt.plot(range(20), test_result.iloc[-50:-30 , 2], 'g--', label='real')
# plt.scatter(range(len(test_result)), test_result['pred'], label='pred')
# plt.plot(range(len(test_result)), test_result['real'], 'g--', label='real')
plt.legend()
plt.show()

# %%
df_ma = test_result.copy()
df_ma['sma_pred_5d'] = df_ma['pred_rescale'].rolling(5).mean()
df_ma['sma_pred_10d'] = df_ma['pred_rescale'].rolling(10).mean()
df_ma['sma_pred_20d'] = df_ma['pred_rescale'].ewm(20).mean()
df_ma['sma_real_5d'] = df_ma['real'].rolling(5).mean()
df_ma['sma_real_10d'] = df_ma['real'].rolling(10).mean()
df_ma['sma_real_20d'] = df_ma['real'].rolling(20).mean()
df_ma['ewm_pred_5d'] = df_ma['pred_rescale'].ewm(5).mean()
df_ma['ewm_pred_10d'] = df_ma['pred_rescale'].ewm(10).mean()
df_ma['ewm_pred_20d'] = df_ma['pred_rescale'].ewm(20).mean()
df_ma['ewm_real_5d'] = df_ma['real'].ewm(5).mean()
df_ma['ewm_real_10d'] = df_ma['real'].ewm(10).mean()
df_ma['ewm_real_20d'] = df_ma['real'].ewm(20).mean()
df_ma = df_ma.dropna()
df_ma
# Out:
#          pred  pred_rescale         real  sma_pred_5d  sma_pred_10d  \
# 19   0.819717   2759.816905  2547.679932  2757.928522   2756.627483
# 20   0.818963   2757.534638  2556.879883  2758.306068   2756.338833
# 21   0.818534   2756.237621  2536.580078  2758.220093   2756.197951
# 22   0.818684   2756.689675  2534.699951  2758.025496   2756.467020
# 23   0.818150   2755.074940  2572.889893  2757.070756   2756.816257
# ..        ...           ...          ...          ...           ...
# 187  0.864395   2894.976432  2723.459961  2888.741951   2880.504513
# 188  0.864587   2895.558133  2721.810059  2891.823885   2883.568903
# 189  0.866430   2901.132079  2687.600098  2895.364762   2886.515744
# 190  0.865172   2897.327760  2722.989990  2896.290940   2888.754717
# 191  0.866427   2901.122883  2722.850098  2898.023457   2891.297217
#
#      sma_pred_20d  sma_real_5d  sma_real_10d  sma_real_20d  ewm_pred_5d  \
# 19    2764.048477  2565.202002   2560.277979   2545.087988  2759.112878
# 20    2763.564616  2559.667969   2561.624976   2543.368982  2758.843993
# 21    2763.034487  2550.547998   2560.066992   2541.654480  2758.401584
# 22    2762.586502  2544.819971   2557.414990   2542.107483  2758.111893
# 23    2762.068054  2549.745947   2559.076978   2544.759473  2757.599286
# ..            ...          ...           ...           ...          ...
# 187   2866.893040  2733.479980   2730.976978   2699.853491  2882.463110
# 188   2868.258179  2727.241992   2728.652979   2704.471997  2884.645614
# 189   2869.823751  2719.837988   2726.198999   2707.701001  2887.393358
# 190   2871.133583  2716.008008   2725.735010   2710.063000  2889.049092
# 191   2872.561767  2715.742041   2725.299023   2714.774500  2891.061390
#
#      ewm_pred_10d  ewm_pred_20d  ewm_real_5d  ewm_real_10d  ewm_real_20d
# 19    2761.649868   2764.048477  2554.978804   2550.852041   2547.991777
# 20    2761.217303   2763.564616  2555.302691   2551.485646   2548.652003
# 21    2760.701204   2763.034487  2552.124689   2549.940818   2547.778565
# 22    2760.290672   2762.586502  2549.176057   2548.381098   2546.855130
# 23    2759.762936   2762.068054  2553.178713   2550.860938   2548.652046
# ..            ...           ...          ...           ...           ...
# 187   2878.516068   2866.893040  2722.007220   2709.457601   2693.483271
# 188   2880.065346   2868.258179  2721.974360   2710.580551   2694.832299
# 189   2881.980504   2869.823751  2716.245316   2708.491419   2694.487876
# 190   2883.375709   2871.133583  2717.369429   2709.809471   2695.845241
# 191   2884.989089   2872.561767  2718.282873   2710.994983   2697.131297
#
# [173 rows x 15 columns]

# %%
plt.figure(figsize=(20, 5))
plt.plot(range(len(df_ma)), df_ma['sma_pred_5d'], 'r-', label='sma_pred_5d')
plt.plot(range(len(df_ma)), df_ma['sma_pred_10d'], 'g-', label='sma_pred_10d')
plt.plot(range(len(df_ma)), df_ma['sma_pred_20d'], 'b-', label='sma_pred_20d')
plt.plot(range(len(df_ma)), df_ma['sma_real_5d'], 'r--', label='sma_real_5d')
plt.plot(range(len(df_ma)), df_ma['sma_real_10d'], 'g--', label='sma_real_10d')
plt.plot(range(len(df_ma)), df_ma['sma_real_20d'], 'b--', label='sma_real_20d')
plt.plot(range(len(df_ma)), df_ma['real'], 'k-.', label='real')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.plot(range(len(df_ma)), df_ma['sma_pred_5d'], 'r-', label='sma_pred_5d')
plt.plot(range(len(df_ma)), df_ma['sma_pred_10d'], 'g-', label='sma_pred_10d')
plt.plot(range(len(df_ma)), df_ma['sma_pred_20d'], 'b-', label='sma_pred_20d')
# plt.plot(range(len(df_ma)), df_ma['sma_real_5d'], 'r--', label='sma_real_5d')
# plt.plot(range(len(df_ma)), df_ma['sma_real_10d'], 'g--', label='sma_real_10d')
# plt.plot(range(len(df_ma)), df_ma['sma_real_20d'], 'b--', label='sma_real_20d')
plt.plot(range(len(df_ma)), df_ma['real'], 'k-.', label='real')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.plot(range(len(df_ma)), df_ma['ewm_pred_5d'], 'r-', label='ewm_pred_5d')
plt.plot(range(len(df_ma)), df_ma['ewm_pred_10d'], 'g-', label='ewm_pred_10d')
plt.plot(range(len(df_ma)), df_ma['ewm_pred_20d'], 'b-', label='ewm_pred_20d')
plt.plot(range(len(df_ma)), df_ma['ewm_real_5d'], 'r--', label='ewm_real_5d')
plt.plot(range(len(df_ma)), df_ma['ewm_real_10d'], 'g--', label='ewm_real_10d')
plt.plot(range(len(df_ma)), df_ma['ewm_real_20d'], 'b--', label='ewm_real_20d')
plt.plot(range(len(df_ma)), df_ma['real'], 'k-.', label='real')
plt.legend()
plt.show()

# %% [markdown]
# ## 11. evaluation metrics
# MAPE, MSE

# %%
mse = mean_squared_error(test_result['real'], test_result['pred_rescale'])
mape = mean_absolute_percentage_error(test_result['real'], test_result['pred_rescale'])
print(f'MSE: {mse:.4f}, MAPE: {mape:.4f}')
# Out:
# MSE: 40314.1545, MAPE: 0.0753

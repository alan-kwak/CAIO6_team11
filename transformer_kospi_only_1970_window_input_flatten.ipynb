# %% [markdown]
# ## 0. Import libraries

# %%
import torch
import pandas as pd
import numpy as np
import math, copy, time
import torch.nn as nn
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset 
from torch.optim import Adam
import tqdm
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error

# %% [markdown]
# ## 1. Load Data

# %%
df = pd.read_csv('./kospi.csv')
df.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 6758  2024-05-17  2751.469971  2752.169922  2724.620117  2724.620117
# 6759  2024-05-20  2741.239990  2756.409912  2734.639893  2742.139893
# 6760  2024-05-21  2733.030029  2734.479980  2719.739990  2724.179932
# 6761  2024-05-22  2723.459961  2733.070068  2707.870117  2723.459961
# 6762  2024-05-23  2719.030029  2734.270020  2704.000000  2721.810059
#
#         Adj Close  Volume
# 6758  2724.620117  575900
# 6759  2742.139893  582100
# 6760  2724.179932  560800
# 6761  2723.459961  484700
# 6762  2721.810059  428079

# %%
df['kospi_shift'] = df['Adj Close'].shift(-1)
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  1996-12-11  705.989990  709.479980  704.429993  704.679993  704.679993
# 1  1996-12-12  705.109985  706.010010  688.739990  689.380005  689.380005
# 2  1996-12-13  690.440002  695.719971  677.640015  689.070007  689.070007
# 3  1996-12-16  686.969971  686.969971  667.710022  673.919983  673.919983
# 4  1996-12-17  675.349976  680.090027  660.390015  663.349976  663.349976
#
#    Volume  kospi_shift
# 0   28000   689.380005
# 1   25900   689.070007
# 2   26500   673.919983
# 3   22800   663.349976
# 4   31600   661.390015

# %%
col_names = df.columns.values
print(col_names)
# Out:
# ['Date' 'Open' 'High' 'Low' 'Close' 'Adj Close' 'Volume' 'kospi_shift']

# %%
# global variables and hyperparameter
IN_DIM = 128
DAY_INT = 1
BATCH_SIZE = 64
SCALER = 'MINMAX'   # 'NORMAL'
# SCALER = 'NORMAL'   # 'NORMAL'
TRAIN_TEST_SPLIT = 0.95
LR = 1e-4

# %% [markdown]
# ## 2. Split data train and test

# %%
# train test split
df_train = df.iloc[:int(len(df) * TRAIN_TEST_SPLIT), :]
df_test = df.iloc[int(len(df) * TRAIN_TEST_SPLIT): , :]
# print(df_train.tail())
# print(df_test.head())
scale_params = pd.DataFrame(index=['mean', 'var', 'max', 'min'])
for i in col_names[1:]:
    scale_params[i] = [df_train[i].mean(), df_train[i].var(), df_train[i].max(), df_train[i].min()]
scale_params
# Out:
#                Open           High            Low          Close  \
# mean    1567.013038    1576.568176    1555.123470    1566.202960
# var   516480.085060  518612.861169  512764.718865  515801.468025
# max     3305.459961    3316.080078    3295.439941    3305.209961
# min      283.410004     291.010010     277.369995     280.000000
#
#           Adj Close        Volume    kospi_shift
# mean    1566.202960  4.352795e+05    1566.444445
# var   515801.468025  7.428265e+10  515759.929164
# max     3305.209961  3.455500e+06    3305.209961
# min      280.000000  1.390000e+04     280.000000

# %%
# scaling
train_data = pd.DataFrame()
test_data = pd.DataFrame()
if SCALER == 'MINMAX':
    for i in col_names[1:]:
        train_data[i] = df_train[i].apply(lambda x: (x - scale_params.loc['min', i])/(scale_params.loc['max', i] - scale_params.loc['min', i]))
        test_data[i] = df_test[i].apply(lambda x: (x - scale_params.loc['min', i])/(scale_params.loc['max', i] - scale_params.loc['min', i]))
elif SCALER == 'NORMAL':
    for i in col_names[1:]:
        train_data[i] = df_train[i].apply(lambda x: (x - scale_params.loc['mean', i])/scale_params.loc['var', i])
        test_data[i] = df_test[i].apply(lambda x: (x - scale_params.loc['mean', i])/scale_params.loc['var', i])
test_data.tail()
# Out:
#           Open      High       Low     Close  Adj Close    Volume  kospi_shift
# 6758  0.816684  0.813588  0.810866  0.808083   0.808083  0.163296     0.813874
# 6759  0.813299  0.814989  0.814186  0.813874   0.813874  0.165098     0.807937
# 6760  0.810582  0.807740  0.809249  0.807937   0.807937  0.158909     0.807699
# 6761  0.807415  0.807274  0.805316  0.807699   0.807699  0.136797     0.807154
# 6762  0.805950  0.807671  0.804034  0.807154   0.807154  0.120345          NaN

# %%
class StockDataset(Dataset):
    def __init__(self, y, input_window=128, output_window=1, stride=1):
        #총 데이터의 개수
        L = y.shape[0]
        #stride씩 움직일 때 생기는 총 sample의 개수
        num_samples = (L - input_window - output_window) // stride + 1
        start_pos = (L - input_window - output_window) % stride
        iter_times = (L - input_window - output_window) // stride + 1
        print(y.shape, num_samples, iter_times, start_pos, L)

        #input과 output
        X = np.zeros([input_window, num_samples])
        Y = np.zeros([output_window, num_samples])

        for i in np.arange(num_samples):
            start_x = start_pos + i * stride
            end_x = start_x + input_window
            X[:,i] = y[start_x:end_x]

            # end_y = start_y + output_window
            # print(i, start_x, end_x)
            Y[:,i] = y[end_x: end_x + output_window]
        # print(X.shape, Y.shape)
        X = X.reshape(X.shape[0], X.shape[1], 1).transpose((1,0,2))
        Y = Y.reshape(Y.shape[0], Y.shape[1], 1).transpose((1,0,2))
        print(X.shape, Y.shape)
        self.x = X
        self.y = Y
        
        self.len = len(X)
    def __getitem__(self, i):
        return self.x[i], self.y[i]
    def __len__(self):
        return self.len

# %% [markdown]
# ### 3. create dataloader

# %%
train_dataset = StockDataset(train_data['Adj Close'], 128, 1, 1)
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

test_dataset = StockDataset(test_data['Adj Close'], 128, 1, 1)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
a1 = next(iter(train_dataset))
print(len(train_dataloader), len(train_dataloader.dataset), a1[0].shape, a1[1].shape)
# print(next(iter(test_dataset)))
# Out:
# (6424,) 6296 6296 0 6424
# (6296, 128, 1) (6296, 1, 1)
# (339,) 211 211 0 339
# (211, 128, 1) (211, 1, 1)
# 99 6296 (128, 1) (1, 1)

# %% [markdown]
# ## 4. Make a Transformer model

# %% [markdown]
# In this sections, we will implement the building blocks of the transformer: [Positional encoding](#1a), [Multi-head attention](#1b) and [Position wise feedforward network](#1c)

# %%
4938/64
# Out:
# 77.15625

# %% [markdown]
# ### a. Sinusoidal Positional Encoding
# <a id='1a'></a>
# In this section, we will implement sinusoidal positional encoding
#
# $$\begin{align}
# PE(pos, 2i) &= \sin \left( pos / 10000^{2i / d_{model}} \right)  \\
# PE(pos, 2i+1) &= \cos \left( pos / 10000^{2i / d_{model}} \right)
# \end{align}$$

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model , max_len, device):
        """
        d_model: dimension of model
        max_len: maximum sequence length
        device: 'cuda' or 'cpu'
        """
        super().__init__()
        self.encoding = torch.zeros(max_len, d_model, device=device)
        self.encoding.required_grad = False

        pos = torch.arange(0, max_len, device=device)
        pos = pos.float().unsqueeze(dim=1) # [a, b, ...] -> [[a], [b], [c], ...]

        _2i = torch.arange(0, d_model, step=2, device=device) # i is d_model and step=2 means 2*i
        self.encoding[:, 0::2] = torch.sin(pos / (10000 ** (_2i / d_model)))
        self.encoding[:, 1::2] = torch.cos(pos / (10000 ** (_2i / d_model)))
    
    def forward(self, x):
        # x: Tensor, shape ``[batch_size, seq_len, embedding_dim]
        # d_model = 512
        # print(x.size())
        batch_size, seq_len = x.size()[:2]
        pe = self.encoding[:seq_len, :]
        return pe

# %%
sample_pos_encoding = PositionalEncoding(128, 50, device='cpu')

plt.pcolormesh(sample_pos_encoding.encoding.numpy(), cmap='RdBu')
plt.xlabel('Depth')
plt.ylabel('Position')
plt.colorbar()
plt.show()

# %% [markdown]
# ### b. Scaled dot product attention

# %% [markdown]
# __Scaled dot product:__
# ![picture](./assets/transformer_2.png)

# %%
class ScaleDotProductAttention(nn.Module):
    """
    Query: given setence
    Key: same with query(encoder)
    Value: same with key
    """

    def __init__(self):
        super().__init__()
        self.softmax = nn.Softmax(dim=-1)
    
    def forward(self, q, k, v, mask=None, e=1e-12):
        # input: 4 dimension tensor
        # [batch_size, head, length, d_tensor]
        batch_size, head, length, d_tensor = k.size()

        # 1. q @ K.T
        k_t = k.transpose(2, 3)
        # print(q.size(), k_t.size())
        score = (q @ k_t) / math.sqrt(d_tensor)

        # 2. masking(decoder self attention only)
        if mask is not None:
            score = score.masked_fill(mask == 0, -10000)
        
        # 3. pass them softmax to [0, 1] range
        score = self.softmax(score)

        # 4. multiply with value
        v = score @ v

        return v, score

# %% [markdown]
# ### c. MultiheadAttention
# <a id='1b'></a>
# Equation:
#
# $$\begin{align} \text{MultiHead}(Q, K, V) &= \text{Concat}(head_1, ...., head_h) W^O \\
# \text{where head}_i &= \text{Attention} \left( QW^Q_i, K W^K_i, VW^v_i \right)
# \end{align}$$

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, n_head):
        super().__init__()
        self.n_head = n_head
        self.attention = ScaleDotProductAttention()
        self.w_q = nn.Linear(d_model, d_model)
        self.w_k = nn.Linear(d_model, d_model)
        self.w_v = nn.Linear(d_model, d_model)
        self.w_concat = nn.Linear(d_model, d_model)
    
    def forward(self, q, k, v, mask=None):
        # 1. dot product with weight matrices
        q, k, v = self.w_q(q), self.w_k(k), self.w_v(v)

        # 2. split tensor by heads
        q, k, v = self.split(q), self.split(k), self.split(v)

        # 3. scale dot product
        out, attention = self.attention(q, k, v, mask=mask)

        # 4. concat and pass to linear layer
        out = self.concat(out)
        out = self.w_concat(out)

        return out
    
    def split(self, tensor):
        '''
        split tensor by heads
        tensor: [batch_size, seq_len, d_model]
        return: [batch_size, head, seq_len, d_tensor] --- d_model = head * d_tensor
        '''
        batch_size, seq_len, d_model = tensor.size()
        d_tensor = d_model // self.n_head
        tensor = tensor.view(batch_size, seq_len, self.n_head, d_tensor).transpose(1, 2)
        # split by # of heads
        return tensor
    
    def concat(self, tensor):
        '''
        inverse of split(tensor)
        tensor: [batch_size, head, seq_len, d_tensor]
        return: [batch_size, seq_len, d_model]
        '''
        batch_size, head, seq_len, d_tensor = tensor.size()
        d_model = head * d_tensor

        tensor = tensor.transpose(1, 2).contiguous().view(batch_size, seq_len, d_model)
        return tensor

# %% [markdown]
# ### d. Position-wise feed forward network
# <a id='1c'></a>
# In this section, we will implement position-wise feed forward network
#
# $$\text{FFN}(x) = \max \left(0, x W_1 + b_1 \right) W_2 + b_2$$

# %%
class PositionwiseFeedForward(nn.Module):
    def __init__(self, d_model, hidden, dropout):
        super().__init__()
        self.linear1 = nn.Linear(d_model, hidden)
        self.linear2 = nn.Linear(hidden, d_model)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=dropout)
    
    def forward(self, x):
        x = self.linear1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear2(x)
        return x

# %% [markdown]
# ### e. Layer Normalization

# %%
class LayerNorm(nn.Module):
    def __init__(self, d_model, eps=1e-12):
        super().__init__()
        self.gamma = nn.Parameter(torch.ones(d_model))
        self.beta = nn.Parameter(torch.zeros(d_model))
        self.eps = eps
    
    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        var = x.var(-1, keepdim=True)
        # -1 to get mean and var for the last dimension(d_model)

        out = (x - mean) / torch.sqrt(var + self.eps)
        out = self.gamma * out + self.beta
        return out

# %% [markdown]
# ## 5. Embedding input data
#
# make 1 input dimension data to d_model dimentions

# %%
class LinearEmbedding(nn.Module):
    def __init__(self, dropout, d_model):
        '''
        data: [batch_size, seq_len, 1]
        In this model, only kospi input window
        '''
        super().__init__()
        self.d_model = d_model
        self.linear1 = nn.Linear(1, d_model//2)
        self.linear2 = nn.Linear(d_model//2, d_model)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=dropout)
        # self.normal = LayerNorm(d_model=d_model)
    
    def forward(self, x):
        '''
        input: [batch_size, seq_len, 1]
        output: [batch_size, seq_len, d_model]
        '''
        residual = x
        x = self.linear1(x)
        x = self.relu(x)
        x = self.dropout(x)
        # x = self.normal(x)
        x = self.linear2(x)
        x = self.relu(x)
        return x

# %%
class TrnasformerEmbedding(nn.Module):
    '''
    d_model: dimension of input data
    seq_len: max length of sequence
    '''
    def __init__(self, dropout, d_model, seq_len, device):
        super().__init__()
        self.lin_emb = LinearEmbedding(dropout, d_model)
        self.pos_emb = PositionalEncoding(d_model, seq_len, device)
        self.dropout = nn.Dropout(p=dropout)

    def forward(self, x):
        lin_emb = self.lin_emb(x)
        pos_emb = self.pos_emb(x)
        return self.dropout(lin_emb + pos_emb)

# %% [markdown]
# ## 6. Encoder Layer
# Trnasformer Encoder Except Embedding

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, ffn_hidden, n_head, dropout):
        super().__init__()
        self.attention = MultiHeadAttention(d_model=d_model, n_head=n_head)
        self.normal1 = LayerNorm(d_model=d_model)
        self.dropout1 = nn.Dropout(p=dropout)

        self.ffn = PositionwiseFeedForward(d_model=d_model, hidden=ffn_hidden, dropout=dropout)
        self.normal2 = LayerNorm(d_model=d_model)
        self.dropout2 = nn.Dropout(p=dropout)
    
    def forward(self, x, src_mask=None):
        # 1. multihead Attention
        residual = x
        x = self.attention(x, x, x)

        # 2. add and norm
        x = self.dropout1(x)
        x = self.normal1(x + residual)

        # 3. positionwise FFN
        residual = x
        x = self.ffn(x)

        # 4. add and norm
        x = self.dropout2(x)
        x = self.normal2(x + residual)

        return x

# %% [markdown]
# ## 7. Encoder
# Build Embedding and Encoder Block

# %%
class Encoder(nn.Module):
    def __init__(self, seq_len, d_model, ffn_hidden, n_head, dropout, n_layers, device):
        super().__init__()
        self.emb = TrnasformerEmbedding(dropout, d_model, seq_len, device)
        self.layers = nn.ModuleList([EncoderLayer(d_model, ffn_hidden, n_head, dropout)
                                     for _ in range(n_layers)])
    
    def forward(self, x):
        x = self.emb(x)
        for layer in self.layers:
            x = layer(x)
        
        return x

# %% [markdown]
# ## 8. Transformer Encoder
# Only use encoder module and FFN

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, seq_len, d_model, ffn_hidden, n_head, dropout, n_layers, device):
        super().__init__()
        self.encoder = Encoder(seq_len, d_model, ffn_hidden, n_head, dropout, n_layers, device)
        self.flatten = nn.Flatten()
        self.flatten_dim = seq_len * d_model
        self.linear1 = nn.Linear(self.flatten_dim, self.flatten_dim // 100)
        self.linear2 = nn.Linear(self.flatten_dim // 100, self.flatten_dim // 1000)
        self.linear3 = nn.Linear(self.flatten_dim // 1000, 1)
        self.normal1 = nn.LayerNorm(self.flatten_dim // 100)
        self.normal2 = nn.LayerNorm(self.flatten_dim // 1000)

        self.dropout = nn.Dropout(p=dropout)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        # x = self.encoder(x)[:, -1, :]
        x = self.encoder(x)
        x = self.flatten(x)
        # print(x.size())
        # x = self.linear1(x)[:, -1, :]
        x = self.linear1(x)
        # print(x.size())
        x = self.relu(x)
        x = self.dropout(x)
        x = self.normal1(x)
        x = self.linear2(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.normal2(x)
        x = self.linear3(x)
        x = self.relu(x)
        return x

# %% [markdown]
# ## 9. model, loss_fn, optimizer

# %%
# next(iter(train_dataloader)).shape
# torch.cuda.empty.cache()
batch_size, seq_len, input_dim = next(iter(train_dataloader))[0].size()
print(batch_size, seq_len, input_dim)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model_d = 512
dropout = 0.2
ffn_hidden = model_d // 2
n_layers = 4
n_head = 4
lr_sched = True
lr = 2e-5
# Out:
# 64 128 1

# %%
model = TransformerEncoder(seq_len, model_d, ffn_hidden, n_head, dropout, n_layers, device).to(device)
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr = lr)
if lr_sched == True:
    # scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer=optimizer,
    #                                     lr_lambda=lambda epoch: 0.95 ** epoch,
    #                                     last_epoch=-1,
    #                                     verbose=False)
    # scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)

# %%
model
# Out:
# TransformerEncoder(
#   (encoder): Encoder(
#     (emb): TrnasformerEmbedding(
#       (lin_emb): LinearEmbedding(
#         (linear1): Linear(in_features=1, out_features=256, bias=True)
#         (linear2): Linear(in_features=256, out_features=512, bias=True)
#         (relu): ReLU()
#         (dropout): Dropout(p=0.2, inplace=False)
#       )
#       (pos_emb): PositionalEncoding()
#       (dropout): Dropout(p=0.2, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-3): 4 x EncoderLayer(
#         (attention): MultiHeadAttention(
#           (attention): ScaleDotProductAttention(
#             (softmax): Softmax(dim=-1)
#           )
#           (w_q): Linear(in_features=512, out_features=512, bias=True)
#           (w_k): Linear(in_features=512, out_features=512, bias=True)
#           (w_v): Linear(in_features=512, out_features=512, bias=True)
#           (w_concat): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (normal1): LayerNorm()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (ffn): PositionwiseFeedForward(
#           (linear1): Linear(in_features=512, out_features=256, bias=True)
#           (linear2): Linear(in_features=256, out_features=512, bias=True)
#           (relu): ReLU()
#           (dropout): Dropout(p=0.2, inplace=False)
#         )
#         (normal2): LayerNorm()
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#     )
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear1): Linear(in_features=65536, out_features=655, bias=True)
#   (linear2): Linear(in_features=655, out_features=65, bias=True)
#   (linear3): Linear(in_features=65, out_features=1, bias=True)
#   (normal1): LayerNorm((655,), eps=1e-05, elementwise_affine=True)
#   (normal2): LayerNorm((65,), eps=1e-05, elementwise_affine=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (relu): ReLU()
# )

# %% [markdown]
# ## 10. Train and Test function

# %%
linear_model = LinearEmbedding(0.2, model_d).to(device)
in_x, in_y = next(iter(train_dataloader))
in_x = in_x.to(device).float()
out = linear_model(in_x)
out.size()
# Out:
# torch.Size([64, 128, 512])

# %%
emb_model = TrnasformerEmbedding(0.2, model_d, seq_len, device).to(device)
in_x, in_y = next(iter(train_dataloader))
in_x = in_x.to(device).float()
out = emb_model(in_x)
out.size()
# Out:
# torch.Size([64, 128, 512])

# %%
encoder_model = Encoder(seq_len, model_d, ffn_hidden, n_head, dropout, n_layers, device).to(device)
in_x, in_y = next(iter(train_dataloader))
in_x = in_x.to(device).float()
out = encoder_model(in_x)
print(out.size())
print(in_y.shape)
print(in_y.contiguous().view(-1).shape)
# Out:
# torch.Size([64, 128, 512])
# torch.Size([64, 1, 1])
# torch.Size([64])

# %%
in_x, in_y = next(iter(train_dataloader))
in_x = in_x.to(device).float()
out = model(in_x)
print(out.size())
print(in_y.shape)
print(in_y.contiguous().view(-1).shape)
# Out:
# torch.Size([64, 1])
# torch.Size([64, 1, 1])
# torch.Size([64])

# %%
epochs = 3000
loss_np = np.zeros((epochs, 2))
df_loss = pd.DataFrame(loss_np, columns=['epoch', 'loss'])
for i in range(epochs):
    epoch_loss = 0
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device).float()
        labels = labels.squeeze(1).to(device)

        optimizer.zero_grad()
        output = model(inputs)
        loss = loss_fn(output.float(), labels.float())
        # print(loss)
        loss.backward()
        # torch.nn.utils.clip_grad_norm(model.parameters(), 0.5)  # when using scheduler, it is not for grad exploding
        optimizer.step()

        epoch_loss += loss.item()
    
    print(f'epochs: {i}, loss: {epoch_loss:.6f}, lr: ', round(optimizer.param_groups[0]['lr'], 8))
    if lr_sched == True:
        scheduler.step()
    df_loss.loc[i, :] = [i, epoch_loss]
# Out:
# epochs: 0, loss: 9.025858, lr:  2e-05
# epochs: 1, loss: 1.821385, lr:  2e-05
# epochs: 2, loss: 1.257526, lr:  2e-05
# epochs: 3, loss: 0.970837, lr:  2e-05
# epochs: 4, loss: 0.816726, lr:  2e-05
# epochs: 5, loss: 0.705627, lr:  2e-05
# epochs: 6, loss: 0.590006, lr:  2e-05
# epochs: 7, loss: 0.528881, lr:  2e-05
# epochs: 8, loss: 0.493907, lr:  2e-05
# epochs: 9, loss: 0.459447, lr:  2e-05
# epochs: 10, loss: 0.434507, lr:  2e-05
# epochs: 11, loss: 0.412553, lr:  2e-05
# epochs: 12, loss: 0.421427, lr:  2e-05
# epochs: 13, loss: 0.394533, lr:  2e-05
# epochs: 14, loss: 0.378196, lr:  2e-05
# epochs: 15, loss: 0.362865, lr:  2e-05
# epochs: 16, loss: 0.345405, lr:  2e-05
# epochs: 17, loss: 0.347684, lr:  2e-05
# epochs: 18, loss: 0.349335, lr:  2e-05
# epochs: 19, loss: 0.334930, lr:  2e-05
# epochs: 20, loss: 0.319873, lr:  2e-05
# epochs: 21, loss: 0.312661, lr:  2e-05
# epochs: 22, loss: 0.312016, lr:  2e-05
# epochs: 23, loss: 0.285206, lr:  2e-05
# epochs: 24, loss: 0.296913, lr:  2e-05
# epochs: 25, loss: 0.282993, lr:  2e-05
# epochs: 26, loss: 0.297182, lr:  2e-05
# epochs: 27, loss: 0.275860, lr:  2e-05
# epochs: 28, loss: 0.267067, lr:  2e-05
# epochs: 29, loss: 0.268085, lr:  2e-05
# epochs: 30, loss: 0.258547, lr:  2e-05
# epochs: 31, loss: 0.263424, lr:  2e-05
# epochs: 32, loss: 0.258041, lr:  2e-05
# epochs: 33, loss: 0.252550, lr:  2e-05
# epochs: 34, loss: 0.242542, lr:  2e-05
# epochs: 35, loss: 0.238513, lr:  2e-05
# epochs: 36, loss: 0.240732, lr:  2e-05
# epochs: 37, loss: 0.230272, lr:  2e-05
# epochs: 38, loss: 0.236362, lr:  2e-05
# epochs: 39, loss: 0.233142, lr:  2e-05
# epochs: 40, loss: 0.233163, lr:  2e-05
# epochs: 41, loss: 0.219834, lr:  2e-05
# epochs: 42, loss: 0.223200, lr:  2e-05
# epochs: 43, loss: 0.221092, lr:  2e-05
# epochs: 44, loss: 0.215971, lr:  2e-05
# epochs: 45, loss: 0.210780, lr:  2e-05
# epochs: 46, loss: 0.203259, lr:  2e-05
# epochs: 47, loss: 0.208738, lr:  2e-05
# epochs: 48, loss: 0.204196, lr:  2e-05
# epochs: 49, loss: 0.204923, lr:  2e-05
# epochs: 50, loss: 0.209948, lr:  2e-05
# epochs: 51, loss: 0.201529, lr:  2e-05
# epochs: 52, loss: 0.201053, lr:  2e-05
# epochs: 53, loss: 0.197256, lr:  2e-05
# epochs: 54, loss: 0.193127, lr:  2e-05
# epochs: 55, loss: 0.196827, lr:  2e-05
# epochs: 56, loss: 0.193928, lr:  2e-05
# epochs: 57, loss: 0.196818, lr:  2e-05
# epochs: 58, loss: 0.195138, lr:  2e-05
# epochs: 59, loss: 0.188585, lr:  2e-05
# epochs: 60, loss: 0.184464, lr:  2e-05
# epochs: 61, loss: 0.182641, lr:  2e-05
# epochs: 62, loss: 0.184588, lr:  2e-05
# epochs: 63, loss: 0.180862, lr:  2e-05
# epochs: 64, loss: 0.187793, lr:  2e-05
# epochs: 65, loss: 0.185838, lr:  2e-05
# epochs: 66, loss: 0.174107, lr:  2e-05
# epochs: 67, loss: 0.178445, lr:  2e-05
# epochs: 68, loss: 0.174635, lr:  2e-05
# epochs: 69, loss: 0.180993, lr:  2e-05
# epochs: 70, loss: 0.176959, lr:  2e-05
# epochs: 71, loss: 0.173350, lr:  2e-05
# epochs: 72, loss: 0.167901, lr:  2e-05
# epochs: 73, loss: 0.167640, lr:  2e-05
# epochs: 74, loss: 0.169210, lr:  2e-05
# epochs: 75, loss: 0.167460, lr:  2e-05
# epochs: 76, loss: 0.158631, lr:  2e-05
# epochs: 77, loss: 0.152621, lr:  2e-05
# epochs: 78, loss: 0.159622, lr:  2e-05
# epochs: 79, loss: 0.165278, lr:  2e-05
# epochs: 80, loss: 0.156786, lr:  2e-05
# epochs: 81, loss: 0.159516, lr:  2e-05
# epochs: 82, loss: 0.148047, lr:  2e-05
# epochs: 83, loss: 0.152623, lr:  2e-05
# epochs: 84, loss: 0.152930, lr:  2e-05
# epochs: 85, loss: 0.146478, lr:  2e-05
# epochs: 86, loss: 0.153300, lr:  2e-05
# epochs: 87, loss: 0.148244, lr:  2e-05
# epochs: 88, loss: 0.145371, lr:  2e-05
# epochs: 89, loss: 0.146137, lr:  2e-05
# epochs: 90, loss: 0.156081, lr:  2e-05
# epochs: 91, loss: 0.146908, lr:  2e-05
# epochs: 92, loss: 0.140242, lr:  2e-05
# epochs: 93, loss: 0.138435, lr:  2e-05
# epochs: 94, loss: 0.144319, lr:  2e-05
# epochs: 95, loss: 0.141685, lr:  2e-05
# epochs: 96, loss: 0.138118, lr:  2e-05
# epochs: 97, loss: 0.138796, lr:  2e-05
# epochs: 98, loss: 0.132683, lr:  2e-05
# epochs: 99, loss: 0.133079, lr:  2e-05
# epochs: 100, loss: 0.125539, lr:  1e-05
# epochs: 101, loss: 0.133479, lr:  1e-05
# epochs: 102, loss: 0.133639, lr:  1e-05
# epochs: 103, loss: 0.129013, lr:  1e-05
# epochs: 104, loss: 0.129655, lr:  1e-05
# epochs: 105, loss: 0.124544, lr:  1e-05
# epochs: 106, loss: 0.126503, lr:  1e-05
# epochs: 107, loss: 0.125601, lr:  1e-05
# epochs: 108, loss: 0.121101, lr:  1e-05
# epochs: 109, loss: 0.127314, lr:  1e-05
# epochs: 110, loss: 0.129018, lr:  1e-05
# epochs: 111, loss: 0.127588, lr:  1e-05
# epochs: 112, loss: 0.127401, lr:  1e-05
# epochs: 113, loss: 0.127544, lr:  1e-05
# epochs: 114, loss: 0.127268, lr:  1e-05
# epochs: 115, loss: 0.118191, lr:  1e-05
# epochs: 116, loss: 0.121630, lr:  1e-05
# epochs: 117, loss: 0.124883, lr:  1e-05
# epochs: 118, loss: 0.124671, lr:  1e-05
# epochs: 119, loss: 0.119854, lr:  1e-05
# epochs: 120, loss: 0.125649, lr:  1e-05
# epochs: 121, loss: 0.118837, lr:  1e-05
# epochs: 122, loss: 0.123957, lr:  1e-05
# epochs: 123, loss: 0.119579, lr:  1e-05
# epochs: 124, loss: 0.123574, lr:  1e-05
# epochs: 125, loss: 0.121201, lr:  1e-05
# epochs: 126, loss: 0.118138, lr:  1e-05
# epochs: 127, loss: 0.119866, lr:  1e-05
# epochs: 128, loss: 0.115449, lr:  1e-05
# epochs: 129, loss: 0.110340, lr:  1e-05
# epochs: 130, loss: 0.114543, lr:  1e-05
# epochs: 131, loss: 0.112203, lr:  1e-05
# epochs: 132, loss: 0.112859, lr:  1e-05
# epochs: 133, loss: 0.117192, lr:  1e-05
# epochs: 134, loss: 0.114100, lr:  1e-05
# epochs: 135, loss: 0.116069, lr:  1e-05
# epochs: 136, loss: 0.114701, lr:  1e-05
# epochs: 137, loss: 0.111115, lr:  1e-05
# epochs: 138, loss: 0.114996, lr:  1e-05
# epochs: 139, loss: 0.112928, lr:  1e-05
# epochs: 140, loss: 0.111871, lr:  1e-05
# epochs: 141, loss: 0.111238, lr:  1e-05
# epochs: 142, loss: 0.110851, lr:  1e-05
# epochs: 143, loss: 0.109706, lr:  1e-05
# epochs: 144, loss: 0.112737, lr:  1e-05
# epochs: 145, loss: 0.110639, lr:  1e-05
# epochs: 146, loss: 0.110826, lr:  1e-05
# epochs: 147, loss: 0.111330, lr:  1e-05
# epochs: 148, loss: 0.107844, lr:  1e-05
# epochs: 149, loss: 0.111766, lr:  1e-05
# epochs: 150, loss: 0.110982, lr:  1e-05
# epochs: 151, loss: 0.105063, lr:  1e-05
# epochs: 152, loss: 0.108054, lr:  1e-05
# epochs: 153, loss: 0.105542, lr:  1e-05
# epochs: 154, loss: 0.103751, lr:  1e-05
# epochs: 155, loss: 0.111509, lr:  1e-05
# epochs: 156, loss: 0.107266, lr:  1e-05
# epochs: 157, loss: 0.106852, lr:  1e-05
# epochs: 158, loss: 0.105810, lr:  1e-05
# epochs: 159, loss: 0.106731, lr:  1e-05
# epochs: 160, loss: 0.105211, lr:  1e-05
# epochs: 161, loss: 0.102609, lr:  1e-05
# epochs: 162, loss: 0.104889, lr:  1e-05
# epochs: 163, loss: 0.108360, lr:  1e-05
# epochs: 164, loss: 0.100128, lr:  1e-05
# epochs: 165, loss: 0.101627, lr:  1e-05
# epochs: 166, loss: 0.102130, lr:  1e-05
# epochs: 167, loss: 0.104961, lr:  1e-05
# epochs: 168, loss: 0.103772, lr:  1e-05
# epochs: 169, loss: 0.099975, lr:  1e-05
# epochs: 170, loss: 0.097724, lr:  1e-05
# epochs: 171, loss: 0.099456, lr:  1e-05
# epochs: 172, loss: 0.097261, lr:  1e-05
# epochs: 173, loss: 0.098158, lr:  1e-05
# epochs: 174, loss: 0.104712, lr:  1e-05
# epochs: 175, loss: 0.102653, lr:  1e-05
# epochs: 176, loss: 0.098618, lr:  1e-05
# epochs: 177, loss: 0.100637, lr:  1e-05
# epochs: 178, loss: 0.093776, lr:  1e-05
# epochs: 179, loss: 0.099145, lr:  1e-05
# epochs: 180, loss: 0.095751, lr:  1e-05
# epochs: 181, loss: 0.096088, lr:  1e-05
# epochs: 182, loss: 0.103764, lr:  1e-05
# epochs: 183, loss: 0.091374, lr:  1e-05
# epochs: 184, loss: 0.099655, lr:  1e-05
# epochs: 185, loss: 0.100029, lr:  1e-05
# epochs: 186, loss: 0.097756, lr:  1e-05
# epochs: 187, loss: 0.100046, lr:  1e-05
# epochs: 188, loss: 0.093814, lr:  1e-05
# epochs: 189, loss: 0.096358, lr:  1e-05
# epochs: 190, loss: 0.091907, lr:  1e-05
# epochs: 191, loss: 0.094380, lr:  1e-05
# epochs: 192, loss: 0.094027, lr:  1e-05
# epochs: 193, loss: 0.091536, lr:  1e-05
# epochs: 194, loss: 0.094688, lr:  1e-05
# epochs: 195, loss: 0.089875, lr:  1e-05
# epochs: 196, loss: 0.094197, lr:  1e-05
# epochs: 197, loss: 0.091127, lr:  1e-05
# epochs: 198, loss: 0.095534, lr:  1e-05
# epochs: 199, loss: 0.091004, lr:  1e-05
# epochs: 200, loss: 0.088436, lr:  5e-06
# epochs: 201, loss: 0.092117, lr:  5e-06
# epochs: 202, loss: 0.089714, lr:  5e-06
# epochs: 203, loss: 0.091839, lr:  5e-06
# epochs: 204, loss: 0.087628, lr:  5e-06
# epochs: 205, loss: 0.087375, lr:  5e-06
# epochs: 206, loss: 0.088361, lr:  5e-06
# epochs: 207, loss: 0.091578, lr:  5e-06
# epochs: 208, loss: 0.089423, lr:  5e-06
# epochs: 209, loss: 0.087855, lr:  5e-06
# epochs: 210, loss: 0.085688, lr:  5e-06
# epochs: 211, loss: 0.085776, lr:  5e-06
# epochs: 212, loss: 0.086656, lr:  5e-06
# epochs: 213, loss: 0.085816, lr:  5e-06
# epochs: 214, loss: 0.087072, lr:  5e-06
# epochs: 215, loss: 0.086308, lr:  5e-06
# epochs: 216, loss: 0.083000, lr:  5e-06
# epochs: 217, loss: 0.082640, lr:  5e-06
# epochs: 218, loss: 0.085102, lr:  5e-06
# epochs: 219, loss: 0.085849, lr:  5e-06
# epochs: 220, loss: 0.087934, lr:  5e-06
# epochs: 221, loss: 0.087038, lr:  5e-06
# epochs: 222, loss: 0.080958, lr:  5e-06
# epochs: 223, loss: 0.085280, lr:  5e-06
# epochs: 224, loss: 0.088041, lr:  5e-06
# epochs: 225, loss: 0.085427, lr:  5e-06
# epochs: 226, loss: 0.084051, lr:  5e-06
# epochs: 227, loss: 0.085838, lr:  5e-06
# epochs: 228, loss: 0.084231, lr:  5e-06
# epochs: 229, loss: 0.083209, lr:  5e-06
# epochs: 230, loss: 0.087235, lr:  5e-06
# epochs: 231, loss: 0.085562, lr:  5e-06
# epochs: 232, loss: 0.085862, lr:  5e-06
# epochs: 233, loss: 0.082787, lr:  5e-06
# epochs: 234, loss: 0.087239, lr:  5e-06
# epochs: 235, loss: 0.079689, lr:  5e-06
# epochs: 236, loss: 0.083227, lr:  5e-06
# epochs: 237, loss: 0.084980, lr:  5e-06
# epochs: 238, loss: 0.081688, lr:  5e-06
# epochs: 239, loss: 0.086316, lr:  5e-06
# epochs: 240, loss: 0.081762, lr:  5e-06
# epochs: 241, loss: 0.084501, lr:  5e-06
# epochs: 242, loss: 0.084638, lr:  5e-06
# epochs: 243, loss: 0.082665, lr:  5e-06
# epochs: 244, loss: 0.085662, lr:  5e-06
# epochs: 245, loss: 0.084550, lr:  5e-06
# epochs: 246, loss: 0.081698, lr:  5e-06
# epochs: 247, loss: 0.082699, lr:  5e-06
# epochs: 248, loss: 0.080009, lr:  5e-06
# epochs: 249, loss: 0.082084, lr:  5e-06
# epochs: 250, loss: 0.082701, lr:  5e-06
# epochs: 251, loss: 0.081209, lr:  5e-06
# epochs: 252, loss: 0.079832, lr:  5e-06
# epochs: 253, loss: 0.087144, lr:  5e-06
# epochs: 254, loss: 0.083847, lr:  5e-06
# epochs: 255, loss: 0.079362, lr:  5e-06
# epochs: 256, loss: 0.084190, lr:  5e-06
# epochs: 257, loss: 0.080460, lr:  5e-06
# epochs: 258, loss: 0.082489, lr:  5e-06
# epochs: 259, loss: 0.080712, lr:  5e-06
# epochs: 260, loss: 0.079260, lr:  5e-06
# epochs: 261, loss: 0.083663, lr:  5e-06
# epochs: 262, loss: 0.083400, lr:  5e-06
# epochs: 263, loss: 0.082615, lr:  5e-06
# epochs: 264, loss: 0.084176, lr:  5e-06
# epochs: 265, loss: 0.084560, lr:  5e-06
# epochs: 266, loss: 0.080505, lr:  5e-06
# epochs: 267, loss: 0.084693, lr:  5e-06
# epochs: 268, loss: 0.076120, lr:  5e-06
# epochs: 269, loss: 0.079566, lr:  5e-06
# epochs: 270, loss: 0.079766, lr:  5e-06
# epochs: 271, loss: 0.077677, lr:  5e-06
# epochs: 272, loss: 0.077979, lr:  5e-06
# epochs: 273, loss: 0.082071, lr:  5e-06
# epochs: 274, loss: 0.079705, lr:  5e-06
# epochs: 275, loss: 0.079035, lr:  5e-06
# epochs: 276, loss: 0.077677, lr:  5e-06
# epochs: 277, loss: 0.078434, lr:  5e-06
# epochs: 278, loss: 0.077837, lr:  5e-06
# epochs: 279, loss: 0.077779, lr:  5e-06
# epochs: 280, loss: 0.082790, lr:  5e-06
# epochs: 281, loss: 0.081452, lr:  5e-06
# epochs: 282, loss: 0.079780, lr:  5e-06
# epochs: 283, loss: 0.081059, lr:  5e-06
# epochs: 284, loss: 0.078844, lr:  5e-06
# epochs: 285, loss: 0.080558, lr:  5e-06
# epochs: 286, loss: 0.081239, lr:  5e-06
# epochs: 287, loss: 0.076723, lr:  5e-06
# epochs: 288, loss: 0.079857, lr:  5e-06
# epochs: 289, loss: 0.078054, lr:  5e-06
# epochs: 290, loss: 0.079292, lr:  5e-06
# epochs: 291, loss: 0.077976, lr:  5e-06
# epochs: 292, loss: 0.078842, lr:  5e-06
# epochs: 293, loss: 0.077608, lr:  5e-06
# epochs: 294, loss: 0.079329, lr:  5e-06
# epochs: 295, loss: 0.076895, lr:  5e-06
# epochs: 296, loss: 0.077679, lr:  5e-06
# epochs: 297, loss: 0.076753, lr:  5e-06
# epochs: 298, loss: 0.078314, lr:  5e-06
# epochs: 299, loss: 0.073439, lr:  5e-06
# epochs: 300, loss: 0.078272, lr:  2.5e-06
# epochs: 301, loss: 0.073203, lr:  2.5e-06
# epochs: 302, loss: 0.076690, lr:  2.5e-06
# epochs: 303, loss: 0.075194, lr:  2.5e-06
# epochs: 304, loss: 0.077170, lr:  2.5e-06
# epochs: 305, loss: 0.073284, lr:  2.5e-06
# epochs: 306, loss: 0.076888, lr:  2.5e-06
# epochs: 307, loss: 0.075703, lr:  2.5e-06
# epochs: 308, loss: 0.076017, lr:  2.5e-06
# epochs: 309, loss: 0.076639, lr:  2.5e-06
# epochs: 310, loss: 0.080221, lr:  2.5e-06
# epochs: 311, loss: 0.076044, lr:  2.5e-06
# epochs: 312, loss: 0.075836, lr:  2.5e-06
# epochs: 313, loss: 0.075202, lr:  2.5e-06
# epochs: 314, loss: 0.077852, lr:  2.5e-06
# epochs: 315, loss: 0.073019, lr:  2.5e-06
# epochs: 316, loss: 0.071949, lr:  2.5e-06
# epochs: 317, loss: 0.076451, lr:  2.5e-06
# epochs: 318, loss: 0.077071, lr:  2.5e-06
# epochs: 319, loss: 0.072150, lr:  2.5e-06
# epochs: 320, loss: 0.077747, lr:  2.5e-06
# epochs: 321, loss: 0.076527, lr:  2.5e-06
# epochs: 322, loss: 0.078780, lr:  2.5e-06
# epochs: 323, loss: 0.075766, lr:  2.5e-06
# epochs: 324, loss: 0.075349, lr:  2.5e-06
# epochs: 325, loss: 0.077489, lr:  2.5e-06
# epochs: 326, loss: 0.075597, lr:  2.5e-06
# epochs: 327, loss: 0.071484, lr:  2.5e-06
# epochs: 328, loss: 0.072423, lr:  2.5e-06
# epochs: 329, loss: 0.076290, lr:  2.5e-06
# epochs: 330, loss: 0.072383, lr:  2.5e-06
# epochs: 331, loss: 0.075343, lr:  2.5e-06
# epochs: 332, loss: 0.073752, lr:  2.5e-06
# epochs: 333, loss: 0.078054, lr:  2.5e-06
# epochs: 334, loss: 0.075399, lr:  2.5e-06
# epochs: 335, loss: 0.072334, lr:  2.5e-06
# epochs: 336, loss: 0.073656, lr:  2.5e-06
# epochs: 337, loss: 0.079693, lr:  2.5e-06
# epochs: 338, loss: 0.077348, lr:  2.5e-06
# epochs: 339, loss: 0.072970, lr:  2.5e-06
# epochs: 340, loss: 0.074539, lr:  2.5e-06
# epochs: 341, loss: 0.074042, lr:  2.5e-06
# epochs: 342, loss: 0.074927, lr:  2.5e-06
# epochs: 343, loss: 0.073276, lr:  2.5e-06
# epochs: 344, loss: 0.075804, lr:  2.5e-06
# epochs: 345, loss: 0.074264, lr:  2.5e-06
# epochs: 346, loss: 0.072295, lr:  2.5e-06
# epochs: 347, loss: 0.073788, lr:  2.5e-06
# epochs: 348, loss: 0.072699, lr:  2.5e-06
# epochs: 349, loss: 0.071394, lr:  2.5e-06
# epochs: 350, loss: 0.077281, lr:  2.5e-06
# epochs: 351, loss: 0.077591, lr:  2.5e-06
# epochs: 352, loss: 0.074915, lr:  2.5e-06
# epochs: 353, loss: 0.072230, lr:  2.5e-06
# epochs: 354, loss: 0.072464, lr:  2.5e-06
# epochs: 355, loss: 0.070823, lr:  2.5e-06
# epochs: 356, loss: 0.072745, lr:  2.5e-06
# epochs: 357, loss: 0.072319, lr:  2.5e-06
# epochs: 358, loss: 0.076856, lr:  2.5e-06
# epochs: 359, loss: 0.074299, lr:  2.5e-06
# epochs: 360, loss: 0.072289, lr:  2.5e-06
# epochs: 361, loss: 0.073483, lr:  2.5e-06
# epochs: 362, loss: 0.072777, lr:  2.5e-06
# epochs: 363, loss: 0.071471, lr:  2.5e-06
# epochs: 364, loss: 0.071229, lr:  2.5e-06
# epochs: 365, loss: 0.072214, lr:  2.5e-06
# epochs: 366, loss: 0.071374, lr:  2.5e-06
# epochs: 367, loss: 0.072409, lr:  2.5e-06
# epochs: 368, loss: 0.073460, lr:  2.5e-06
# epochs: 369, loss: 0.072547, lr:  2.5e-06
# epochs: 370, loss: 0.074669, lr:  2.5e-06
# epochs: 371, loss: 0.072490, lr:  2.5e-06
# epochs: 372, loss: 0.070985, lr:  2.5e-06
# epochs: 373, loss: 0.073665, lr:  2.5e-06
# epochs: 374, loss: 0.072202, lr:  2.5e-06
# epochs: 375, loss: 0.074564, lr:  2.5e-06
# epochs: 376, loss: 0.072260, lr:  2.5e-06
# epochs: 377, loss: 0.071483, lr:  2.5e-06
# epochs: 378, loss: 0.074243, lr:  2.5e-06
# epochs: 379, loss: 0.072486, lr:  2.5e-06
# epochs: 380, loss: 0.070633, lr:  2.5e-06
# epochs: 381, loss: 0.068407, lr:  2.5e-06
# epochs: 382, loss: 0.074113, lr:  2.5e-06
# epochs: 383, loss: 0.071839, lr:  2.5e-06
# epochs: 384, loss: 0.069552, lr:  2.5e-06
# epochs: 385, loss: 0.070615, lr:  2.5e-06
# epochs: 386, loss: 0.069026, lr:  2.5e-06
# epochs: 387, loss: 0.070555, lr:  2.5e-06
# epochs: 388, loss: 0.072676, lr:  2.5e-06
# epochs: 389, loss: 0.072160, lr:  2.5e-06
# epochs: 390, loss: 0.069604, lr:  2.5e-06
# epochs: 391, loss: 0.069751, lr:  2.5e-06
# epochs: 392, loss: 0.074088, lr:  2.5e-06
# epochs: 393, loss: 0.069680, lr:  2.5e-06
# epochs: 394, loss: 0.073035, lr:  2.5e-06
# epochs: 395, loss: 0.070579, lr:  2.5e-06
# epochs: 396, loss: 0.073596, lr:  2.5e-06
# epochs: 397, loss: 0.069464, lr:  2.5e-06
# epochs: 398, loss: 0.071461, lr:  2.5e-06
# epochs: 399, loss: 0.070795, lr:  2.5e-06
# epochs: 400, loss: 0.068530, lr:  1.25e-06
# epochs: 401, loss: 0.069875, lr:  1.25e-06
# epochs: 402, loss: 0.068491, lr:  1.25e-06
# epochs: 403, loss: 0.069799, lr:  1.25e-06
# epochs: 404, loss: 0.072832, lr:  1.25e-06
# epochs: 405, loss: 0.068832, lr:  1.25e-06
# epochs: 406, loss: 0.070886, lr:  1.25e-06
# epochs: 407, loss: 0.070098, lr:  1.25e-06
# epochs: 408, loss: 0.070406, lr:  1.25e-06
# epochs: 409, loss: 0.071474, lr:  1.25e-06
# epochs: 410, loss: 0.069359, lr:  1.25e-06
# epochs: 411, loss: 0.071073, lr:  1.25e-06
# epochs: 412, loss: 0.069611, lr:  1.25e-06
# epochs: 413, loss: 0.067399, lr:  1.25e-06
# epochs: 414, loss: 0.069386, lr:  1.25e-06
# epochs: 415, loss: 0.072587, lr:  1.25e-06
# epochs: 416, loss: 0.069360, lr:  1.25e-06
# epochs: 417, loss: 0.072369, lr:  1.25e-06
# epochs: 418, loss: 0.070223, lr:  1.25e-06
# epochs: 419, loss: 0.069895, lr:  1.25e-06
# epochs: 420, loss: 0.069124, lr:  1.25e-06
# epochs: 421, loss: 0.070342, lr:  1.25e-06
# epochs: 422, loss: 0.070905, lr:  1.25e-06
# epochs: 423, loss: 0.072250, lr:  1.25e-06
# epochs: 424, loss: 0.073223, lr:  1.25e-06
# epochs: 425, loss: 0.070521, lr:  1.25e-06
# epochs: 426, loss: 0.068837, lr:  1.25e-06
# epochs: 427, loss: 0.071727, lr:  1.25e-06
# epochs: 428, loss: 0.069188, lr:  1.25e-06
# epochs: 429, loss: 0.068015, lr:  1.25e-06
# epochs: 430, loss: 0.070942, lr:  1.25e-06
# epochs: 431, loss: 0.068059, lr:  1.25e-06
# epochs: 432, loss: 0.073136, lr:  1.25e-06
# epochs: 433, loss: 0.066985, lr:  1.25e-06
# epochs: 434, loss: 0.067083, lr:  1.25e-06
# epochs: 435, loss: 0.071345, lr:  1.25e-06
# epochs: 436, loss: 0.069485, lr:  1.25e-06
# epochs: 437, loss: 0.070899, lr:  1.25e-06
# epochs: 438, loss: 0.069945, lr:  1.25e-06
# epochs: 439, loss: 0.071961, lr:  1.25e-06
# epochs: 440, loss: 0.071296, lr:  1.25e-06
# epochs: 441, loss: 0.069516, lr:  1.25e-06
# epochs: 442, loss: 0.070932, lr:  1.25e-06
# epochs: 443, loss: 0.070593, lr:  1.25e-06
# epochs: 444, loss: 0.068572, lr:  1.25e-06
# epochs: 445, loss: 0.069453, lr:  1.25e-06
# epochs: 446, loss: 0.067554, lr:  1.25e-06
# epochs: 447, loss: 0.068968, lr:  1.25e-06
# epochs: 448, loss: 0.068445, lr:  1.25e-06
# epochs: 449, loss: 0.067337, lr:  1.25e-06
# epochs: 450, loss: 0.069498, lr:  1.25e-06
# epochs: 451, loss: 0.073403, lr:  1.25e-06
# epochs: 452, loss: 0.067302, lr:  1.25e-06
# epochs: 453, loss: 0.069923, lr:  1.25e-06
# epochs: 454, loss: 0.071205, lr:  1.25e-06
# epochs: 455, loss: 0.070102, lr:  1.25e-06
# epochs: 456, loss: 0.069177, lr:  1.25e-06
# epochs: 457, loss: 0.070899, lr:  1.25e-06
# epochs: 458, loss: 0.069851, lr:  1.25e-06
# epochs: 459, loss: 0.070824, lr:  1.25e-06
# epochs: 460, loss: 0.070540, lr:  1.25e-06
# epochs: 461, loss: 0.068793, lr:  1.25e-06
# epochs: 462, loss: 0.069383, lr:  1.25e-06
# epochs: 463, loss: 0.070451, lr:  1.25e-06
# epochs: 464, loss: 0.069350, lr:  1.25e-06
# epochs: 465, loss: 0.067669, lr:  1.25e-06
# epochs: 466, loss: 0.071117, lr:  1.25e-06
# epochs: 467, loss: 0.069134, lr:  1.25e-06
# epochs: 468, loss: 0.070987, lr:  1.25e-06
# epochs: 469, loss: 0.070280, lr:  1.25e-06
# epochs: 470, loss: 0.070590, lr:  1.25e-06
# epochs: 471, loss: 0.068087, lr:  1.25e-06
# epochs: 472, loss: 0.068326, lr:  1.25e-06
# epochs: 473, loss: 0.068494, lr:  1.25e-06
# epochs: 474, loss: 0.066927, lr:  1.25e-06
# epochs: 475, loss: 0.068534, lr:  1.25e-06
# epochs: 476, loss: 0.068078, lr:  1.25e-06
# epochs: 477, loss: 0.069701, lr:  1.25e-06
# epochs: 478, loss: 0.064024, lr:  1.25e-06
# epochs: 479, loss: 0.070154, lr:  1.25e-06
# epochs: 480, loss: 0.070072, lr:  1.25e-06
# epochs: 481, loss: 0.070949, lr:  1.25e-06
# epochs: 482, loss: 0.065095, lr:  1.25e-06
# epochs: 483, loss: 0.068472, lr:  1.25e-06
# epochs: 484, loss: 0.069975, lr:  1.25e-06
# epochs: 485, loss: 0.071526, lr:  1.25e-06
# epochs: 486, loss: 0.066594, lr:  1.25e-06
# epochs: 487, loss: 0.069958, lr:  1.25e-06
# epochs: 488, loss: 0.068002, lr:  1.25e-06
# epochs: 489, loss: 0.068624, lr:  1.25e-06
# epochs: 490, loss: 0.067269, lr:  1.25e-06
# epochs: 491, loss: 0.073983, lr:  1.25e-06
# epochs: 492, loss: 0.069038, lr:  1.25e-06
# epochs: 493, loss: 0.069634, lr:  1.25e-06
# epochs: 494, loss: 0.068405, lr:  1.25e-06
# epochs: 495, loss: 0.068016, lr:  1.25e-06
# epochs: 496, loss: 0.069245, lr:  1.25e-06
# epochs: 497, loss: 0.072297, lr:  1.25e-06
# epochs: 498, loss: 0.071562, lr:  1.25e-06
# epochs: 499, loss: 0.068295, lr:  1.25e-06
# epochs: 500, loss: 0.066673, lr:  6.3e-07
# epochs: 501, loss: 0.067159, lr:  6.3e-07
# epochs: 502, loss: 0.068065, lr:  6.3e-07
# epochs: 503, loss: 0.069186, lr:  6.3e-07
# epochs: 504, loss: 0.066674, lr:  6.3e-07
# epochs: 505, loss: 0.066530, lr:  6.3e-07
# epochs: 506, loss: 0.068608, lr:  6.3e-07
# epochs: 507, loss: 0.066158, lr:  6.3e-07
# epochs: 508, loss: 0.066944, lr:  6.3e-07
# epochs: 509, loss: 0.064776, lr:  6.3e-07
# epochs: 510, loss: 0.066885, lr:  6.3e-07
# epochs: 511, loss: 0.064610, lr:  6.3e-07
# epochs: 512, loss: 0.070860, lr:  6.3e-07
# epochs: 513, loss: 0.065373, lr:  6.3e-07
# epochs: 514, loss: 0.067675, lr:  6.3e-07
# epochs: 515, loss: 0.067478, lr:  6.3e-07
# epochs: 516, loss: 0.068252, lr:  6.3e-07
# epochs: 517, loss: 0.067950, lr:  6.3e-07
# epochs: 518, loss: 0.067215, lr:  6.3e-07
# epochs: 519, loss: 0.065976, lr:  6.3e-07
# epochs: 520, loss: 0.063310, lr:  6.3e-07
# epochs: 521, loss: 0.067662, lr:  6.3e-07
# epochs: 522, loss: 0.067144, lr:  6.3e-07
# epochs: 523, loss: 0.067622, lr:  6.3e-07
# epochs: 524, loss: 0.066520, lr:  6.3e-07
# epochs: 525, loss: 0.070157, lr:  6.3e-07
# epochs: 526, loss: 0.067172, lr:  6.3e-07
# epochs: 527, loss: 0.068264, lr:  6.3e-07
# epochs: 528, loss: 0.066000, lr:  6.3e-07
# epochs: 529, loss: 0.065705, lr:  6.3e-07
# epochs: 530, loss: 0.067408, lr:  6.3e-07
# epochs: 531, loss: 0.066319, lr:  6.3e-07
# epochs: 532, loss: 0.068824, lr:  6.3e-07
# epochs: 533, loss: 0.068968, lr:  6.3e-07
# epochs: 534, loss: 0.068239, lr:  6.3e-07
# epochs: 535, loss: 0.068810, lr:  6.3e-07
# epochs: 536, loss: 0.070458, lr:  6.3e-07
# epochs: 537, loss: 0.069258, lr:  6.3e-07
# epochs: 538, loss: 0.068299, lr:  6.3e-07
# epochs: 539, loss: 0.066274, lr:  6.3e-07
# epochs: 540, loss: 0.068200, lr:  6.3e-07
# epochs: 541, loss: 0.066317, lr:  6.3e-07
# epochs: 542, loss: 0.066174, lr:  6.3e-07
# epochs: 543, loss: 0.064982, lr:  6.3e-07
# epochs: 544, loss: 0.066510, lr:  6.3e-07
# epochs: 545, loss: 0.067621, lr:  6.3e-07
# epochs: 546, loss: 0.067131, lr:  6.3e-07
# epochs: 547, loss: 0.068001, lr:  6.3e-07
# epochs: 548, loss: 0.067675, lr:  6.3e-07
# epochs: 549, loss: 0.068850, lr:  6.3e-07
# epochs: 550, loss: 0.067678, lr:  6.3e-07
# epochs: 551, loss: 0.066747, lr:  6.3e-07
# epochs: 552, loss: 0.069529, lr:  6.3e-07
# epochs: 553, loss: 0.068507, lr:  6.3e-07
# epochs: 554, loss: 0.068940, lr:  6.3e-07
# epochs: 555, loss: 0.067867, lr:  6.3e-07
# epochs: 556, loss: 0.066504, lr:  6.3e-07
# epochs: 557, loss: 0.068733, lr:  6.3e-07
# epochs: 558, loss: 0.067892, lr:  6.3e-07
# epochs: 559, loss: 0.068466, lr:  6.3e-07
# epochs: 560, loss: 0.066969, lr:  6.3e-07
# epochs: 561, loss: 0.068925, lr:  6.3e-07
# epochs: 562, loss: 0.065468, lr:  6.3e-07
# epochs: 563, loss: 0.065309, lr:  6.3e-07
# epochs: 564, loss: 0.068907, lr:  6.3e-07
# epochs: 565, loss: 0.069837, lr:  6.3e-07
# epochs: 566, loss: 0.071216, lr:  6.3e-07
# epochs: 567, loss: 0.067543, lr:  6.3e-07
# epochs: 568, loss: 0.067605, lr:  6.3e-07
# epochs: 569, loss: 0.068123, lr:  6.3e-07
# epochs: 570, loss: 0.065718, lr:  6.3e-07
# epochs: 571, loss: 0.072187, lr:  6.3e-07
# epochs: 572, loss: 0.067553, lr:  6.3e-07
# epochs: 573, loss: 0.064682, lr:  6.3e-07
# epochs: 574, loss: 0.066018, lr:  6.3e-07
# epochs: 575, loss: 0.066836, lr:  6.3e-07
# epochs: 576, loss: 0.068803, lr:  6.3e-07
# epochs: 577, loss: 0.065778, lr:  6.3e-07
# epochs: 578, loss: 0.065423, lr:  6.3e-07
# epochs: 579, loss: 0.067181, lr:  6.3e-07
# epochs: 580, loss: 0.065457, lr:  6.3e-07
# epochs: 581, loss: 0.067063, lr:  6.3e-07
# epochs: 582, loss: 0.066289, lr:  6.3e-07
# epochs: 583, loss: 0.066172, lr:  6.3e-07
# epochs: 584, loss: 0.065448, lr:  6.3e-07
# epochs: 585, loss: 0.069124, lr:  6.3e-07
# epochs: 586, loss: 0.065046, lr:  6.3e-07
# epochs: 587, loss: 0.069869, lr:  6.3e-07
# epochs: 588, loss: 0.066946, lr:  6.3e-07
# epochs: 589, loss: 0.065728, lr:  6.3e-07
# epochs: 590, loss: 0.066055, lr:  6.3e-07
# epochs: 591, loss: 0.067164, lr:  6.3e-07
# epochs: 592, loss: 0.065472, lr:  6.3e-07
# epochs: 593, loss: 0.067420, lr:  6.3e-07
# epochs: 594, loss: 0.066535, lr:  6.3e-07
# epochs: 595, loss: 0.065254, lr:  6.3e-07
# epochs: 596, loss: 0.068801, lr:  6.3e-07
# epochs: 597, loss: 0.069775, lr:  6.3e-07
# epochs: 598, loss: 0.068349, lr:  6.3e-07
# epochs: 599, loss: 0.066233, lr:  6.3e-07
# epochs: 600, loss: 0.067810, lr:  3.1e-07
# epochs: 601, loss: 0.066563, lr:  3.1e-07
# epochs: 602, loss: 0.067353, lr:  3.1e-07
# epochs: 603, loss: 0.069239, lr:  3.1e-07
# epochs: 604, loss: 0.068642, lr:  3.1e-07
# epochs: 605, loss: 0.065183, lr:  3.1e-07
# epochs: 606, loss: 0.065917, lr:  3.1e-07
# epochs: 607, loss: 0.066351, lr:  3.1e-07
# epochs: 608, loss: 0.066264, lr:  3.1e-07
# epochs: 609, loss: 0.063575, lr:  3.1e-07
# epochs: 610, loss: 0.067085, lr:  3.1e-07
# epochs: 611, loss: 0.066491, lr:  3.1e-07
# epochs: 612, loss: 0.064744, lr:  3.1e-07
# epochs: 613, loss: 0.067462, lr:  3.1e-07
# epochs: 614, loss: 0.067155, lr:  3.1e-07
# epochs: 615, loss: 0.066778, lr:  3.1e-07
# epochs: 616, loss: 0.065704, lr:  3.1e-07
# epochs: 617, loss: 0.065184, lr:  3.1e-07
# epochs: 618, loss: 0.068412, lr:  3.1e-07
# epochs: 619, loss: 0.066327, lr:  3.1e-07
# epochs: 620, loss: 0.064522, lr:  3.1e-07
# epochs: 621, loss: 0.068639, lr:  3.1e-07
# epochs: 622, loss: 0.066356, lr:  3.1e-07
# epochs: 623, loss: 0.066626, lr:  3.1e-07
# epochs: 624, loss: 0.066250, lr:  3.1e-07
# epochs: 625, loss: 0.065959, lr:  3.1e-07
# epochs: 626, loss: 0.067464, lr:  3.1e-07
# epochs: 627, loss: 0.065503, lr:  3.1e-07
# epochs: 628, loss: 0.067318, lr:  3.1e-07
# epochs: 629, loss: 0.068238, lr:  3.1e-07
# epochs: 630, loss: 0.068189, lr:  3.1e-07
# epochs: 631, loss: 0.066745, lr:  3.1e-07
# epochs: 632, loss: 0.065107, lr:  3.1e-07
# epochs: 633, loss: 0.062496, lr:  3.1e-07
# epochs: 634, loss: 0.066531, lr:  3.1e-07
# epochs: 635, loss: 0.065285, lr:  3.1e-07
# epochs: 636, loss: 0.065774, lr:  3.1e-07
# epochs: 637, loss: 0.066079, lr:  3.1e-07
# epochs: 638, loss: 0.066518, lr:  3.1e-07
# epochs: 639, loss: 0.064614, lr:  3.1e-07
# epochs: 640, loss: 0.066695, lr:  3.1e-07
# epochs: 641, loss: 0.065183, lr:  3.1e-07
# epochs: 642, loss: 0.065908, lr:  3.1e-07
# epochs: 643, loss: 0.067042, lr:  3.1e-07
# epochs: 644, loss: 0.067545, lr:  3.1e-07
# epochs: 645, loss: 0.064875, lr:  3.1e-07
# epochs: 646, loss: 0.067002, lr:  3.1e-07
# epochs: 647, loss: 0.067444, lr:  3.1e-07
# epochs: 648, loss: 0.067552, lr:  3.1e-07
# epochs: 649, loss: 0.067104, lr:  3.1e-07
# epochs: 650, loss: 0.067201, lr:  3.1e-07
# epochs: 651, loss: 0.066974, lr:  3.1e-07
# epochs: 652, loss: 0.066455, lr:  3.1e-07
# epochs: 653, loss: 0.065067, lr:  3.1e-07
# epochs: 654, loss: 0.067201, lr:  3.1e-07
# epochs: 655, loss: 0.065490, lr:  3.1e-07
# epochs: 656, loss: 0.067287, lr:  3.1e-07
# epochs: 657, loss: 0.064271, lr:  3.1e-07
# epochs: 658, loss: 0.067796, lr:  3.1e-07
# epochs: 659, loss: 0.066936, lr:  3.1e-07
# epochs: 660, loss: 0.066060, lr:  3.1e-07
# epochs: 661, loss: 0.065401, lr:  3.1e-07
# epochs: 662, loss: 0.066899, lr:  3.1e-07
# epochs: 663, loss: 0.065796, lr:  3.1e-07
# epochs: 664, loss: 0.069969, lr:  3.1e-07
# epochs: 665, loss: 0.065513, lr:  3.1e-07
# epochs: 666, loss: 0.066688, lr:  3.1e-07
# epochs: 667, loss: 0.066450, lr:  3.1e-07
# epochs: 668, loss: 0.066733, lr:  3.1e-07
# epochs: 669, loss: 0.067919, lr:  3.1e-07
# epochs: 670, loss: 0.064949, lr:  3.1e-07
# epochs: 671, loss: 0.064246, lr:  3.1e-07
# epochs: 672, loss: 0.068248, lr:  3.1e-07
# epochs: 673, loss: 0.066190, lr:  3.1e-07
# epochs: 674, loss: 0.069098, lr:  3.1e-07
# epochs: 675, loss: 0.065994, lr:  3.1e-07
# epochs: 676, loss: 0.067286, lr:  3.1e-07
# epochs: 677, loss: 0.066882, lr:  3.1e-07
# epochs: 678, loss: 0.067319, lr:  3.1e-07
# epochs: 679, loss: 0.065633, lr:  3.1e-07
# epochs: 680, loss: 0.065993, lr:  3.1e-07
# epochs: 681, loss: 0.067665, lr:  3.1e-07
# epochs: 682, loss: 0.066196, lr:  3.1e-07
# epochs: 683, loss: 0.065408, lr:  3.1e-07
# epochs: 684, loss: 0.065871, lr:  3.1e-07
# epochs: 685, loss: 0.065903, lr:  3.1e-07
# epochs: 686, loss: 0.067763, lr:  3.1e-07
# epochs: 687, loss: 0.066238, lr:  3.1e-07
# epochs: 688, loss: 0.068308, lr:  3.1e-07
# epochs: 689, loss: 0.064242, lr:  3.1e-07
# epochs: 690, loss: 0.065990, lr:  3.1e-07
# epochs: 691, loss: 0.063374, lr:  3.1e-07
# epochs: 692, loss: 0.065007, lr:  3.1e-07
# epochs: 693, loss: 0.064470, lr:  3.1e-07
# epochs: 694, loss: 0.065853, lr:  3.1e-07
# epochs: 695, loss: 0.067394, lr:  3.1e-07
# epochs: 696, loss: 0.067991, lr:  3.1e-07
# epochs: 697, loss: 0.066037, lr:  3.1e-07
# epochs: 698, loss: 0.067201, lr:  3.1e-07
# epochs: 699, loss: 0.065209, lr:  3.1e-07
# epochs: 700, loss: 0.066017, lr:  1.6e-07
# epochs: 701, loss: 0.065400, lr:  1.6e-07
# epochs: 702, loss: 0.066589, lr:  1.6e-07
# epochs: 703, loss: 0.065809, lr:  1.6e-07
# epochs: 704, loss: 0.068789, lr:  1.6e-07
# epochs: 705, loss: 0.065582, lr:  1.6e-07
# epochs: 706, loss: 0.065363, lr:  1.6e-07
# epochs: 707, loss: 0.065219, lr:  1.6e-07
# epochs: 708, loss: 0.068127, lr:  1.6e-07
# epochs: 709, loss: 0.064166, lr:  1.6e-07
# epochs: 710, loss: 0.065536, lr:  1.6e-07
# epochs: 711, loss: 0.064458, lr:  1.6e-07
# epochs: 712, loss: 0.069081, lr:  1.6e-07
# epochs: 713, loss: 0.065907, lr:  1.6e-07
# epochs: 714, loss: 0.065588, lr:  1.6e-07
# epochs: 715, loss: 0.067096, lr:  1.6e-07
# epochs: 716, loss: 0.066990, lr:  1.6e-07
# epochs: 717, loss: 0.062381, lr:  1.6e-07
# epochs: 718, loss: 0.065881, lr:  1.6e-07
# epochs: 719, loss: 0.066826, lr:  1.6e-07
# epochs: 720, loss: 0.066318, lr:  1.6e-07
# epochs: 721, loss: 0.066452, lr:  1.6e-07
# epochs: 722, loss: 0.063926, lr:  1.6e-07
# epochs: 723, loss: 0.064648, lr:  1.6e-07
# epochs: 724, loss: 0.064553, lr:  1.6e-07
# epochs: 725, loss: 0.064956, lr:  1.6e-07
# epochs: 726, loss: 0.065761, lr:  1.6e-07
# epochs: 727, loss: 0.066691, lr:  1.6e-07
# epochs: 728, loss: 0.066129, lr:  1.6e-07
# epochs: 729, loss: 0.067686, lr:  1.6e-07
# epochs: 730, loss: 0.067492, lr:  1.6e-07
# epochs: 731, loss: 0.067850, lr:  1.6e-07
# epochs: 732, loss: 0.066881, lr:  1.6e-07
# epochs: 733, loss: 0.064975, lr:  1.6e-07
# epochs: 734, loss: 0.064192, lr:  1.6e-07
# epochs: 735, loss: 0.064479, lr:  1.6e-07
# epochs: 736, loss: 0.067245, lr:  1.6e-07
# epochs: 737, loss: 0.067155, lr:  1.6e-07
# epochs: 738, loss: 0.067359, lr:  1.6e-07
# epochs: 739, loss: 0.065414, lr:  1.6e-07
# epochs: 740, loss: 0.065456, lr:  1.6e-07
# epochs: 741, loss: 0.067030, lr:  1.6e-07
# epochs: 742, loss: 0.064485, lr:  1.6e-07
# epochs: 743, loss: 0.066907, lr:  1.6e-07
# epochs: 744, loss: 0.068027, lr:  1.6e-07
# epochs: 745, loss: 0.067112, lr:  1.6e-07
# epochs: 746, loss: 0.068045, lr:  1.6e-07
# epochs: 747, loss: 0.066502, lr:  1.6e-07
# epochs: 748, loss: 0.065812, lr:  1.6e-07
# epochs: 749, loss: 0.064816, lr:  1.6e-07
# epochs: 750, loss: 0.063662, lr:  1.6e-07
# epochs: 751, loss: 0.063813, lr:  1.6e-07
# epochs: 752, loss: 0.063216, lr:  1.6e-07
# epochs: 753, loss: 0.065383, lr:  1.6e-07
# epochs: 754, loss: 0.064361, lr:  1.6e-07
# epochs: 755, loss: 0.066505, lr:  1.6e-07
# epochs: 756, loss: 0.064578, lr:  1.6e-07
# epochs: 757, loss: 0.064949, lr:  1.6e-07
# epochs: 758, loss: 0.068030, lr:  1.6e-07
# epochs: 759, loss: 0.066112, lr:  1.6e-07
# epochs: 760, loss: 0.068744, lr:  1.6e-07
# epochs: 761, loss: 0.066542, lr:  1.6e-07
# epochs: 762, loss: 0.066718, lr:  1.6e-07
# epochs: 763, loss: 0.066431, lr:  1.6e-07
# epochs: 764, loss: 0.063687, lr:  1.6e-07
# epochs: 765, loss: 0.065977, lr:  1.6e-07
# epochs: 766, loss: 0.067656, lr:  1.6e-07
# epochs: 767, loss: 0.063596, lr:  1.6e-07
# epochs: 768, loss: 0.068568, lr:  1.6e-07
# epochs: 769, loss: 0.065124, lr:  1.6e-07
# epochs: 770, loss: 0.065873, lr:  1.6e-07
# epochs: 771, loss: 0.064754, lr:  1.6e-07
# epochs: 772, loss: 0.065231, lr:  1.6e-07
# epochs: 773, loss: 0.065010, lr:  1.6e-07
# epochs: 774, loss: 0.067257, lr:  1.6e-07
# epochs: 775, loss: 0.064403, lr:  1.6e-07
# epochs: 776, loss: 0.065842, lr:  1.6e-07
# epochs: 777, loss: 0.065143, lr:  1.6e-07
# epochs: 778, loss: 0.067392, lr:  1.6e-07
# epochs: 779, loss: 0.065702, lr:  1.6e-07
# epochs: 780, loss: 0.068316, lr:  1.6e-07
# epochs: 781, loss: 0.064377, lr:  1.6e-07
# epochs: 782, loss: 0.066116, lr:  1.6e-07
# epochs: 783, loss: 0.065245, lr:  1.6e-07
# epochs: 784, loss: 0.065184, lr:  1.6e-07
# epochs: 785, loss: 0.066880, lr:  1.6e-07
# epochs: 786, loss: 0.067115, lr:  1.6e-07
# epochs: 787, loss: 0.066708, lr:  1.6e-07
# epochs: 788, loss: 0.065359, lr:  1.6e-07
# epochs: 789, loss: 0.068094, lr:  1.6e-07
# epochs: 790, loss: 0.068250, lr:  1.6e-07
# epochs: 791, loss: 0.066136, lr:  1.6e-07
# epochs: 792, loss: 0.067447, lr:  1.6e-07
# epochs: 793, loss: 0.065682, lr:  1.6e-07
# epochs: 794, loss: 0.064841, lr:  1.6e-07
# epochs: 795, loss: 0.066338, lr:  1.6e-07
# epochs: 796, loss: 0.067688, lr:  1.6e-07
# epochs: 797, loss: 0.067706, lr:  1.6e-07
# epochs: 798, loss: 0.064082, lr:  1.6e-07
# epochs: 799, loss: 0.066985, lr:  1.6e-07
# epochs: 800, loss: 0.065447, lr:  8e-08
# epochs: 801, loss: 0.063696, lr:  8e-08
# epochs: 802, loss: 0.066317, lr:  8e-08
# epochs: 803, loss: 0.066538, lr:  8e-08
# epochs: 804, loss: 0.066416, lr:  8e-08
# epochs: 805, loss: 0.064306, lr:  8e-08
# epochs: 806, loss: 0.067994, lr:  8e-08
# epochs: 807, loss: 0.064533, lr:  8e-08
# epochs: 808, loss: 0.064348, lr:  8e-08
# epochs: 809, loss: 0.065071, lr:  8e-08
# epochs: 810, loss: 0.066422, lr:  8e-08
# epochs: 811, loss: 0.065555, lr:  8e-08
# epochs: 812, loss: 0.063655, lr:  8e-08
# epochs: 813, loss: 0.069413, lr:  8e-08
# epochs: 814, loss: 0.064762, lr:  8e-08
# epochs: 815, loss: 0.067919, lr:  8e-08
# epochs: 816, loss: 0.067279, lr:  8e-08
# epochs: 817, loss: 0.067338, lr:  8e-08
# epochs: 818, loss: 0.068904, lr:  8e-08
# epochs: 819, loss: 0.066804, lr:  8e-08
# epochs: 820, loss: 0.066447, lr:  8e-08
# epochs: 821, loss: 0.067813, lr:  8e-08
# epochs: 822, loss: 0.068799, lr:  8e-08
# epochs: 823, loss: 0.067046, lr:  8e-08
# epochs: 824, loss: 0.065843, lr:  8e-08
# epochs: 825, loss: 0.062714, lr:  8e-08
# epochs: 826, loss: 0.065370, lr:  8e-08
# epochs: 827, loss: 0.065040, lr:  8e-08
# epochs: 828, loss: 0.066105, lr:  8e-08
# epochs: 829, loss: 0.066103, lr:  8e-08
# epochs: 830, loss: 0.066359, lr:  8e-08
# epochs: 831, loss: 0.066601, lr:  8e-08
# epochs: 832, loss: 0.064287, lr:  8e-08
# epochs: 833, loss: 0.063709, lr:  8e-08
# epochs: 834, loss: 0.065887, lr:  8e-08
# epochs: 835, loss: 0.066779, lr:  8e-08
# epochs: 836, loss: 0.067175, lr:  8e-08
# epochs: 837, loss: 0.067597, lr:  8e-08
# epochs: 838, loss: 0.064407, lr:  8e-08
# epochs: 839, loss: 0.067724, lr:  8e-08
# epochs: 840, loss: 0.066142, lr:  8e-08
# epochs: 841, loss: 0.065839, lr:  8e-08
# epochs: 842, loss: 0.065120, lr:  8e-08
# epochs: 843, loss: 0.065600, lr:  8e-08
# epochs: 844, loss: 0.066215, lr:  8e-08
# epochs: 845, loss: 0.064685, lr:  8e-08
# epochs: 846, loss: 0.066181, lr:  8e-08
# epochs: 847, loss: 0.066719, lr:  8e-08
# epochs: 848, loss: 0.065706, lr:  8e-08
# epochs: 849, loss: 0.067494, lr:  8e-08
# epochs: 850, loss: 0.067764, lr:  8e-08
# epochs: 851, loss: 0.068705, lr:  8e-08
# epochs: 852, loss: 0.063990, lr:  8e-08
# epochs: 853, loss: 0.068245, lr:  8e-08
# epochs: 854, loss: 0.065462, lr:  8e-08
# epochs: 855, loss: 0.064822, lr:  8e-08
# epochs: 856, loss: 0.065423, lr:  8e-08
# epochs: 857, loss: 0.065163, lr:  8e-08
# epochs: 858, loss: 0.066309, lr:  8e-08
# epochs: 859, loss: 0.067503, lr:  8e-08
# epochs: 860, loss: 0.069684, lr:  8e-08
# epochs: 861, loss: 0.061916, lr:  8e-08
# epochs: 862, loss: 0.063593, lr:  8e-08
# epochs: 863, loss: 0.066197, lr:  8e-08
# epochs: 864, loss: 0.070070, lr:  8e-08
# epochs: 865, loss: 0.064710, lr:  8e-08
# epochs: 866, loss: 0.064283, lr:  8e-08
# epochs: 867, loss: 0.065972, lr:  8e-08
# epochs: 868, loss: 0.066276, lr:  8e-08
# epochs: 869, loss: 0.066059, lr:  8e-08
# epochs: 870, loss: 0.064637, lr:  8e-08
# epochs: 871, loss: 0.067961, lr:  8e-08
# epochs: 872, loss: 0.066800, lr:  8e-08
# epochs: 873, loss: 0.067859, lr:  8e-08
# epochs: 874, loss: 0.065491, lr:  8e-08
# epochs: 875, loss: 0.066956, lr:  8e-08
# epochs: 876, loss: 0.065840, lr:  8e-08
# epochs: 877, loss: 0.065420, lr:  8e-08
# epochs: 878, loss: 0.064300, lr:  8e-08
# epochs: 879, loss: 0.064149, lr:  8e-08
# epochs: 880, loss: 0.065837, lr:  8e-08
# epochs: 881, loss: 0.066043, lr:  8e-08
# epochs: 882, loss: 0.064667, lr:  8e-08
# epochs: 883, loss: 0.067646, lr:  8e-08
# epochs: 884, loss: 0.064193, lr:  8e-08
# epochs: 885, loss: 0.067413, lr:  8e-08
# epochs: 886, loss: 0.066664, lr:  8e-08
# epochs: 887, loss: 0.067516, lr:  8e-08
# epochs: 888, loss: 0.065505, lr:  8e-08
# epochs: 889, loss: 0.064982, lr:  8e-08
# epochs: 890, loss: 0.066356, lr:  8e-08
# epochs: 891, loss: 0.066491, lr:  8e-08
# epochs: 892, loss: 0.066970, lr:  8e-08
# epochs: 893, loss: 0.067775, lr:  8e-08
# epochs: 894, loss: 0.067457, lr:  8e-08
# epochs: 895, loss: 0.064443, lr:  8e-08
# epochs: 896, loss: 0.065409, lr:  8e-08
# epochs: 897, loss: 0.066876, lr:  8e-08
# epochs: 898, loss: 0.064807, lr:  8e-08
# epochs: 899, loss: 0.067042, lr:  8e-08
# epochs: 900, loss: 0.066188, lr:  4e-08
# epochs: 901, loss: 0.066648, lr:  4e-08
# epochs: 902, loss: 0.065798, lr:  4e-08
# epochs: 903, loss: 0.067224, lr:  4e-08
# epochs: 904, loss: 0.065044, lr:  4e-08
# epochs: 905, loss: 0.066610, lr:  4e-08
# epochs: 906, loss: 0.064522, lr:  4e-08
# epochs: 907, loss: 0.066328, lr:  4e-08
# epochs: 908, loss: 0.068989, lr:  4e-08
# epochs: 909, loss: 0.065727, lr:  4e-08
# epochs: 910, loss: 0.066900, lr:  4e-08
# epochs: 911, loss: 0.065681, lr:  4e-08
# epochs: 912, loss: 0.065519, lr:  4e-08
# epochs: 913, loss: 0.065055, lr:  4e-08
# epochs: 914, loss: 0.064623, lr:  4e-08
# epochs: 915, loss: 0.066915, lr:  4e-08
# epochs: 916, loss: 0.063967, lr:  4e-08
# epochs: 917, loss: 0.065536, lr:  4e-08
# epochs: 918, loss: 0.064352, lr:  4e-08
# epochs: 919, loss: 0.066334, lr:  4e-08
# epochs: 920, loss: 0.064739, lr:  4e-08
# epochs: 921, loss: 0.065529, lr:  4e-08
# epochs: 922, loss: 0.065392, lr:  4e-08
# epochs: 923, loss: 0.068599, lr:  4e-08
# epochs: 924, loss: 0.067294, lr:  4e-08
# epochs: 925, loss: 0.065916, lr:  4e-08
# epochs: 926, loss: 0.068414, lr:  4e-08
# epochs: 927, loss: 0.065742, lr:  4e-08
# epochs: 928, loss: 0.065101, lr:  4e-08
# epochs: 929, loss: 0.065455, lr:  4e-08
# epochs: 930, loss: 0.067629, lr:  4e-08
# epochs: 931, loss: 0.064009, lr:  4e-08
# epochs: 932, loss: 0.066025, lr:  4e-08
# epochs: 933, loss: 0.063573, lr:  4e-08
# epochs: 934, loss: 0.066798, lr:  4e-08
# epochs: 935, loss: 0.066995, lr:  4e-08
# epochs: 936, loss: 0.064529, lr:  4e-08
# epochs: 937, loss: 0.066923, lr:  4e-08
# epochs: 938, loss: 0.065474, lr:  4e-08
# epochs: 939, loss: 0.064782, lr:  4e-08
# epochs: 940, loss: 0.062891, lr:  4e-08
# epochs: 941, loss: 0.066562, lr:  4e-08
# epochs: 942, loss: 0.065136, lr:  4e-08
# epochs: 943, loss: 0.064789, lr:  4e-08
# epochs: 944, loss: 0.066868, lr:  4e-08
# epochs: 945, loss: 0.066049, lr:  4e-08
# epochs: 946, loss: 0.067019, lr:  4e-08
# epochs: 947, loss: 0.068166, lr:  4e-08
# epochs: 948, loss: 0.066644, lr:  4e-08
# epochs: 949, loss: 0.067222, lr:  4e-08
# epochs: 950, loss: 0.063922, lr:  4e-08
# epochs: 951, loss: 0.066504, lr:  4e-08
# epochs: 952, loss: 0.064383, lr:  4e-08
# epochs: 953, loss: 0.062068, lr:  4e-08
# epochs: 954, loss: 0.067081, lr:  4e-08
# epochs: 955, loss: 0.065064, lr:  4e-08
# epochs: 956, loss: 0.065575, lr:  4e-08
# epochs: 957, loss: 0.062572, lr:  4e-08
# epochs: 958, loss: 0.068934, lr:  4e-08
# epochs: 959, loss: 0.068546, lr:  4e-08
# epochs: 960, loss: 0.063770, lr:  4e-08
# epochs: 961, loss: 0.066330, lr:  4e-08
# epochs: 962, loss: 0.064813, lr:  4e-08
# epochs: 963, loss: 0.063061, lr:  4e-08
# epochs: 964, loss: 0.064636, lr:  4e-08
# epochs: 965, loss: 0.064584, lr:  4e-08
# epochs: 966, loss: 0.065734, lr:  4e-08
# epochs: 967, loss: 0.068500, lr:  4e-08
# epochs: 968, loss: 0.066680, lr:  4e-08
# epochs: 969, loss: 0.066804, lr:  4e-08
# epochs: 970, loss: 0.062978, lr:  4e-08
# epochs: 971, loss: 0.067297, lr:  4e-08
# epochs: 972, loss: 0.066233, lr:  4e-08
# epochs: 973, loss: 0.065283, lr:  4e-08
# epochs: 974, loss: 0.066443, lr:  4e-08
# epochs: 975, loss: 0.065257, lr:  4e-08
# epochs: 976, loss: 0.065601, lr:  4e-08
# epochs: 977, loss: 0.065387, lr:  4e-08
# epochs: 978, loss: 0.065184, lr:  4e-08
# epochs: 979, loss: 0.064763, lr:  4e-08
# epochs: 980, loss: 0.064754, lr:  4e-08
# epochs: 981, loss: 0.064245, lr:  4e-08
# epochs: 982, loss: 0.069293, lr:  4e-08
# epochs: 983, loss: 0.065480, lr:  4e-08
# epochs: 984, loss: 0.066591, lr:  4e-08
# epochs: 985, loss: 0.064633, lr:  4e-08
# epochs: 986, loss: 0.065140, lr:  4e-08
# epochs: 987, loss: 0.063460, lr:  4e-08
# epochs: 988, loss: 0.068276, lr:  4e-08
# epochs: 989, loss: 0.064285, lr:  4e-08
# epochs: 990, loss: 0.065446, lr:  4e-08
# epochs: 991, loss: 0.065878, lr:  4e-08
# epochs: 992, loss: 0.066362, lr:  4e-08
# epochs: 993, loss: 0.066432, lr:  4e-08
# epochs: 994, loss: 0.066059, lr:  4e-08
# epochs: 995, loss: 0.065616, lr:  4e-08
# epochs: 996, loss: 0.067858, lr:  4e-08
# epochs: 997, loss: 0.064682, lr:  4e-08
# epochs: 998, loss: 0.066434, lr:  4e-08
# epochs: 999, loss: 0.065458, lr:  4e-08
# epochs: 1000, loss: 0.063433, lr:  2e-08
# epochs: 1001, loss: 0.064082, lr:  2e-08
# epochs: 1002, loss: 0.066680, lr:  2e-08
# epochs: 1003, loss: 0.065229, lr:  2e-08
# epochs: 1004, loss: 0.065844, lr:  2e-08
# epochs: 1005, loss: 0.067815, lr:  2e-08
# epochs: 1006, loss: 0.069063, lr:  2e-08
# epochs: 1007, loss: 0.065184, lr:  2e-08
# epochs: 1008, loss: 0.067914, lr:  2e-08
# epochs: 1009, loss: 0.065509, lr:  2e-08
# epochs: 1010, loss: 0.065524, lr:  2e-08
# epochs: 1011, loss: 0.067260, lr:  2e-08
# epochs: 1012, loss: 0.064840, lr:  2e-08
# epochs: 1013, loss: 0.064896, lr:  2e-08
# epochs: 1014, loss: 0.064801, lr:  2e-08
# epochs: 1015, loss: 0.063703, lr:  2e-08
# epochs: 1016, loss: 0.063206, lr:  2e-08
# epochs: 1017, loss: 0.067668, lr:  2e-08
# epochs: 1018, loss: 0.065593, lr:  2e-08
# epochs: 1019, loss: 0.070206, lr:  2e-08
# epochs: 1020, loss: 0.064548, lr:  2e-08
# epochs: 1021, loss: 0.066057, lr:  2e-08
# epochs: 1022, loss: 0.063320, lr:  2e-08
# epochs: 1023, loss: 0.066291, lr:  2e-08
# epochs: 1024, loss: 0.063813, lr:  2e-08
# epochs: 1025, loss: 0.067290, lr:  2e-08
# epochs: 1026, loss: 0.063228, lr:  2e-08
# epochs: 1027, loss: 0.068856, lr:  2e-08
# epochs: 1028, loss: 0.066172, lr:  2e-08
# epochs: 1029, loss: 0.064648, lr:  2e-08
# epochs: 1030, loss: 0.067640, lr:  2e-08
# epochs: 1031, loss: 0.065375, lr:  2e-08
# epochs: 1032, loss: 0.063282, lr:  2e-08
# epochs: 1033, loss: 0.064534, lr:  2e-08
# epochs: 1034, loss: 0.063652, lr:  2e-08
# epochs: 1035, loss: 0.064547, lr:  2e-08
# epochs: 1036, loss: 0.067031, lr:  2e-08
# epochs: 1037, loss: 0.064595, lr:  2e-08
# epochs: 1038, loss: 0.065268, lr:  2e-08
# epochs: 1039, loss: 0.065815, lr:  2e-08
# epochs: 1040, loss: 0.065369, lr:  2e-08
# epochs: 1041, loss: 0.066490, lr:  2e-08
# epochs: 1042, loss: 0.065488, lr:  2e-08
# epochs: 1043, loss: 0.068561, lr:  2e-08
# epochs: 1044, loss: 0.067190, lr:  2e-08
# epochs: 1045, loss: 0.065138, lr:  2e-08
# epochs: 1046, loss: 0.067067, lr:  2e-08
# epochs: 1047, loss: 0.065809, lr:  2e-08
# epochs: 1048, loss: 0.065686, lr:  2e-08
# epochs: 1049, loss: 0.062815, lr:  2e-08
# epochs: 1050, loss: 0.065108, lr:  2e-08
# epochs: 1051, loss: 0.064214, lr:  2e-08
# epochs: 1052, loss: 0.066160, lr:  2e-08
# epochs: 1053, loss: 0.065994, lr:  2e-08
# epochs: 1054, loss: 0.063562, lr:  2e-08
# epochs: 1055, loss: 0.062684, lr:  2e-08
# epochs: 1056, loss: 0.064408, lr:  2e-08
# epochs: 1057, loss: 0.065605, lr:  2e-08
# epochs: 1058, loss: 0.065711, lr:  2e-08
# epochs: 1059, loss: 0.066007, lr:  2e-08
# epochs: 1060, loss: 0.066901, lr:  2e-08
# epochs: 1061, loss: 0.066659, lr:  2e-08
# epochs: 1062, loss: 0.065976, lr:  2e-08
# epochs: 1063, loss: 0.065711, lr:  2e-08
# epochs: 1064, loss: 0.064892, lr:  2e-08
# epochs: 1065, loss: 0.067513, lr:  2e-08
# epochs: 1066, loss: 0.064572, lr:  2e-08
# epochs: 1067, loss: 0.065841, lr:  2e-08
# epochs: 1068, loss: 0.066366, lr:  2e-08
# epochs: 1069, loss: 0.065521, lr:  2e-08
# epochs: 1070, loss: 0.065544, lr:  2e-08
# epochs: 1071, loss: 0.065891, lr:  2e-08
# epochs: 1072, loss: 0.064308, lr:  2e-08
# epochs: 1073, loss: 0.062463, lr:  2e-08
# epochs: 1074, loss: 0.064242, lr:  2e-08
# epochs: 1075, loss: 0.064445, lr:  2e-08
# epochs: 1076, loss: 0.063455, lr:  2e-08
# epochs: 1077, loss: 0.067894, lr:  2e-08
# epochs: 1078, loss: 0.066798, lr:  2e-08
# epochs: 1079, loss: 0.066671, lr:  2e-08
# epochs: 1080, loss: 0.064436, lr:  2e-08
# epochs: 1081, loss: 0.065513, lr:  2e-08
# epochs: 1082, loss: 0.067533, lr:  2e-08
# epochs: 1083, loss: 0.065581, lr:  2e-08
# epochs: 1084, loss: 0.064059, lr:  2e-08
# epochs: 1085, loss: 0.066184, lr:  2e-08
# epochs: 1086, loss: 0.065402, lr:  2e-08
# epochs: 1087, loss: 0.066380, lr:  2e-08
# epochs: 1088, loss: 0.066231, lr:  2e-08
# epochs: 1089, loss: 0.066234, lr:  2e-08
# epochs: 1090, loss: 0.066370, lr:  2e-08
# epochs: 1091, loss: 0.064824, lr:  2e-08
# epochs: 1092, loss: 0.065256, lr:  2e-08
# epochs: 1093, loss: 0.064007, lr:  2e-08
# epochs: 1094, loss: 0.064613, lr:  2e-08
# epochs: 1095, loss: 0.064085, lr:  2e-08
# epochs: 1096, loss: 0.068455, lr:  2e-08
# epochs: 1097, loss: 0.066242, lr:  2e-08
# epochs: 1098, loss: 0.065797, lr:  2e-08
# epochs: 1099, loss: 0.064603, lr:  2e-08
# epochs: 1100, loss: 0.065322, lr:  1e-08
# epochs: 1101, loss: 0.066269, lr:  1e-08
# epochs: 1102, loss: 0.067315, lr:  1e-08
# epochs: 1103, loss: 0.064920, lr:  1e-08
# epochs: 1104, loss: 0.065061, lr:  1e-08
# epochs: 1105, loss: 0.066555, lr:  1e-08
# epochs: 1106, loss: 0.064969, lr:  1e-08
# epochs: 1107, loss: 0.067399, lr:  1e-08
# epochs: 1108, loss: 0.064758, lr:  1e-08
# epochs: 1109, loss: 0.063741, lr:  1e-08
# epochs: 1110, loss: 0.069955, lr:  1e-08
# epochs: 1111, loss: 0.063791, lr:  1e-08
# epochs: 1112, loss: 0.065588, lr:  1e-08
# epochs: 1113, loss: 0.063899, lr:  1e-08
# epochs: 1114, loss: 0.064477, lr:  1e-08
# epochs: 1115, loss: 0.064204, lr:  1e-08
# epochs: 1116, loss: 0.060076, lr:  1e-08
# epochs: 1117, loss: 0.067545, lr:  1e-08
# epochs: 1118, loss: 0.064623, lr:  1e-08
# epochs: 1119, loss: 0.064211, lr:  1e-08
# epochs: 1120, loss: 0.065538, lr:  1e-08
# epochs: 1121, loss: 0.067536, lr:  1e-08
# epochs: 1122, loss: 0.067900, lr:  1e-08
# epochs: 1123, loss: 0.066366, lr:  1e-08
# epochs: 1124, loss: 0.063638, lr:  1e-08
# epochs: 1125, loss: 0.064653, lr:  1e-08
# epochs: 1126, loss: 0.065504, lr:  1e-08
# epochs: 1127, loss: 0.064913, lr:  1e-08
# epochs: 1128, loss: 0.064398, lr:  1e-08
# epochs: 1129, loss: 0.066330, lr:  1e-08
# epochs: 1130, loss: 0.063425, lr:  1e-08
# epochs: 1131, loss: 0.065599, lr:  1e-08
# epochs: 1132, loss: 0.064185, lr:  1e-08
# epochs: 1133, loss: 0.065407, lr:  1e-08
# epochs: 1134, loss: 0.069845, lr:  1e-08
# epochs: 1135, loss: 0.062901, lr:  1e-08
# epochs: 1136, loss: 0.068117, lr:  1e-08
# epochs: 1137, loss: 0.064305, lr:  1e-08
# epochs: 1138, loss: 0.062220, lr:  1e-08
# epochs: 1139, loss: 0.066718, lr:  1e-08
# epochs: 1140, loss: 0.065516, lr:  1e-08
# epochs: 1141, loss: 0.066769, lr:  1e-08
# epochs: 1142, loss: 0.065945, lr:  1e-08
# epochs: 1143, loss: 0.066480, lr:  1e-08
# epochs: 1144, loss: 0.064230, lr:  1e-08
# epochs: 1145, loss: 0.064805, lr:  1e-08
# epochs: 1146, loss: 0.061207, lr:  1e-08
# epochs: 1147, loss: 0.066116, lr:  1e-08
# epochs: 1148, loss: 0.066610, lr:  1e-08
# epochs: 1149, loss: 0.067876, lr:  1e-08
# epochs: 1150, loss: 0.065646, lr:  1e-08
# epochs: 1151, loss: 0.066635, lr:  1e-08
# epochs: 1152, loss: 0.068325, lr:  1e-08
# epochs: 1153, loss: 0.064938, lr:  1e-08
# epochs: 1154, loss: 0.062268, lr:  1e-08
# epochs: 1155, loss: 0.062179, lr:  1e-08
# epochs: 1156, loss: 0.062319, lr:  1e-08
# epochs: 1157, loss: 0.065159, lr:  1e-08
# epochs: 1158, loss: 0.066829, lr:  1e-08
# epochs: 1159, loss: 0.065028, lr:  1e-08
# epochs: 1160, loss: 0.066524, lr:  1e-08
# epochs: 1161, loss: 0.066526, lr:  1e-08
# epochs: 1162, loss: 0.067443, lr:  1e-08
# epochs: 1163, loss: 0.063622, lr:  1e-08
# epochs: 1164, loss: 0.063330, lr:  1e-08
# epochs: 1165, loss: 0.068247, lr:  1e-08
# epochs: 1166, loss: 0.066008, lr:  1e-08
# epochs: 1167, loss: 0.067795, lr:  1e-08
# epochs: 1168, loss: 0.067339, lr:  1e-08
# epochs: 1169, loss: 0.066304, lr:  1e-08
# ...
# epochs: 2590, loss: 0.066102, lr:  0.0
# epochs: 2591, loss: 0.064822, lr:  0.0
# epochs: 2592, loss: 0.063564, lr:  0.0
# epochs: 2593, loss: 0.066905, lr:  0.0
# epochs: 2594, loss: 0.063310, lr:  0.0
# epochs: 2595, loss: 0.067705, lr:  0.0
# epochs: 2596, loss: 0.065720, lr:  0.0
# epochs: 2597, loss: 0.067278, lr:  0.0
# epochs: 2598, loss: 0.065574, lr:  0.0
# epochs: 2599, loss: 0.065899, lr:  0.0
# epochs: 2600, loss: 0.066727, lr:  0.0
# epochs: 2601, loss: 0.064520, lr:  0.0
# epochs: 2602, loss: 0.063765, lr:  0.0
# epochs: 2603, loss: 0.065801, lr:  0.0
# epochs: 2604, loss: 0.067060, lr:  0.0
# epochs: 2605, loss: 0.064064, lr:  0.0
# epochs: 2606, loss: 0.066171, lr:  0.0
# epochs: 2607, loss: 0.065358, lr:  0.0
# epochs: 2608, loss: 0.063376, lr:  0.0
# epochs: 2609, loss: 0.064991, lr:  0.0
# epochs: 2610, loss: 0.068483, lr:  0.0
# epochs: 2611, loss: 0.064164, lr:  0.0
# epochs: 2612, loss: 0.066714, lr:  0.0
# epochs: 2613, loss: 0.064207, lr:  0.0
# epochs: 2614, loss: 0.068272, lr:  0.0
# epochs: 2615, loss: 0.066393, lr:  0.0
# epochs: 2616, loss: 0.064836, lr:  0.0
# epochs: 2617, loss: 0.066768, lr:  0.0
# epochs: 2618, loss: 0.065067, lr:  0.0
# epochs: 2619, loss: 0.066692, lr:  0.0
# epochs: 2620, loss: 0.064814, lr:  0.0
# epochs: 2621, loss: 0.065559, lr:  0.0
# epochs: 2622, loss: 0.066139, lr:  0.0
# epochs: 2623, loss: 0.067194, lr:  0.0
# epochs: 2624, loss: 0.066945, lr:  0.0
# epochs: 2625, loss: 0.067096, lr:  0.0
# epochs: 2626, loss: 0.065074, lr:  0.0
# epochs: 2627, loss: 0.061806, lr:  0.0
# epochs: 2628, loss: 0.067760, lr:  0.0
# epochs: 2629, loss: 0.067875, lr:  0.0
# epochs: 2630, loss: 0.064793, lr:  0.0
# epochs: 2631, loss: 0.068086, lr:  0.0
# epochs: 2632, loss: 0.066426, lr:  0.0
# epochs: 2633, loss: 0.064176, lr:  0.0
# epochs: 2634, loss: 0.065091, lr:  0.0
# epochs: 2635, loss: 0.069981, lr:  0.0
# epochs: 2636, loss: 0.064944, lr:  0.0
# epochs: 2637, loss: 0.069379, lr:  0.0
# epochs: 2638, loss: 0.067236, lr:  0.0
# epochs: 2639, loss: 0.066944, lr:  0.0
# epochs: 2640, loss: 0.063534, lr:  0.0
# epochs: 2641, loss: 0.063991, lr:  0.0
# epochs: 2642, loss: 0.064323, lr:  0.0
# epochs: 2643, loss: 0.066993, lr:  0.0
# epochs: 2644, loss: 0.067909, lr:  0.0
# epochs: 2645, loss: 0.064317, lr:  0.0
# epochs: 2646, loss: 0.066838, lr:  0.0
# epochs: 2647, loss: 0.064640, lr:  0.0
# epochs: 2648, loss: 0.062059, lr:  0.0
# epochs: 2649, loss: 0.066318, lr:  0.0
# epochs: 2650, loss: 0.067036, lr:  0.0
# epochs: 2651, loss: 0.066890, lr:  0.0
# epochs: 2652, loss: 0.062828, lr:  0.0
# epochs: 2653, loss: 0.066706, lr:  0.0
# epochs: 2654, loss: 0.067723, lr:  0.0
# epochs: 2655, loss: 0.066143, lr:  0.0
# epochs: 2656, loss: 0.066859, lr:  0.0
# epochs: 2657, loss: 0.066252, lr:  0.0
# epochs: 2658, loss: 0.065278, lr:  0.0
# epochs: 2659, loss: 0.065798, lr:  0.0
# epochs: 2660, loss: 0.069910, lr:  0.0
# epochs: 2661, loss: 0.067469, lr:  0.0
# epochs: 2662, loss: 0.067161, lr:  0.0
# epochs: 2663, loss: 0.064921, lr:  0.0
# epochs: 2664, loss: 0.064567, lr:  0.0
# epochs: 2665, loss: 0.066931, lr:  0.0
# epochs: 2666, loss: 0.065141, lr:  0.0
# epochs: 2667, loss: 0.065194, lr:  0.0
# epochs: 2668, loss: 0.066655, lr:  0.0
# epochs: 2669, loss: 0.066699, lr:  0.0
# epochs: 2670, loss: 0.064176, lr:  0.0
# epochs: 2671, loss: 0.066321, lr:  0.0
# epochs: 2672, loss: 0.066591, lr:  0.0
# epochs: 2673, loss: 0.063694, lr:  0.0
# epochs: 2674, loss: 0.067604, lr:  0.0
# epochs: 2675, loss: 0.064370, lr:  0.0
# epochs: 2676, loss: 0.066421, lr:  0.0
# epochs: 2677, loss: 0.065079, lr:  0.0
# epochs: 2678, loss: 0.065714, lr:  0.0
# epochs: 2679, loss: 0.064532, lr:  0.0
# epochs: 2680, loss: 0.067177, lr:  0.0
# epochs: 2681, loss: 0.068714, lr:  0.0
# epochs: 2682, loss: 0.064880, lr:  0.0
# epochs: 2683, loss: 0.067538, lr:  0.0
# epochs: 2684, loss: 0.066069, lr:  0.0
# epochs: 2685, loss: 0.066618, lr:  0.0
# epochs: 2686, loss: 0.066844, lr:  0.0
# epochs: 2687, loss: 0.064131, lr:  0.0
# epochs: 2688, loss: 0.068063, lr:  0.0
# epochs: 2689, loss: 0.062944, lr:  0.0
# epochs: 2690, loss: 0.066282, lr:  0.0
# epochs: 2691, loss: 0.067447, lr:  0.0
# epochs: 2692, loss: 0.067178, lr:  0.0
# epochs: 2693, loss: 0.064163, lr:  0.0
# epochs: 2694, loss: 0.064106, lr:  0.0
# epochs: 2695, loss: 0.065079, lr:  0.0
# epochs: 2696, loss: 0.063646, lr:  0.0
# epochs: 2697, loss: 0.065265, lr:  0.0
# epochs: 2698, loss: 0.066386, lr:  0.0
# epochs: 2699, loss: 0.064359, lr:  0.0
# epochs: 2700, loss: 0.065612, lr:  0.0
# epochs: 2701, loss: 0.066036, lr:  0.0
# epochs: 2702, loss: 0.063080, lr:  0.0
# epochs: 2703, loss: 0.065699, lr:  0.0
# epochs: 2704, loss: 0.065413, lr:  0.0
# epochs: 2705, loss: 0.065982, lr:  0.0
# epochs: 2706, loss: 0.067152, lr:  0.0
# epochs: 2707, loss: 0.067211, lr:  0.0
# epochs: 2708, loss: 0.064987, lr:  0.0
# epochs: 2709, loss: 0.066037, lr:  0.0
# epochs: 2710, loss: 0.066854, lr:  0.0
# epochs: 2711, loss: 0.066643, lr:  0.0
# epochs: 2712, loss: 0.065278, lr:  0.0
# epochs: 2713, loss: 0.065121, lr:  0.0
# epochs: 2714, loss: 0.064308, lr:  0.0
# epochs: 2715, loss: 0.065822, lr:  0.0
# epochs: 2716, loss: 0.063314, lr:  0.0
# epochs: 2717, loss: 0.064263, lr:  0.0
# epochs: 2718, loss: 0.064700, lr:  0.0
# epochs: 2719, loss: 0.064962, lr:  0.0
# epochs: 2720, loss: 0.065315, lr:  0.0
# epochs: 2721, loss: 0.067474, lr:  0.0
# epochs: 2722, loss: 0.068732, lr:  0.0
# epochs: 2723, loss: 0.064346, lr:  0.0
# epochs: 2724, loss: 0.065451, lr:  0.0
# epochs: 2725, loss: 0.064986, lr:  0.0
# epochs: 2726, loss: 0.064312, lr:  0.0
# epochs: 2727, loss: 0.066575, lr:  0.0
# epochs: 2728, loss: 0.065321, lr:  0.0
# epochs: 2729, loss: 0.067065, lr:  0.0
# epochs: 2730, loss: 0.063763, lr:  0.0
# epochs: 2731, loss: 0.063844, lr:  0.0
# epochs: 2732, loss: 0.065438, lr:  0.0
# epochs: 2733, loss: 0.064415, lr:  0.0
# epochs: 2734, loss: 0.064811, lr:  0.0
# epochs: 2735, loss: 0.066094, lr:  0.0
# epochs: 2736, loss: 0.062515, lr:  0.0
# epochs: 2737, loss: 0.067872, lr:  0.0
# epochs: 2738, loss: 0.064228, lr:  0.0
# epochs: 2739, loss: 0.066651, lr:  0.0
# epochs: 2740, loss: 0.067090, lr:  0.0
# epochs: 2741, loss: 0.065068, lr:  0.0
# epochs: 2742, loss: 0.066299, lr:  0.0
# epochs: 2743, loss: 0.065832, lr:  0.0
# epochs: 2744, loss: 0.065095, lr:  0.0
# epochs: 2745, loss: 0.063868, lr:  0.0
# epochs: 2746, loss: 0.063877, lr:  0.0
# epochs: 2747, loss: 0.067313, lr:  0.0
# epochs: 2748, loss: 0.064280, lr:  0.0
# epochs: 2749, loss: 0.064798, lr:  0.0
# epochs: 2750, loss: 0.068400, lr:  0.0
# epochs: 2751, loss: 0.067926, lr:  0.0
# epochs: 2752, loss: 0.064436, lr:  0.0
# epochs: 2753, loss: 0.065995, lr:  0.0
# epochs: 2754, loss: 0.067470, lr:  0.0
# epochs: 2755, loss: 0.065626, lr:  0.0
# epochs: 2756, loss: 0.064121, lr:  0.0
# epochs: 2757, loss: 0.066927, lr:  0.0
# epochs: 2758, loss: 0.063852, lr:  0.0
# epochs: 2759, loss: 0.064341, lr:  0.0
# epochs: 2760, loss: 0.063709, lr:  0.0
# epochs: 2761, loss: 0.067249, lr:  0.0
# epochs: 2762, loss: 0.066008, lr:  0.0
# epochs: 2763, loss: 0.066278, lr:  0.0
# epochs: 2764, loss: 0.065209, lr:  0.0
# epochs: 2765, loss: 0.063593, lr:  0.0
# epochs: 2766, loss: 0.067370, lr:  0.0
# epochs: 2767, loss: 0.066640, lr:  0.0
# epochs: 2768, loss: 0.063647, lr:  0.0
# epochs: 2769, loss: 0.067475, lr:  0.0
# epochs: 2770, loss: 0.066720, lr:  0.0
# epochs: 2771, loss: 0.066303, lr:  0.0
# epochs: 2772, loss: 0.066806, lr:  0.0
# epochs: 2773, loss: 0.066707, lr:  0.0
# epochs: 2774, loss: 0.064079, lr:  0.0
# epochs: 2775, loss: 0.065381, lr:  0.0
# epochs: 2776, loss: 0.065618, lr:  0.0
# epochs: 2777, loss: 0.065664, lr:  0.0
# epochs: 2778, loss: 0.066608, lr:  0.0
# epochs: 2779, loss: 0.065225, lr:  0.0
# epochs: 2780, loss: 0.064894, lr:  0.0
# epochs: 2781, loss: 0.063154, lr:  0.0
# epochs: 2782, loss: 0.064425, lr:  0.0
# epochs: 2783, loss: 0.069302, lr:  0.0
# epochs: 2784, loss: 0.065329, lr:  0.0
# epochs: 2785, loss: 0.064694, lr:  0.0
# epochs: 2786, loss: 0.064672, lr:  0.0
# epochs: 2787, loss: 0.067608, lr:  0.0
# epochs: 2788, loss: 0.065262, lr:  0.0
# epochs: 2789, loss: 0.063895, lr:  0.0
# epochs: 2790, loss: 0.068327, lr:  0.0
# epochs: 2791, loss: 0.068471, lr:  0.0
# epochs: 2792, loss: 0.065824, lr:  0.0
# epochs: 2793, loss: 0.065629, lr:  0.0
# epochs: 2794, loss: 0.063491, lr:  0.0
# epochs: 2795, loss: 0.067708, lr:  0.0
# epochs: 2796, loss: 0.066500, lr:  0.0
# epochs: 2797, loss: 0.063727, lr:  0.0
# epochs: 2798, loss: 0.064378, lr:  0.0
# epochs: 2799, loss: 0.064957, lr:  0.0
# epochs: 2800, loss: 0.068007, lr:  0.0
# epochs: 2801, loss: 0.068247, lr:  0.0
# epochs: 2802, loss: 0.065795, lr:  0.0
# epochs: 2803, loss: 0.067531, lr:  0.0
# epochs: 2804, loss: 0.065731, lr:  0.0
# epochs: 2805, loss: 0.065916, lr:  0.0
# epochs: 2806, loss: 0.068659, lr:  0.0
# epochs: 2807, loss: 0.066835, lr:  0.0
# epochs: 2808, loss: 0.066832, lr:  0.0
# epochs: 2809, loss: 0.066148, lr:  0.0
# epochs: 2810, loss: 0.068193, lr:  0.0
# epochs: 2811, loss: 0.068157, lr:  0.0
# epochs: 2812, loss: 0.064508, lr:  0.0
# epochs: 2813, loss: 0.064778, lr:  0.0
# epochs: 2814, loss: 0.066980, lr:  0.0
# epochs: 2815, loss: 0.064243, lr:  0.0
# epochs: 2816, loss: 0.066693, lr:  0.0
# epochs: 2817, loss: 0.064986, lr:  0.0
# epochs: 2818, loss: 0.065311, lr:  0.0
# epochs: 2819, loss: 0.063974, lr:  0.0
# epochs: 2820, loss: 0.063267, lr:  0.0
# epochs: 2821, loss: 0.068675, lr:  0.0
# epochs: 2822, loss: 0.065179, lr:  0.0
# epochs: 2823, loss: 0.067940, lr:  0.0
# epochs: 2824, loss: 0.063619, lr:  0.0
# epochs: 2825, loss: 0.064968, lr:  0.0
# epochs: 2826, loss: 0.068376, lr:  0.0
# epochs: 2827, loss: 0.069170, lr:  0.0
# epochs: 2828, loss: 0.066076, lr:  0.0
# epochs: 2829, loss: 0.066013, lr:  0.0
# epochs: 2830, loss: 0.062693, lr:  0.0
# epochs: 2831, loss: 0.061992, lr:  0.0
# epochs: 2832, loss: 0.063620, lr:  0.0
# epochs: 2833, loss: 0.066310, lr:  0.0
# epochs: 2834, loss: 0.063230, lr:  0.0
# epochs: 2835, loss: 0.064300, lr:  0.0
# epochs: 2836, loss: 0.067382, lr:  0.0
# epochs: 2837, loss: 0.063308, lr:  0.0
# epochs: 2838, loss: 0.066942, lr:  0.0
# epochs: 2839, loss: 0.066100, lr:  0.0
# epochs: 2840, loss: 0.064755, lr:  0.0
# epochs: 2841, loss: 0.064065, lr:  0.0
# epochs: 2842, loss: 0.065295, lr:  0.0
# epochs: 2843, loss: 0.062272, lr:  0.0
# epochs: 2844, loss: 0.065648, lr:  0.0
# epochs: 2845, loss: 0.066759, lr:  0.0
# epochs: 2846, loss: 0.065289, lr:  0.0
# epochs: 2847, loss: 0.063955, lr:  0.0
# epochs: 2848, loss: 0.064531, lr:  0.0
# epochs: 2849, loss: 0.062650, lr:  0.0
# epochs: 2850, loss: 0.063901, lr:  0.0
# epochs: 2851, loss: 0.063524, lr:  0.0
# epochs: 2852, loss: 0.067284, lr:  0.0
# epochs: 2853, loss: 0.064411, lr:  0.0
# epochs: 2854, loss: 0.064408, lr:  0.0
# epochs: 2855, loss: 0.066103, lr:  0.0
# epochs: 2856, loss: 0.064850, lr:  0.0
# epochs: 2857, loss: 0.067510, lr:  0.0
# epochs: 2858, loss: 0.064940, lr:  0.0
# epochs: 2859, loss: 0.065918, lr:  0.0
# epochs: 2860, loss: 0.066621, lr:  0.0
# epochs: 2861, loss: 0.067510, lr:  0.0
# epochs: 2862, loss: 0.064004, lr:  0.0
# epochs: 2863, loss: 0.065607, lr:  0.0
# epochs: 2864, loss: 0.066416, lr:  0.0
# epochs: 2865, loss: 0.065685, lr:  0.0
# epochs: 2866, loss: 0.066225, lr:  0.0
# epochs: 2867, loss: 0.067350, lr:  0.0
# epochs: 2868, loss: 0.065021, lr:  0.0
# epochs: 2869, loss: 0.065986, lr:  0.0
# epochs: 2870, loss: 0.065961, lr:  0.0
# epochs: 2871, loss: 0.063495, lr:  0.0
# epochs: 2872, loss: 0.067954, lr:  0.0
# epochs: 2873, loss: 0.066420, lr:  0.0
# epochs: 2874, loss: 0.066048, lr:  0.0
# epochs: 2875, loss: 0.064807, lr:  0.0
# epochs: 2876, loss: 0.065009, lr:  0.0
# epochs: 2877, loss: 0.068017, lr:  0.0
# epochs: 2878, loss: 0.067527, lr:  0.0
# epochs: 2879, loss: 0.066294, lr:  0.0
# epochs: 2880, loss: 0.063096, lr:  0.0
# epochs: 2881, loss: 0.065538, lr:  0.0
# epochs: 2882, loss: 0.067088, lr:  0.0
# epochs: 2883, loss: 0.065287, lr:  0.0
# epochs: 2884, loss: 0.064934, lr:  0.0
# epochs: 2885, loss: 0.066895, lr:  0.0
# epochs: 2886, loss: 0.066707, lr:  0.0
# epochs: 2887, loss: 0.065638, lr:  0.0
# epochs: 2888, loss: 0.065509, lr:  0.0
# epochs: 2889, loss: 0.067979, lr:  0.0
# epochs: 2890, loss: 0.066842, lr:  0.0
# epochs: 2891, loss: 0.063296, lr:  0.0
# epochs: 2892, loss: 0.066937, lr:  0.0
# epochs: 2893, loss: 0.065208, lr:  0.0
# epochs: 2894, loss: 0.066204, lr:  0.0
# epochs: 2895, loss: 0.067138, lr:  0.0
# epochs: 2896, loss: 0.065792, lr:  0.0
# epochs: 2897, loss: 0.066212, lr:  0.0
# epochs: 2898, loss: 0.062838, lr:  0.0
# epochs: 2899, loss: 0.066084, lr:  0.0
# epochs: 2900, loss: 0.065109, lr:  0.0
# epochs: 2901, loss: 0.065044, lr:  0.0
# epochs: 2902, loss: 0.068014, lr:  0.0
# epochs: 2903, loss: 0.067369, lr:  0.0
# epochs: 2904, loss: 0.062450, lr:  0.0
# epochs: 2905, loss: 0.064624, lr:  0.0
# epochs: 2906, loss: 0.066488, lr:  0.0
# epochs: 2907, loss: 0.066185, lr:  0.0
# epochs: 2908, loss: 0.066681, lr:  0.0
# epochs: 2909, loss: 0.067193, lr:  0.0
# epochs: 2910, loss: 0.065015, lr:  0.0
# epochs: 2911, loss: 0.065544, lr:  0.0
# epochs: 2912, loss: 0.066498, lr:  0.0
# epochs: 2913, loss: 0.067095, lr:  0.0
# epochs: 2914, loss: 0.065846, lr:  0.0
# epochs: 2915, loss: 0.064070, lr:  0.0
# epochs: 2916, loss: 0.065032, lr:  0.0
# epochs: 2917, loss: 0.066654, lr:  0.0
# epochs: 2918, loss: 0.065257, lr:  0.0
# epochs: 2919, loss: 0.063911, lr:  0.0
# epochs: 2920, loss: 0.064218, lr:  0.0
# epochs: 2921, loss: 0.064361, lr:  0.0
# epochs: 2922, loss: 0.068456, lr:  0.0
# epochs: 2923, loss: 0.065831, lr:  0.0
# epochs: 2924, loss: 0.063709, lr:  0.0
# epochs: 2925, loss: 0.065512, lr:  0.0
# epochs: 2926, loss: 0.064714, lr:  0.0
# epochs: 2927, loss: 0.065556, lr:  0.0
# epochs: 2928, loss: 0.065991, lr:  0.0
# epochs: 2929, loss: 0.067504, lr:  0.0
# epochs: 2930, loss: 0.066125, lr:  0.0
# epochs: 2931, loss: 0.065808, lr:  0.0
# epochs: 2932, loss: 0.067672, lr:  0.0
# epochs: 2933, loss: 0.065386, lr:  0.0
# epochs: 2934, loss: 0.066300, lr:  0.0
# epochs: 2935, loss: 0.066383, lr:  0.0
# epochs: 2936, loss: 0.065762, lr:  0.0
# epochs: 2937, loss: 0.063930, lr:  0.0
# epochs: 2938, loss: 0.065440, lr:  0.0
# epochs: 2939, loss: 0.064700, lr:  0.0
# epochs: 2940, loss: 0.066203, lr:  0.0
# epochs: 2941, loss: 0.065272, lr:  0.0
# epochs: 2942, loss: 0.064293, lr:  0.0
# epochs: 2943, loss: 0.065256, lr:  0.0
# epochs: 2944, loss: 0.064207, lr:  0.0
# epochs: 2945, loss: 0.065873, lr:  0.0
# epochs: 2946, loss: 0.064884, lr:  0.0
# epochs: 2947, loss: 0.066479, lr:  0.0
# epochs: 2948, loss: 0.064888, lr:  0.0
# epochs: 2949, loss: 0.065272, lr:  0.0
# epochs: 2950, loss: 0.065489, lr:  0.0
# epochs: 2951, loss: 0.069228, lr:  0.0
# epochs: 2952, loss: 0.068138, lr:  0.0
# epochs: 2953, loss: 0.065975, lr:  0.0
# epochs: 2954, loss: 0.067373, lr:  0.0
# epochs: 2955, loss: 0.065852, lr:  0.0
# epochs: 2956, loss: 0.061782, lr:  0.0
# epochs: 2957, loss: 0.066957, lr:  0.0
# epochs: 2958, loss: 0.065239, lr:  0.0
# epochs: 2959, loss: 0.069758, lr:  0.0
# epochs: 2960, loss: 0.066319, lr:  0.0
# epochs: 2961, loss: 0.067543, lr:  0.0
# epochs: 2962, loss: 0.066630, lr:  0.0
# epochs: 2963, loss: 0.065079, lr:  0.0
# epochs: 2964, loss: 0.066793, lr:  0.0
# epochs: 2965, loss: 0.066009, lr:  0.0
# epochs: 2966, loss: 0.065525, lr:  0.0
# epochs: 2967, loss: 0.066359, lr:  0.0
# epochs: 2968, loss: 0.066465, lr:  0.0
# epochs: 2969, loss: 0.067965, lr:  0.0
# epochs: 2970, loss: 0.065766, lr:  0.0
# epochs: 2971, loss: 0.066070, lr:  0.0
# epochs: 2972, loss: 0.068321, lr:  0.0
# epochs: 2973, loss: 0.067495, lr:  0.0
# epochs: 2974, loss: 0.065998, lr:  0.0
# epochs: 2975, loss: 0.066938, lr:  0.0
# epochs: 2976, loss: 0.065718, lr:  0.0
# epochs: 2977, loss: 0.064421, lr:  0.0
# epochs: 2978, loss: 0.063759, lr:  0.0
# epochs: 2979, loss: 0.065250, lr:  0.0
# epochs: 2980, loss: 0.067844, lr:  0.0
# epochs: 2981, loss: 0.065800, lr:  0.0
# epochs: 2982, loss: 0.064852, lr:  0.0
# epochs: 2983, loss: 0.064539, lr:  0.0
# epochs: 2984, loss: 0.067044, lr:  0.0
# epochs: 2985, loss: 0.066382, lr:  0.0
# epochs: 2986, loss: 0.063951, lr:  0.0
# epochs: 2987, loss: 0.065943, lr:  0.0
# epochs: 2988, loss: 0.065602, lr:  0.0
# epochs: 2989, loss: 0.068164, lr:  0.0
# epochs: 2990, loss: 0.066719, lr:  0.0
# epochs: 2991, loss: 0.063443, lr:  0.0
# epochs: 2992, loss: 0.065476, lr:  0.0
# epochs: 2993, loss: 0.068534, lr:  0.0
# epochs: 2994, loss: 0.067563, lr:  0.0
# epochs: 2995, loss: 0.066501, lr:  0.0
# epochs: 2996, loss: 0.066189, lr:  0.0
# epochs: 2997, loss: 0.065092, lr:  0.0
# epochs: 2998, loss: 0.064631, lr:  0.0
# epochs: 2999, loss: 0.064149, lr:  0.0

# %%
save_path = 'transormer_kospi_only_1970_window_flatten_modeld' + str(model_d) + '_seqlen' + str(seq_len) + '_layaers' + str(n_layers) + '_nhead' + str(n_head) + '.pt'
# save_path = 'kospi_only.pt'
torch.save(model.state_dict(), save_path)
print(save_path)
df_loss
# Out:
# transormer_kospi_only_1970_window_flatten_modeld512_seqlen128_layaers4_nhead4.pt
#        epoch      loss
# 0        0.0  9.025858
# 1        1.0  1.821385
# 2        2.0  1.257526
# 3        3.0  0.970837
# 4        4.0  0.816726
# ...      ...       ...
# 2995  2995.0  0.066501
# 2996  2996.0  0.066189
# 2997  2997.0  0.065092
# 2998  2998.0  0.064631
# 2999  2999.0  0.064149
#
# [3000 rows x 2 columns]

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_loss.loc[20: , 'epoch'], df_loss.loc[20: , 'loss'])
plt.show()

# %%
test_result = pd.DataFrame(columns=['pred', 'pred_rescale', 'real'])
num = 0
min = scale_params.loc['min', 'kospi']
max = scale_params.loc['max', 'kospi']
with torch.no_grad():
    for _, data in enumerate(test_dataloader):
        inputs = data[0].to(device).float()
        # outputs = data[1].to(device).float()
        outputs = data[1]

        pred = model(inputs)
        for i in range(len(pred)):
            pred_ = pred.detach().cpu().numpy()[i][0]
            pred_scaled = pred_ * (max - min) + min
            out_scaled = outputs.numpy()[i] * (max - min) + min
            test_result.loc[num] = [pred_, pred_scaled, out_scaled[0][0]]
            num += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\alan.kwak\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'kospi'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 3
#       1 test_result = pd.DataFrame(columns=['pred', 'pred_rescale', 'real'])
#       2 num = 0
# ----> 3 min = scale_params.loc['min', 'kospi']
#       4 max = scale_params.loc['max', 'kospi']
#       5 with torch.no_grad():
#
# File c:\Users\alan.kwak\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File c:\Users\alan.kwak\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4202, in DataFrame._get_value(self, index, col, takeable)
#    4199     series = self._ixs(col, axis=1)
#    4200     return series._values[index]
# -> 4202 series = self._get_item_cache(col)
#    4203 engine = self.index._engine
#    4205 if not isinstance(self.index, MultiIndex):
#    4206     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4207     #  results if our categories are integers that dont match our codes
#    4208     # IntervalIndex: IntervalTree has no get_loc
#
# File c:\Users\alan.kwak\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4626, in DataFrame._get_item_cache(self, item)
#    4621 res = cache.get(item)
#    4622 if res is None:
#    4623     # All places that call _get_item_cache have unique columns,
#    4624     #  pending resolution of GH#33047
# -> 4626     loc = self.columns.get_loc(item)
#    4627     res = self._ixs(loc, axis=1)
#    4629     cache[item] = res
#
# File c:\Users\alan.kwak\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'kospi'

# %%
test_result
# Out:
#          pred  pred_rescale         real
# 0    0.659477   2424.745968  2409.659912
# 1    0.647453   2393.656511  2403.760010
# 2    0.635558   2362.900252  2433.250000
# 3    0.669102   2449.633376  2486.669922
# 4    0.655924   2415.559329  2488.179932
# ..        ...           ...          ...
# 135  0.794430   2773.683808  2724.620117
# 136  0.763815   2694.525434  2742.139893
# 137  0.483076   1968.641980  2724.179932
# 138  0.830284   2866.388270  2723.459961
# 139  0.792134   2767.748225  2721.810059
#
# [140 rows x 3 columns]

# %%
plt.figure(figsize=(20, 5))
# plt.plot(idx_num, test_result['pred'], label='pred')
# plt.plot(range(len(test_result)), test_result['pred_rescale'], label='pred')
plt.scatter(range(len(test_result)), test_result['pred_rescale'], label='pred')
plt.plot(range(len(test_result)), test_result['real'], 'g--', label='real')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 5))
# plt.plot(idx_num, test_result['pred'], label='pred')
plt.scatter(range(20), test_result.iloc[-20: , 1], label='pred')
plt.plot(range(20), test_result.iloc[-20: , 2], 'g--', label='real')
# plt.scatter(range(len(test_result)), test_result['pred'], label='pred')
# plt.plot(range(len(test_result)), test_result['real'], 'g--', label='real')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 5))
# plt.plot(idx_num, test_result['pred'], label='pred')
plt.scatter(range(20), test_result.iloc[-50:-30 , 1], label='pred')
plt.plot(range(20), test_result.iloc[-50:-30 , 2], 'g--', label='real')
# plt.scatter(range(len(test_result)), test_result['pred'], label='pred')
# plt.plot(range(len(test_result)), test_result['real'], 'g--', label='real')
plt.legend()
plt.show()

# %%
df_ma = test_result.copy()
df_ma['sma_pred_5d'] = df_ma['pred_rescale'].rolling(5).mean()
df_ma['sma_pred_10d'] = df_ma['pred_rescale'].rolling(10).mean()
df_ma['sma_pred_20d'] = df_ma['pred_rescale'].ewm(20).mean()
df_ma['sma_real_5d'] = df_ma['real'].rolling(5).mean()
df_ma['sma_real_10d'] = df_ma['real'].rolling(10).mean()
df_ma['sma_real_20d'] = df_ma['real'].rolling(20).mean()
df_ma['ewm_pred_5d'] = df_ma['pred_rescale'].ewm(5).mean()
df_ma['ewm_pred_10d'] = df_ma['pred_rescale'].ewm(10).mean()
df_ma['ewm_pred_20d'] = df_ma['pred_rescale'].ewm(20).mean()
df_ma['ewm_real_5d'] = df_ma['real'].ewm(5).mean()
df_ma['ewm_real_10d'] = df_ma['real'].ewm(10).mean()
df_ma['ewm_real_20d'] = df_ma['real'].ewm(20).mean()
df_ma = df_ma.dropna()
df_ma
# Out:
#          pred  pred_rescale         real  sma_pred_5d  sma_pred_10d  \
# 19   0.716229   2571.486833  2492.070068  2410.091300   2435.941849
# 20   0.695354   2517.511614  2517.850098  2427.507091   2434.389557
# 21   0.483076   1968.641980  2525.360107  2427.507091   2389.285827
# 22   0.671947   2456.990207  2535.270020  2430.837824   2392.532212
# 23   0.483076   1968.641980  2510.659912  2296.654523   2343.414188
# ..        ...           ...          ...          ...           ...
# 135  0.794430   2773.683808  2724.620117  2663.241485   2649.580257
# 136  0.763815   2694.525434  2742.139893  2673.196571   2658.960849
# 137  0.483076   1968.641980  2724.179932  2534.092472   2591.570123
# 138  0.830284   2866.388270  2723.459961  2594.680641   2612.933323
# 139  0.792134   2767.748225  2721.810059  2614.197543   2625.287270
#
#      sma_pred_20d  sma_real_5d  sma_real_10d  sma_real_20d  ewm_pred_5d  \
# 19    2443.017021  2500.337988   2507.083984   2489.524475  2452.972936
# 20    2448.550629  2502.906006   2509.206006   2494.933984  2463.968387
# 21    2413.827863  2504.988037   2512.176025   2501.013989  2379.891015
# 22    2416.875405  2513.186035   2513.527026   2506.114990  2392.937821
# 23    2385.938376  2516.242041   2512.612012   2507.314490  2321.320971
# ..            ...          ...           ...           ...          ...
# 135   2593.054264  2733.102051   2726.132007   2695.316003  2653.312053
# 136   2597.892274  2736.088037   2732.683008   2700.951001  2660.180950
# 137   2567.892247  2734.856006   2731.664990   2706.008997  2544.924455
# 138   2582.122483  2733.479980   2729.505981   2708.394495  2598.501757
# 139   2590.971363  2727.241992   2730.472998   2713.053992  2626.709502
#
#      ewm_pred_10d  ewm_pred_20d  ewm_real_5d  ewm_real_10d  ewm_real_20d
# 19    2445.840284   2443.017021  2501.983685   2498.962738   2495.229964
# 20    2453.373878   2448.550629  2504.686845   2500.948046   2496.910233
# 21    2403.135796   2413.827863  2508.195952   2503.478136   2498.968663
# 22    2408.647149   2416.875405  2512.777454   2506.731654   2501.531774
# 23    2364.126716   2385.938376  2512.420035   2507.129121   2502.161798
# ..            ...           ...          ...           ...           ...
# 135   2625.751509   2593.054264  2720.493622   2706.458041   2692.073667
# 136   2632.003698   2597.892274  2724.101334   2709.701852   2694.460758
# 137   2571.697970   2567.892247  2724.114433   2711.018044   2695.877644
# 138   2598.488044   2582.122483  2724.005355   2712.149129   2697.192579
# 139   2613.875358   2590.971363  2723.639472   2713.027397   2698.366108
#
# [121 rows x 15 columns]

# %%
plt.figure(figsize=(20, 5))
plt.plot(range(len(df_ma)), df_ma['sma_pred_5d'], 'r-', label='sma_pred_5d')
plt.plot(range(len(df_ma)), df_ma['sma_pred_10d'], 'g-', label='sma_pred_10d')
plt.plot(range(len(df_ma)), df_ma['sma_pred_20d'], 'b-', label='sma_pred_20d')
plt.plot(range(len(df_ma)), df_ma['sma_real_5d'], 'r--', label='sma_real_5d')
plt.plot(range(len(df_ma)), df_ma['sma_real_10d'], 'g--', label='sma_real_10d')
plt.plot(range(len(df_ma)), df_ma['sma_real_20d'], 'b--', label='sma_real_20d')
plt.plot(range(len(df_ma)), df_ma['real'], 'k-.', label='real')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.plot(range(len(df_ma)), df_ma['sma_pred_5d'], 'r-', label='sma_pred_5d')
plt.plot(range(len(df_ma)), df_ma['sma_pred_10d'], 'g-', label='sma_pred_10d')
plt.plot(range(len(df_ma)), df_ma['sma_pred_20d'], 'b-', label='sma_pred_20d')
# plt.plot(range(len(df_ma)), df_ma['sma_real_5d'], 'r--', label='sma_real_5d')
# plt.plot(range(len(df_ma)), df_ma['sma_real_10d'], 'g--', label='sma_real_10d')
# plt.plot(range(len(df_ma)), df_ma['sma_real_20d'], 'b--', label='sma_real_20d')
plt.plot(range(len(df_ma)), df_ma['real'], 'k-.', label='real')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.plot(range(len(df_ma)), df_ma['ewm_pred_5d'], 'r-', label='ewm_pred_5d')
plt.plot(range(len(df_ma)), df_ma['ewm_pred_10d'], 'g-', label='ewm_pred_10d')
plt.plot(range(len(df_ma)), df_ma['ewm_pred_20d'], 'b-', label='ewm_pred_20d')
plt.plot(range(len(df_ma)), df_ma['ewm_real_5d'], 'r--', label='ewm_real_5d')
plt.plot(range(len(df_ma)), df_ma['ewm_real_10d'], 'g--', label='ewm_real_10d')
plt.plot(range(len(df_ma)), df_ma['ewm_real_20d'], 'b--', label='ewm_real_20d')
plt.plot(range(len(df_ma)), df_ma['real'], 'k-.', label='real')
plt.legend()
plt.show()

# %% [markdown]
# ## 11. evaluation metrics
# MAPE, MSE

# %%
mse = mean_squared_error(test_result['real'], test_result['pred_rescale'])
mape = mean_absolute_percentage_error(test_result['real'], test_result['pred_rescale'])
print(f'MSE: {mse:.4f}, MAPE: {mape:.4f}')
# Out:
# MSE: 79212.1332, MAPE: 0.0657
